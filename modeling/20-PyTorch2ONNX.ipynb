# %%
import io
import numpy as np

from torch import nn
import torch.utils.model_zoo as model_zoo
import torch.onnx

# %%
import torch.nn as nn
import torch.nn.init as init

# %%
from utils.google_utils import *
from utils.layers import *
from utils.parse_config import *

ONNX_EXPORT = False


def create_modules(module_defs, img_size, cfg):
    # Constructs module list of layer blocks from module configuration in module_defs

    img_size = [img_size] * 2 if isinstance(img_size, int) else img_size  # expand if necessary
    _ = module_defs.pop(0)  # cfg training hyperparams (unused)
    output_filters = [3]  # input channels
    module_list = nn.ModuleList()
    routs = []  # list of layers which rout to deeper layers
    yolo_index = -1

    for i, mdef in enumerate(module_defs):
        modules = nn.Sequential()

        if mdef['type'] == 'convolutional':
            bn = mdef['batch_normalize']
            filters = mdef['filters']
            k = mdef['size']  # kernel size
            stride = mdef['stride'] if 'stride' in mdef else (mdef['stride_y'], mdef['stride_x'])
            if isinstance(k, int):  # single-size conv
                modules.add_module('Conv2d', nn.Conv2d(in_channels=output_filters[-1],
                                                       out_channels=filters,
                                                       kernel_size=k,
                                                       stride=stride,
                                                       padding=k // 2 if mdef['pad'] else 0,
                                                       groups=mdef['groups'] if 'groups' in mdef else 1,
                                                       bias=not bn))
            else:  # multiple-size conv
                modules.add_module('MixConv2d', MixConv2d(in_ch=output_filters[-1],
                                                          out_ch=filters,
                                                          k=k,
                                                          stride=stride,
                                                          bias=not bn))

            if bn:
                modules.add_module('BatchNorm2d', nn.BatchNorm2d(filters, momentum=0.03, eps=1E-4))
            else:
                routs.append(i)  # detection output (goes into yolo layer)

            if mdef['activation'] == 'leaky':  # activation study https://github.com/ultralytics/yolov3/issues/441
                modules.add_module('activation', nn.LeakyReLU(0.1, inplace=True))
            elif mdef['activation'] == 'swish':
                modules.add_module('activation', Swish())
            elif mdef['activation'] == 'mish':
                modules.add_module('activation', Mish())
            elif mdef['activation'] == 'relu':
                modules.add_module('activation', nn.ReLU())

        elif mdef['type'] == 'BatchNorm2d':
            filters = output_filters[-1]
            modules = nn.BatchNorm2d(filters, momentum=0.03, eps=1E-4)
            if i == 0 and filters == 3:  # normalize RGB image
                # imagenet mean and var https://pytorch.org/docs/stable/torchvision/models.html#classification
                modules.running_mean = torch.tensor([0.485, 0.456, 0.406])
                modules.running_var = torch.tensor([0.0524, 0.0502, 0.0506])

        elif mdef['type'] == 'maxpool':
            k = mdef['size']  # kernel size
            stride = mdef['stride']
            maxpool = nn.MaxPool2d(kernel_size=k, stride=stride, padding=(k - 1) // 2)
            if k == 2 and stride == 1:  # yolov3-tiny
                modules.add_module('ZeroPad2d', nn.ZeroPad2d((0, 1, 0, 1)))
                modules.add_module('MaxPool2d', maxpool)
            else:
                modules = maxpool

        elif mdef['type'] == 'upsample':
            if ONNX_EXPORT:  # explicitly state size, avoid scale_factor
                g = (yolo_index + 1) * 2 / 32  # gain
                modules = nn.Upsample(size=tuple(int(x * g) for x in img_size))  # img_size = (320, 192)
            else:
                modules = nn.Upsample(scale_factor=mdef['stride'])

        elif mdef['type'] == 'route':  # nn.Sequential() placeholder for 'route' layer
            layers = mdef['layers']
            filters = sum([output_filters[l + 1 if l > 0 else l] for l in layers])
            routs.extend([i + l if l < 0 else l for l in layers])
            modules = FeatureConcat(layers=layers)

        elif mdef['type'] == 'shortcut':  # nn.Sequential() placeholder for 'shortcut' layer
            layers = mdef['from']
            filters = output_filters[-1]
            routs.extend([i + l if l < 0 else l for l in layers])
            modules = WeightedFeatureFusion(layers=layers, weight='weights_type' in mdef)

        elif mdef['type'] == 'reorg3d':  # yolov3-spp-pan-scale
            pass

        elif mdef['type'] == 'yolo':
            yolo_index += 1
            stride = [32, 16, 8]  # P5, P4, P3 strides
            if any(x in cfg for x in ['panet', 'yolov4', 'cd53']):  # stride order reversed
                stride = list(reversed(stride))
            layers = mdef['from'] if 'from' in mdef else []
            modules = YOLOLayer(anchors=mdef['anchors'][mdef['mask']],  # anchor list
                                nc=mdef['classes'],  # number of classes
                                img_size=img_size,  # (416, 416)
                                yolo_index=yolo_index,  # 0, 1, 2...
                                layers=layers,  # output layers
                                stride=stride[yolo_index])

            # Initialize preceding Conv2d() bias (https://arxiv.org/pdf/1708.02002.pdf section 3.3)
            try:
                j = layers[yolo_index] if 'from' in mdef else -1
                # If previous layer is a dropout layer, get the one before
                if module_list[j].__class__.__name__ == 'Dropout':
                    j -= 1
                bias_ = module_list[j][0].bias  # shape(255,)
                bias = bias_[:modules.no * modules.na].view(modules.na, -1)  # shape(3,85)
                bias[:, 4] += -4.5  # obj
                bias[:, 5:] += math.log(0.6 / (modules.nc - 0.99))  # cls (sigmoid(p) = 1/nc)
                module_list[j][0].bias = torch.nn.Parameter(bias_, requires_grad=bias_.requires_grad)
            except:
                print('WARNING: smart bias initialization failure.')

        elif mdef['type'] == 'dropout':
            perc = float(mdef['probability'])
            modules = nn.Dropout(p=perc)
        else:
            print('Warning: Unrecognized Layer Type: ' + mdef['type'])

        # Register module list and number of output filters
        module_list.append(modules)
        output_filters.append(filters)

    routs_binary = [False] * (i + 1)
    for i in routs:
        routs_binary[i] = True
    return module_list, routs_binary


class YOLOLayer(nn.Module):
    def __init__(self, anchors, nc, img_size, yolo_index, layers, stride):
        super(YOLOLayer, self).__init__()
        self.anchors = torch.Tensor(anchors)
        self.index = yolo_index  # index of this layer in layers
        self.layers = layers  # model output layer indices
        self.stride = stride  # layer stride
        self.nl = len(layers)  # number of output layers (3)
        self.na = len(anchors)  # number of anchors (3)
        self.nc = nc  # number of classes (80)
        self.no = nc + 5  # number of outputs (85)
        self.nx, self.ny, self.ng = 0, 0, 0  # initialize number of x, y gridpoints
        self.anchor_vec = self.anchors / self.stride
        self.anchor_wh = self.anchor_vec.view(1, self.na, 1, 1, 2)

        if ONNX_EXPORT:
            self.training = False
            self.create_grids((img_size[1] // stride, img_size[0] // stride))  # number x, y grid points

    def create_grids(self, ng=(13, 13), device='cpu'):
        self.nx, self.ny = ng  # x and y grid size
        self.ng = torch.tensor(ng, dtype=torch.float)

        # build xy offsets
        if not self.training:
            yv, xv = torch.meshgrid([torch.arange(self.ny, device=device), torch.arange(self.nx, device=device)])
            self.grid = torch.stack((xv, yv), 2).view((1, 1, self.ny, self.nx, 2)).float()

        if self.anchor_vec.device != device:
            self.anchor_vec = self.anchor_vec.to(device)
            self.anchor_wh = self.anchor_wh.to(device)

    def forward(self, p, out):
        ASFF = False  # https://arxiv.org/abs/1911.09516
        if ASFF:
            i, n = self.index, self.nl  # index in layers, number of layers
            p = out[self.layers[i]]
            bs, _, ny, nx = p.shape  # bs, 255, 13, 13
            if (self.nx, self.ny) != (nx, ny):
                self.create_grids((nx, ny), p.device)

            # outputs and weights
            # w = F.softmax(p[:, -n:], 1)  # normalized weights
            w = torch.sigmoid(p[:, -n:]) * (2 / n)  # sigmoid weights (faster)
            # w = w / w.sum(1).unsqueeze(1)  # normalize across layer dimension

            # weighted ASFF sum
            p = out[self.layers[i]][:, :-n] * w[:, i:i + 1]
            for j in range(n):
                if j != i:
                    p += w[:, j:j + 1] * \
                         F.interpolate(out[self.layers[j]][:, :-n], size=[ny, nx], mode='bilinear', align_corners=False)

        elif ONNX_EXPORT:
            bs = 1  # batch size
        else:
            bs, _, ny, nx = p.shape  # bs, 255, 13, 13
            if (self.nx, self.ny) != (nx, ny):
                self.create_grids((nx, ny), p.device)

        # p.view(bs, 255, 13, 13) -- > (bs, 3, 13, 13, 85)  # (bs, anchors, grid, grid, classes + xywh)
        p = p.view(bs, self.na, self.no, self.ny, self.nx).permute(0, 1, 3, 4, 2).contiguous()  # prediction

        if self.training:
            return p

        elif ONNX_EXPORT:
            # Avoid broadcasting for ANE operations
            m = self.na * self.nx * self.ny
            ng = 1. / self.ng.repeat(m, 1)
            grid = self.grid.repeat(1, self.na, 1, 1, 1).view(m, 2)
            anchor_wh = self.anchor_wh.repeat(1, 1, self.nx, self.ny, 1).view(m, 2) * ng

            p = p.view(m, self.no)
            xy = torch.sigmoid(p[:, 0:2]) + grid  # x, y
            wh = torch.exp(p[:, 2:4]) * anchor_wh  # width, height
            p_cls = torch.sigmoid(p[:, 4:5]) if self.nc == 1 else \
                torch.sigmoid(p[:, 5:self.no]) * torch.sigmoid(p[:, 4:5])  # conf
            return p_cls, xy * ng, wh

        else:  # inference
            io = p.clone()  # inference output
            io[..., :2] = torch.sigmoid(io[..., :2]) + self.grid  # xy
            io[..., 2:4] = torch.exp(io[..., 2:4]) * self.anchor_wh  # wh yolo method
            io[..., :4] *= self.stride
            torch.sigmoid_(io[..., 4:])
            return io.view(bs, -1, self.no), p  # view [1, 3, 13, 13, 85] as [1, 507, 85]


class Darknet(nn.Module):
    # YOLOv3 object detection model

    def __init__(self, cfg, img_size=(416, 416), verbose=False):
        super(Darknet, self).__init__()

        self.module_defs = parse_model_cfg(cfg)
        self.module_list, self.routs = create_modules(self.module_defs, img_size, cfg)
        self.yolo_layers = get_yolo_layers(self)
        # torch_utils.initialize_weights(self)

        # Darknet Header https://github.com/AlexeyAB/darknet/issues/2914#issuecomment-496675346
        self.version = np.array([0, 2, 5], dtype=np.int32)  # (int32) version info: major, minor, revision
        self.seen = np.array([0], dtype=np.int64)  # (int64) number of images seen during training
        self.info(verbose) if not ONNX_EXPORT else None  # print model description

    def forward(self, x, augment=False, verbose=False):

        if not augment:
            return self.forward_once(x)
        else:  # Augment images (inference and test only) https://github.com/ultralytics/yolov3/issues/931
            img_size = x.shape[-2:]  # height, width
            s = [0.83, 0.67]  # scales
            y = []
            for i, xi in enumerate((x,
                                    torch_utils.scale_img(x.flip(3), s[0], same_shape=False),  # flip-lr and scale
                                    torch_utils.scale_img(x, s[1], same_shape=False),  # scale
                                    )):
                # cv2.imwrite('img%g.jpg' % i, 255 * xi[0].numpy().transpose((1, 2, 0))[:, :, ::-1])
                y.append(self.forward_once(xi)[0])

            y[1][..., :4] /= s[0]  # scale
            y[1][..., 0] = img_size[1] - y[1][..., 0]  # flip lr
            y[2][..., :4] /= s[1]  # scale

            # for i, yi in enumerate(y):  # coco small, medium, large = < 32**2 < 96**2 <
            #     area = yi[..., 2:4].prod(2)[:, :, None]
            #     if i == 1:
            #         yi *= (area < 96. ** 2).float()
            #     elif i == 2:
            #         yi *= (area > 32. ** 2).float()
            #     y[i] = yi

            y = torch.cat(y, 1)
            return y, None

    def forward_once(self, x, augment=False, verbose=False):
        img_size = x.shape[-2:]  # height, width
        yolo_out, out = [], []
        if verbose:
            print('0', x.shape)
            str = ''

        # Augment images (inference and test only)
        if augment:  # https://github.com/ultralytics/yolov3/issues/931
            nb = x.shape[0]  # batch size
            s = [0.83, 0.67]  # scales
            x = torch.cat((x,
                           torch_utils.scale_img(x.flip(3), s[0]),  # flip-lr and scale
                           torch_utils.scale_img(x, s[1]),  # scale
                           ), 0)

        for i, module in enumerate(self.module_list):
            name = module.__class__.__name__
            if name in ['WeightedFeatureFusion', 'FeatureConcat']:  # sum, concat
                if verbose:
                    l = [i - 1] + module.layers  # layers
                    sh = [list(x.shape)] + [list(out[i].shape) for i in module.layers]  # shapes
                    str = ' >> ' + ' + '.join(['layer %g %s' % x for x in zip(l, sh)])
                x = module(x, out)  # WeightedFeatureFusion(), FeatureConcat()
            elif name == 'YOLOLayer':
                yolo_out.append(module(x, out))
            else:  # run module directly, i.e. mtype = 'convolutional', 'upsample', 'maxpool', 'batchnorm2d' etc.
                x = module(x)

            out.append(x if self.routs[i] else [])
            if verbose:
                print('%g/%g %s -' % (i, len(self.module_list), name), list(x.shape), str)
                str = ''

        if self.training:  # train
            return yolo_out
        elif ONNX_EXPORT:  # export
            x = [torch.cat(x, 0) for x in zip(*yolo_out)]
            return x[0], torch.cat(x[1:3], 1)  # scores, boxes: 3780x80, 3780x4
        else:  # inference or test
            x, p = zip(*yolo_out)  # inference output, training output
            x = torch.cat(x, 1)  # cat yolo outputs
            if augment:  # de-augment results
                x = torch.split(x, nb, dim=0)
                x[1][..., :4] /= s[0]  # scale
                x[1][..., 0] = img_size[1] - x[1][..., 0]  # flip lr
                x[2][..., :4] /= s[1]  # scale
                x = torch.cat(x, 1)
            return x, p

    def fuse(self):
        # Fuse Conv2d + BatchNorm2d layers throughout model
        print('Fusing layers...')
        fused_list = nn.ModuleList()
        for a in list(self.children())[0]:
            if isinstance(a, nn.Sequential):
                for i, b in enumerate(a):
                    if isinstance(b, nn.modules.batchnorm.BatchNorm2d):
                        # fuse this bn layer with the previous conv2d layer
                        conv = a[i - 1]
                        fused = torch_utils.fuse_conv_and_bn(conv, b)
                        a = nn.Sequential(fused, *list(a.children())[i + 1:])
                        break
            fused_list.append(a)
        self.module_list = fused_list
        self.info() if not ONNX_EXPORT else None  # yolov3-spp reduced from 225 to 152 layers

    def info(self, verbose=False):
        torch_utils.model_info(self, verbose)


def get_yolo_layers(model):
    return [i for i, m in enumerate(model.module_list) if m.__class__.__name__ == 'YOLOLayer']  # [89, 101, 113]


def load_darknet_weights(self, weights, cutoff=-1):
    # Parses and loads the weights stored in 'weights'

    # Establish cutoffs (load layers between 0 and cutoff. if cutoff = -1 all are loaded)
    file = Path(weights).name
    if file == 'darknet53.conv.74':
        cutoff = 75
    elif file == 'yolov3-tiny.conv.15':
        cutoff = 15

    # Read weights file
    with open(weights, 'rb') as f:
        # Read Header https://github.com/AlexeyAB/darknet/issues/2914#issuecomment-496675346
        self.version = np.fromfile(f, dtype=np.int32, count=3)  # (int32) version info: major, minor, revision
        self.seen = np.fromfile(f, dtype=np.int64, count=1)  # (int64) number of images seen during training

        weights = np.fromfile(f, dtype=np.float32)  # the rest are weights

    ptr = 0
    for i, (mdef, module) in enumerate(zip(self.module_defs[:cutoff], self.module_list[:cutoff])):
        if mdef['type'] == 'convolutional':
            conv = module[0]
            if mdef['batch_normalize']:
                # Load BN bias, weights, running mean and running variance
                bn = module[1]
                nb = bn.bias.numel()  # number of biases
                # Bias
                bn.bias.data.copy_(torch.from_numpy(weights[ptr:ptr + nb]).view_as(bn.bias))
                ptr += nb
                # Weight
                bn.weight.data.copy_(torch.from_numpy(weights[ptr:ptr + nb]).view_as(bn.weight))
                ptr += nb
                # Running Mean
                bn.running_mean.data.copy_(torch.from_numpy(weights[ptr:ptr + nb]).view_as(bn.running_mean))
                ptr += nb
                # Running Var
                bn.running_var.data.copy_(torch.from_numpy(weights[ptr:ptr + nb]).view_as(bn.running_var))
                ptr += nb
            else:
                # Load conv. bias
                nb = conv.bias.numel()
                conv_b = torch.from_numpy(weights[ptr:ptr + nb]).view_as(conv.bias)
                conv.bias.data.copy_(conv_b)
                ptr += nb
            # Load conv. weights
            nw = conv.weight.numel()  # number of weights
            conv.weight.data.copy_(torch.from_numpy(weights[ptr:ptr + nw]).view_as(conv.weight))
            ptr += nw

# %%
imgsz = (320, 512)
imgsz = 320

cfg = 'cfg/yolo-fastest.cfg'
weights = 'weights/best.pt'
device = 'cpu'

# %%
# Initialize model
model = Darknet(cfg, imgsz)

# Load weights
if weights.endswith('.pt'):  # pytorch format
    model.load_state_dict(torch.load(weights, map_location=device)['model'])
else:  # darknet format
    load_darknet_weights(model, weights)
# Out:
# Model Summary: 253 layers, 290066 parameters, 290066 gradients

# %%
model.eval()
# Out:
# Darknet(
#   (module_list): ModuleList(
#     (0): Sequential(
#       (Conv2d): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (1): Sequential(
#       (Conv2d): Conv2d(8, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (2): Sequential(
#       (Conv2d): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (3): Sequential(
#       (Conv2d): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(4, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (4): Sequential(
#       (Conv2d): Conv2d(4, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (5): Sequential(
#       (Conv2d): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (6): Sequential(
#       (Conv2d): Conv2d(8, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(4, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (7): Dropout(p=0.15, inplace=False)
#     (8): WeightedFeatureFusion()
#     (9): Sequential(
#       (Conv2d): Conv2d(4, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (10): Sequential(
#       (Conv2d): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (11): Sequential(
#       (Conv2d): Conv2d(24, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (12): Sequential(
#       (Conv2d): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(32, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (13): Sequential(
#       (Conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (BatchNorm2d): BatchNorm2d(32, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (14): Sequential(
#       (Conv2d): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (15): Dropout(p=0.15, inplace=False)
#     (16): WeightedFeatureFusion()
#     (17): Sequential(
#       (Conv2d): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(32, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (18): Sequential(
#       (Conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (BatchNorm2d): BatchNorm2d(32, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (19): Sequential(
#       (Conv2d): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (20): Dropout(p=0.15, inplace=False)
#     (21): WeightedFeatureFusion()
#     (22): Sequential(
#       (Conv2d): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(32, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (23): Sequential(
#       (Conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (BatchNorm2d): BatchNorm2d(32, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (24): Sequential(
#       (Conv2d): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (25): Sequential(
#       (Conv2d): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (26): Sequential(
#       (Conv2d): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (27): Sequential(
#       (Conv2d): Conv2d(48, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (28): Dropout(p=0.15, inplace=False)
#     (29): WeightedFeatureFusion()
#     (30): Sequential(
#       (Conv2d): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (31): Sequential(
#       (Conv2d): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (32): Sequential(
#       (Conv2d): Conv2d(48, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(8, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (33): Dropout(p=0.15, inplace=False)
#     (34): WeightedFeatureFusion()
#     (35): Sequential(
#       (Conv2d): Conv2d(8, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (36): Sequential(
#       (Conv2d): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (37): Sequential(
#       (Conv2d): Conv2d(48, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(16, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (38): Sequential(
#       (Conv2d): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (39): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (40): Sequential(
#       (Conv2d): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(16, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (41): Dropout(p=0.15, inplace=False)
#     (42): WeightedFeatureFusion()
#     (43): Sequential(
#       (Conv2d): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (44): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (45): Sequential(
#       (Conv2d): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(16, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (46): Dropout(p=0.15, inplace=False)
#     (47): WeightedFeatureFusion()
#     (48): Sequential(
#       (Conv2d): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (49): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (50): Sequential(
#       (Conv2d): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(16, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (51): Dropout(p=0.15, inplace=False)
#     (52): WeightedFeatureFusion()
#     (53): Sequential(
#       (Conv2d): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (54): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (55): Sequential(
#       (Conv2d): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(16, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (56): Dropout(p=0.15, inplace=False)
#     (57): WeightedFeatureFusion()
#     (58): Sequential(
#       (Conv2d): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (59): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (60): Sequential(
#       (Conv2d): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (61): Sequential(
#       (Conv2d): Conv2d(24, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (62): Sequential(
#       (Conv2d): Conv2d(136, 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=136, bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (63): Sequential(
#       (Conv2d): Conv2d(136, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (64): Dropout(p=0.15, inplace=False)
#     (65): WeightedFeatureFusion()
#     (66): Sequential(
#       (Conv2d): Conv2d(24, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (67): Sequential(
#       (Conv2d): Conv2d(136, 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=136, bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (68): Sequential(
#       (Conv2d): Conv2d(136, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (69): Dropout(p=0.15, inplace=False)
#     (70): WeightedFeatureFusion()
#     (71): Sequential(
#       (Conv2d): Conv2d(24, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (72): Sequential(
#       (Conv2d): Conv2d(136, 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=136, bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (73): Sequential(
#       (Conv2d): Conv2d(136, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (74): Dropout(p=0.15, inplace=False)
#     (75): WeightedFeatureFusion()
#     (76): Sequential(
#       (Conv2d): Conv2d(24, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (77): Sequential(
#       (Conv2d): Conv2d(136, 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=136, bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (78): Sequential(
#       (Conv2d): Conv2d(136, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(24, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (79): Dropout(p=0.15, inplace=False)
#     (80): WeightedFeatureFusion()
#     (81): Sequential(
#       (Conv2d): Conv2d(24, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (82): Sequential(
#       (Conv2d): Conv2d(136, 136, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=136, bias=False)
#       (BatchNorm2d): BatchNorm2d(136, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (83): Sequential(
#       (Conv2d): Conv2d(136, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (84): Sequential(
#       (Conv2d): Conv2d(48, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (85): Sequential(
#       (Conv2d): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=224, bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (86): Sequential(
#       (Conv2d): Conv2d(224, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (87): Dropout(p=0.15, inplace=False)
#     (88): WeightedFeatureFusion()
#     (89): Sequential(
#       (Conv2d): Conv2d(48, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (90): Sequential(
#       (Conv2d): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=224, bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (91): Sequential(
#       (Conv2d): Conv2d(224, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (92): Dropout(p=0.15, inplace=False)
#     (93): WeightedFeatureFusion()
#     (94): Sequential(
#       (Conv2d): Conv2d(48, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (95): Sequential(
#       (Conv2d): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=224, bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (96): Sequential(
#       (Conv2d): Conv2d(224, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (97): Dropout(p=0.15, inplace=False)
#     (98): WeightedFeatureFusion()
#     (99): Sequential(
#       (Conv2d): Conv2d(48, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (100): Sequential(
#       (Conv2d): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=224, bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (101): Sequential(
#       (Conv2d): Conv2d(224, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (102): Dropout(p=0.15, inplace=False)
#     (103): WeightedFeatureFusion()
#     (104): Sequential(
#       (Conv2d): Conv2d(48, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (105): Sequential(
#       (Conv2d): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=224, bias=False)
#       (BatchNorm2d): BatchNorm2d(224, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (106): Sequential(
#       (Conv2d): Conv2d(224, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(48, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (107): Dropout(p=0.15, inplace=False)
#     (108): WeightedFeatureFusion()
#     (109): Sequential(
#       (Conv2d): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (110): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (111): Sequential(
#       (Conv2d): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (112): Sequential(
#       (Conv2d): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128, bias=False)
#       (BatchNorm2d): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (113): Sequential(
#       (Conv2d): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(128, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (114): Sequential(
#       (Conv2d): Conv2d(128, 21, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (115): YOLOLayer()
#     (116): FeatureConcat()
#     (117): Upsample(scale_factor=2.0, mode=nearest)
#     (118): FeatureConcat()
#     (119): Sequential(
#       (Conv2d): Conv2d(232, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (120): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (121): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (122): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (123): Sequential(
#       (Conv2d): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (BatchNorm2d): BatchNorm2d(96, eps=0.0001, momentum=0.03, affine=True, track_running_stats=True)
#     )
#     (124): Sequential(
#       (Conv2d): Conv2d(96, 21, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (125): YOLOLayer()
#   )
# )

# %%
batch_size = 1
# Input to the model
x = torch.randn(batch_size, 3, 320, 512, requires_grad=True)
torch_out = model(x)

# %%
# Export the model
torch.onnx.export(model,                     # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "weights/yolo-fastest.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=11,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  verbose=True,
                  input_names = ['images'],   # the model's input names
                  output_names = ['classes','yolo1','yolo2'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable lenght axes
                                'output' : {0 : 'batch_size'}}
                 )
# Out:
# graph(%images : Float(1:491520, 3:163840, 320:512, 512:1),
#       %module_list.0.Conv2d.weight : Float(8:27, 3:9, 3:3, 3:1),
#       %module_list.0.BatchNorm2d.weight : Float(8:1),
#       %module_list.0.BatchNorm2d.bias : Float(8:1),
#       %module_list.0.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.0.BatchNorm2d.running_var : Float(8:1),
#       %module_list.1.Conv2d.weight : Float(8:8, 8:1, 1:1, 1:1),
#       %module_list.1.BatchNorm2d.weight : Float(8:1),
#       %module_list.1.BatchNorm2d.bias : Float(8:1),
#       %module_list.1.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.1.BatchNorm2d.running_var : Float(8:1),
#       %module_list.2.Conv2d.weight : Float(8:9, 1:9, 3:3, 3:1),
#       %module_list.2.BatchNorm2d.weight : Float(8:1),
#       %module_list.2.BatchNorm2d.bias : Float(8:1),
#       %module_list.2.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.2.BatchNorm2d.running_var : Float(8:1),
#       %module_list.3.Conv2d.weight : Float(4:8, 8:1, 1:1, 1:1),
#       %module_list.3.BatchNorm2d.weight : Float(4:1),
#       %module_list.3.BatchNorm2d.bias : Float(4:1),
#       %module_list.3.BatchNorm2d.running_mean : Float(4:1),
#       %module_list.3.BatchNorm2d.running_var : Float(4:1),
#       %module_list.4.Conv2d.weight : Float(8:4, 4:1, 1:1, 1:1),
#       %module_list.4.BatchNorm2d.weight : Float(8:1),
#       %module_list.4.BatchNorm2d.bias : Float(8:1),
#       %module_list.4.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.4.BatchNorm2d.running_var : Float(8:1),
#       %module_list.5.Conv2d.weight : Float(8:9, 1:9, 3:3, 3:1),
#       %module_list.5.BatchNorm2d.weight : Float(8:1),
#       %module_list.5.BatchNorm2d.bias : Float(8:1),
#       %module_list.5.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.5.BatchNorm2d.running_var : Float(8:1),
#       %module_list.6.Conv2d.weight : Float(4:8, 8:1, 1:1, 1:1),
#       %module_list.6.BatchNorm2d.weight : Float(4:1),
#       %module_list.6.BatchNorm2d.bias : Float(4:1),
#       %module_list.6.BatchNorm2d.running_mean : Float(4:1),
#       %module_list.6.BatchNorm2d.running_var : Float(4:1),
#       %module_list.9.Conv2d.weight : Float(24:4, 4:1, 1:1, 1:1),
#       %module_list.9.BatchNorm2d.weight : Float(24:1),
#       %module_list.9.BatchNorm2d.bias : Float(24:1),
#       %module_list.9.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.9.BatchNorm2d.running_var : Float(24:1),
#       %module_list.10.Conv2d.weight : Float(24:9, 1:9, 3:3, 3:1),
#       %module_list.10.BatchNorm2d.weight : Float(24:1),
#       %module_list.10.BatchNorm2d.bias : Float(24:1),
#       %module_list.10.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.10.BatchNorm2d.running_var : Float(24:1),
#       %module_list.11.Conv2d.weight : Float(8:24, 24:1, 1:1, 1:1),
#       %module_list.11.BatchNorm2d.weight : Float(8:1),
#       %module_list.11.BatchNorm2d.bias : Float(8:1),
#       %module_list.11.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.11.BatchNorm2d.running_var : Float(8:1),
#       %module_list.12.Conv2d.weight : Float(32:8, 8:1, 1:1, 1:1),
#       %module_list.12.BatchNorm2d.weight : Float(32:1),
#       %module_list.12.BatchNorm2d.bias : Float(32:1),
#       %module_list.12.BatchNorm2d.running_mean : Float(32:1),
#       %module_list.12.BatchNorm2d.running_var : Float(32:1),
#       %module_list.13.Conv2d.weight : Float(32:9, 1:9, 3:3, 3:1),
#       %module_list.13.BatchNorm2d.weight : Float(32:1),
#       %module_list.13.BatchNorm2d.bias : Float(32:1),
#       %module_list.13.BatchNorm2d.running_mean : Float(32:1),
#       %module_list.13.BatchNorm2d.running_var : Float(32:1),
#       %module_list.14.Conv2d.weight : Float(8:32, 32:1, 1:1, 1:1),
#       %module_list.14.BatchNorm2d.weight : Float(8:1),
#       %module_list.14.BatchNorm2d.bias : Float(8:1),
#       %module_list.14.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.14.BatchNorm2d.running_var : Float(8:1),
#       %module_list.17.Conv2d.weight : Float(32:8, 8:1, 1:1, 1:1),
#       %module_list.17.BatchNorm2d.weight : Float(32:1),
#       %module_list.17.BatchNorm2d.bias : Float(32:1),
#       %module_list.17.BatchNorm2d.running_mean : Float(32:1),
#       %module_list.17.BatchNorm2d.running_var : Float(32:1),
#       %module_list.18.Conv2d.weight : Float(32:9, 1:9, 3:3, 3:1),
#       %module_list.18.BatchNorm2d.weight : Float(32:1),
#       %module_list.18.BatchNorm2d.bias : Float(32:1),
#       %module_list.18.BatchNorm2d.running_mean : Float(32:1),
#       %module_list.18.BatchNorm2d.running_var : Float(32:1),
#       %module_list.19.Conv2d.weight : Float(8:32, 32:1, 1:1, 1:1),
#       %module_list.19.BatchNorm2d.weight : Float(8:1),
#       %module_list.19.BatchNorm2d.bias : Float(8:1),
#       %module_list.19.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.19.BatchNorm2d.running_var : Float(8:1),
#       %module_list.22.Conv2d.weight : Float(32:8, 8:1, 1:1, 1:1),
#       %module_list.22.BatchNorm2d.weight : Float(32:1),
#       %module_list.22.BatchNorm2d.bias : Float(32:1),
#       %module_list.22.BatchNorm2d.running_mean : Float(32:1),
#       %module_list.22.BatchNorm2d.running_var : Float(32:1),
#       %module_list.23.Conv2d.weight : Float(32:9, 1:9, 3:3, 3:1),
#       %module_list.23.BatchNorm2d.weight : Float(32:1),
#       %module_list.23.BatchNorm2d.bias : Float(32:1),
#       %module_list.23.BatchNorm2d.running_mean : Float(32:1),
#       %module_list.23.BatchNorm2d.running_var : Float(32:1),
#       %module_list.24.Conv2d.weight : Float(8:32, 32:1, 1:1, 1:1),
#       %module_list.24.BatchNorm2d.weight : Float(8:1),
#       %module_list.24.BatchNorm2d.bias : Float(8:1),
#       %module_list.24.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.24.BatchNorm2d.running_var : Float(8:1),
#       %module_list.25.Conv2d.weight : Float(48:8, 8:1, 1:1, 1:1),
#       %module_list.25.BatchNorm2d.weight : Float(48:1),
#       %module_list.25.BatchNorm2d.bias : Float(48:1),
#       %module_list.25.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.25.BatchNorm2d.running_var : Float(48:1),
#       %module_list.26.Conv2d.weight : Float(48:9, 1:9, 3:3, 3:1),
#       %module_list.26.BatchNorm2d.weight : Float(48:1),
#       %module_list.26.BatchNorm2d.bias : Float(48:1),
#       %module_list.26.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.26.BatchNorm2d.running_var : Float(48:1),
#       %module_list.27.Conv2d.weight : Float(8:48, 48:1, 1:1, 1:1),
#       %module_list.27.BatchNorm2d.weight : Float(8:1),
#       %module_list.27.BatchNorm2d.bias : Float(8:1),
#       %module_list.27.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.27.BatchNorm2d.running_var : Float(8:1),
#       %module_list.30.Conv2d.weight : Float(48:8, 8:1, 1:1, 1:1),
#       %module_list.30.BatchNorm2d.weight : Float(48:1),
#       %module_list.30.BatchNorm2d.bias : Float(48:1),
#       %module_list.30.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.30.BatchNorm2d.running_var : Float(48:1),
#       %module_list.31.Conv2d.weight : Float(48:9, 1:9, 3:3, 3:1),
#       %module_list.31.BatchNorm2d.weight : Float(48:1),
#       %module_list.31.BatchNorm2d.bias : Float(48:1),
#       %module_list.31.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.31.BatchNorm2d.running_var : Float(48:1),
#       %module_list.32.Conv2d.weight : Float(8:48, 48:1, 1:1, 1:1),
#       %module_list.32.BatchNorm2d.weight : Float(8:1),
#       %module_list.32.BatchNorm2d.bias : Float(8:1),
#       %module_list.32.BatchNorm2d.running_mean : Float(8:1),
#       %module_list.32.BatchNorm2d.running_var : Float(8:1),
#       %module_list.35.Conv2d.weight : Float(48:8, 8:1, 1:1, 1:1),
#       %module_list.35.BatchNorm2d.weight : Float(48:1),
#       %module_list.35.BatchNorm2d.bias : Float(48:1),
#       %module_list.35.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.35.BatchNorm2d.running_var : Float(48:1),
#       %module_list.36.Conv2d.weight : Float(48:9, 1:9, 3:3, 3:1),
#       %module_list.36.BatchNorm2d.weight : Float(48:1),
#       %module_list.36.BatchNorm2d.bias : Float(48:1),
#       %module_list.36.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.36.BatchNorm2d.running_var : Float(48:1),
#       %module_list.37.Conv2d.weight : Float(16:48, 48:1, 1:1, 1:1),
#       %module_list.37.BatchNorm2d.weight : Float(16:1),
#       %module_list.37.BatchNorm2d.bias : Float(16:1),
#       %module_list.37.BatchNorm2d.running_mean : Float(16:1),
#       %module_list.37.BatchNorm2d.running_var : Float(16:1),
#       %module_list.38.Conv2d.weight : Float(96:16, 16:1, 1:1, 1:1),
#       %module_list.38.BatchNorm2d.weight : Float(96:1),
#       %module_list.38.BatchNorm2d.bias : Float(96:1),
#       %module_list.38.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.38.BatchNorm2d.running_var : Float(96:1),
#       %module_list.39.Conv2d.weight : Float(96:9, 1:9, 3:3, 3:1),
#       %module_list.39.BatchNorm2d.weight : Float(96:1),
#       %module_list.39.BatchNorm2d.bias : Float(96:1),
#       %module_list.39.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.39.BatchNorm2d.running_var : Float(96:1),
#       %module_list.40.Conv2d.weight : Float(16:96, 96:1, 1:1, 1:1),
#       %module_list.40.BatchNorm2d.weight : Float(16:1),
#       %module_list.40.BatchNorm2d.bias : Float(16:1),
#       %module_list.40.BatchNorm2d.running_mean : Float(16:1),
#       %module_list.40.BatchNorm2d.running_var : Float(16:1),
#       %module_list.43.Conv2d.weight : Float(96:16, 16:1, 1:1, 1:1),
#       %module_list.43.BatchNorm2d.weight : Float(96:1),
#       %module_list.43.BatchNorm2d.bias : Float(96:1),
#       %module_list.43.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.43.BatchNorm2d.running_var : Float(96:1),
#       %module_list.44.Conv2d.weight : Float(96:9, 1:9, 3:3, 3:1),
#       %module_list.44.BatchNorm2d.weight : Float(96:1),
#       %module_list.44.BatchNorm2d.bias : Float(96:1),
#       %module_list.44.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.44.BatchNorm2d.running_var : Float(96:1),
#       %module_list.45.Conv2d.weight : Float(16:96, 96:1, 1:1, 1:1),
#       %module_list.45.BatchNorm2d.weight : Float(16:1),
#       %module_list.45.BatchNorm2d.bias : Float(16:1),
#       %module_list.45.BatchNorm2d.running_mean : Float(16:1),
#       %module_list.45.BatchNorm2d.running_var : Float(16:1),
#       %module_list.48.Conv2d.weight : Float(96:16, 16:1, 1:1, 1:1),
#       %module_list.48.BatchNorm2d.weight : Float(96:1),
#       %module_list.48.BatchNorm2d.bias : Float(96:1),
#       %module_list.48.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.48.BatchNorm2d.running_var : Float(96:1),
#       %module_list.49.Conv2d.weight : Float(96:9, 1:9, 3:3, 3:1),
#       %module_list.49.BatchNorm2d.weight : Float(96:1),
#       %module_list.49.BatchNorm2d.bias : Float(96:1),
#       %module_list.49.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.49.BatchNorm2d.running_var : Float(96:1),
#       %module_list.50.Conv2d.weight : Float(16:96, 96:1, 1:1, 1:1),
#       %module_list.50.BatchNorm2d.weight : Float(16:1),
#       %module_list.50.BatchNorm2d.bias : Float(16:1),
#       %module_list.50.BatchNorm2d.running_mean : Float(16:1),
#       %module_list.50.BatchNorm2d.running_var : Float(16:1),
#       %module_list.53.Conv2d.weight : Float(96:16, 16:1, 1:1, 1:1),
#       %module_list.53.BatchNorm2d.weight : Float(96:1),
#       %module_list.53.BatchNorm2d.bias : Float(96:1),
#       %module_list.53.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.53.BatchNorm2d.running_var : Float(96:1),
#       %module_list.54.Conv2d.weight : Float(96:9, 1:9, 3:3, 3:1),
#       %module_list.54.BatchNorm2d.weight : Float(96:1),
#       %module_list.54.BatchNorm2d.bias : Float(96:1),
#       %module_list.54.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.54.BatchNorm2d.running_var : Float(96:1),
#       %module_list.55.Conv2d.weight : Float(16:96, 96:1, 1:1, 1:1),
#       %module_list.55.BatchNorm2d.weight : Float(16:1),
#       %module_list.55.BatchNorm2d.bias : Float(16:1),
#       %module_list.55.BatchNorm2d.running_mean : Float(16:1),
#       %module_list.55.BatchNorm2d.running_var : Float(16:1),
#       %module_list.58.Conv2d.weight : Float(96:16, 16:1, 1:1, 1:1),
#       %module_list.58.BatchNorm2d.weight : Float(96:1),
#       %module_list.58.BatchNorm2d.bias : Float(96:1),
#       %module_list.58.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.58.BatchNorm2d.running_var : Float(96:1),
#       %module_list.59.Conv2d.weight : Float(96:9, 1:9, 3:3, 3:1),
#       %module_list.59.BatchNorm2d.weight : Float(96:1),
#       %module_list.59.BatchNorm2d.bias : Float(96:1),
#       %module_list.59.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.59.BatchNorm2d.running_var : Float(96:1),
#       %module_list.60.Conv2d.weight : Float(24:96, 96:1, 1:1, 1:1),
#       %module_list.60.BatchNorm2d.weight : Float(24:1),
#       %module_list.60.BatchNorm2d.bias : Float(24:1),
#       %module_list.60.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.60.BatchNorm2d.running_var : Float(24:1),
#       %module_list.61.Conv2d.weight : Float(136:24, 24:1, 1:1, 1:1),
#       %module_list.61.BatchNorm2d.weight : Float(136:1),
#       %module_list.61.BatchNorm2d.bias : Float(136:1),
#       %module_list.61.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.61.BatchNorm2d.running_var : Float(136:1),
#       %module_list.62.Conv2d.weight : Float(136:9, 1:9, 3:3, 3:1),
#       %module_list.62.BatchNorm2d.weight : Float(136:1),
#       %module_list.62.BatchNorm2d.bias : Float(136:1),
#       %module_list.62.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.62.BatchNorm2d.running_var : Float(136:1),
#       %module_list.63.Conv2d.weight : Float(24:136, 136:1, 1:1, 1:1),
#       %module_list.63.BatchNorm2d.weight : Float(24:1),
#       %module_list.63.BatchNorm2d.bias : Float(24:1),
#       %module_list.63.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.63.BatchNorm2d.running_var : Float(24:1),
#       %module_list.66.Conv2d.weight : Float(136:24, 24:1, 1:1, 1:1),
#       %module_list.66.BatchNorm2d.weight : Float(136:1),
#       %module_list.66.BatchNorm2d.bias : Float(136:1),
#       %module_list.66.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.66.BatchNorm2d.running_var : Float(136:1),
#       %module_list.67.Conv2d.weight : Float(136:9, 1:9, 3:3, 3:1),
#       %module_list.67.BatchNorm2d.weight : Float(136:1),
#       %module_list.67.BatchNorm2d.bias : Float(136:1),
#       %module_list.67.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.67.BatchNorm2d.running_var : Float(136:1),
#       %module_list.68.Conv2d.weight : Float(24:136, 136:1, 1:1, 1:1),
#       %module_list.68.BatchNorm2d.weight : Float(24:1),
#       %module_list.68.BatchNorm2d.bias : Float(24:1),
#       %module_list.68.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.68.BatchNorm2d.running_var : Float(24:1),
#       %module_list.71.Conv2d.weight : Float(136:24, 24:1, 1:1, 1:1),
#       %module_list.71.BatchNorm2d.weight : Float(136:1),
#       %module_list.71.BatchNorm2d.bias : Float(136:1),
#       %module_list.71.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.71.BatchNorm2d.running_var : Float(136:1),
#       %module_list.72.Conv2d.weight : Float(136:9, 1:9, 3:3, 3:1),
#       %module_list.72.BatchNorm2d.weight : Float(136:1),
#       %module_list.72.BatchNorm2d.bias : Float(136:1),
#       %module_list.72.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.72.BatchNorm2d.running_var : Float(136:1),
#       %module_list.73.Conv2d.weight : Float(24:136, 136:1, 1:1, 1:1),
#       %module_list.73.BatchNorm2d.weight : Float(24:1),
#       %module_list.73.BatchNorm2d.bias : Float(24:1),
#       %module_list.73.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.73.BatchNorm2d.running_var : Float(24:1),
#       %module_list.76.Conv2d.weight : Float(136:24, 24:1, 1:1, 1:1),
#       %module_list.76.BatchNorm2d.weight : Float(136:1),
#       %module_list.76.BatchNorm2d.bias : Float(136:1),
#       %module_list.76.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.76.BatchNorm2d.running_var : Float(136:1),
#       %module_list.77.Conv2d.weight : Float(136:9, 1:9, 3:3, 3:1),
#       %module_list.77.BatchNorm2d.weight : Float(136:1),
#       %module_list.77.BatchNorm2d.bias : Float(136:1),
#       %module_list.77.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.77.BatchNorm2d.running_var : Float(136:1),
#       %module_list.78.Conv2d.weight : Float(24:136, 136:1, 1:1, 1:1),
#       %module_list.78.BatchNorm2d.weight : Float(24:1),
#       %module_list.78.BatchNorm2d.bias : Float(24:1),
#       %module_list.78.BatchNorm2d.running_mean : Float(24:1),
#       %module_list.78.BatchNorm2d.running_var : Float(24:1),
#       %module_list.81.Conv2d.weight : Float(136:24, 24:1, 1:1, 1:1),
#       %module_list.81.BatchNorm2d.weight : Float(136:1),
#       %module_list.81.BatchNorm2d.bias : Float(136:1),
#       %module_list.81.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.81.BatchNorm2d.running_var : Float(136:1),
#       %module_list.82.Conv2d.weight : Float(136:9, 1:9, 3:3, 3:1),
#       %module_list.82.BatchNorm2d.weight : Float(136:1),
#       %module_list.82.BatchNorm2d.bias : Float(136:1),
#       %module_list.82.BatchNorm2d.running_mean : Float(136:1),
#       %module_list.82.BatchNorm2d.running_var : Float(136:1),
#       %module_list.83.Conv2d.weight : Float(48:136, 136:1, 1:1, 1:1),
#       %module_list.83.BatchNorm2d.weight : Float(48:1),
#       %module_list.83.BatchNorm2d.bias : Float(48:1),
#       %module_list.83.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.83.BatchNorm2d.running_var : Float(48:1),
#       %module_list.84.Conv2d.weight : Float(224:48, 48:1, 1:1, 1:1),
#       %module_list.84.BatchNorm2d.weight : Float(224:1),
#       %module_list.84.BatchNorm2d.bias : Float(224:1),
#       %module_list.84.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.84.BatchNorm2d.running_var : Float(224:1),
#       %module_list.85.Conv2d.weight : Float(224:9, 1:9, 3:3, 3:1),
#       %module_list.85.BatchNorm2d.weight : Float(224:1),
#       %module_list.85.BatchNorm2d.bias : Float(224:1),
#       %module_list.85.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.85.BatchNorm2d.running_var : Float(224:1),
#       %module_list.86.Conv2d.weight : Float(48:224, 224:1, 1:1, 1:1),
#       %module_list.86.BatchNorm2d.weight : Float(48:1),
#       %module_list.86.BatchNorm2d.bias : Float(48:1),
#       %module_list.86.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.86.BatchNorm2d.running_var : Float(48:1),
#       %module_list.89.Conv2d.weight : Float(224:48, 48:1, 1:1, 1:1),
#       %module_list.89.BatchNorm2d.weight : Float(224:1),
#       %module_list.89.BatchNorm2d.bias : Float(224:1),
#       %module_list.89.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.89.BatchNorm2d.running_var : Float(224:1),
#       %module_list.90.Conv2d.weight : Float(224:9, 1:9, 3:3, 3:1),
#       %module_list.90.BatchNorm2d.weight : Float(224:1),
#       %module_list.90.BatchNorm2d.bias : Float(224:1),
#       %module_list.90.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.90.BatchNorm2d.running_var : Float(224:1),
#       %module_list.91.Conv2d.weight : Float(48:224, 224:1, 1:1, 1:1),
#       %module_list.91.BatchNorm2d.weight : Float(48:1),
#       %module_list.91.BatchNorm2d.bias : Float(48:1),
#       %module_list.91.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.91.BatchNorm2d.running_var : Float(48:1),
#       %module_list.94.Conv2d.weight : Float(224:48, 48:1, 1:1, 1:1),
#       %module_list.94.BatchNorm2d.weight : Float(224:1),
#       %module_list.94.BatchNorm2d.bias : Float(224:1),
#       %module_list.94.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.94.BatchNorm2d.running_var : Float(224:1),
#       %module_list.95.Conv2d.weight : Float(224:9, 1:9, 3:3, 3:1),
#       %module_list.95.BatchNorm2d.weight : Float(224:1),
#       %module_list.95.BatchNorm2d.bias : Float(224:1),
#       %module_list.95.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.95.BatchNorm2d.running_var : Float(224:1),
#       %module_list.96.Conv2d.weight : Float(48:224, 224:1, 1:1, 1:1),
#       %module_list.96.BatchNorm2d.weight : Float(48:1),
#       %module_list.96.BatchNorm2d.bias : Float(48:1),
#       %module_list.96.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.96.BatchNorm2d.running_var : Float(48:1),
#       %module_list.99.Conv2d.weight : Float(224:48, 48:1, 1:1, 1:1),
#       %module_list.99.BatchNorm2d.weight : Float(224:1),
#       %module_list.99.BatchNorm2d.bias : Float(224:1),
#       %module_list.99.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.99.BatchNorm2d.running_var : Float(224:1),
#       %module_list.100.Conv2d.weight : Float(224:9, 1:9, 3:3, 3:1),
#       %module_list.100.BatchNorm2d.weight : Float(224:1),
#       %module_list.100.BatchNorm2d.bias : Float(224:1),
#       %module_list.100.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.100.BatchNorm2d.running_var : Float(224:1),
#       %module_list.101.Conv2d.weight : Float(48:224, 224:1, 1:1, 1:1),
#       %module_list.101.BatchNorm2d.weight : Float(48:1),
#       %module_list.101.BatchNorm2d.bias : Float(48:1),
#       %module_list.101.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.101.BatchNorm2d.running_var : Float(48:1),
#       %module_list.104.Conv2d.weight : Float(224:48, 48:1, 1:1, 1:1),
#       %module_list.104.BatchNorm2d.weight : Float(224:1),
#       %module_list.104.BatchNorm2d.bias : Float(224:1),
#       %module_list.104.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.104.BatchNorm2d.running_var : Float(224:1),
#       %module_list.105.Conv2d.weight : Float(224:9, 1:9, 3:3, 3:1),
#       %module_list.105.BatchNorm2d.weight : Float(224:1),
#       %module_list.105.BatchNorm2d.bias : Float(224:1),
#       %module_list.105.BatchNorm2d.running_mean : Float(224:1),
#       %module_list.105.BatchNorm2d.running_var : Float(224:1),
#       %module_list.106.Conv2d.weight : Float(48:224, 224:1, 1:1, 1:1),
#       %module_list.106.BatchNorm2d.weight : Float(48:1),
#       %module_list.106.BatchNorm2d.bias : Float(48:1),
#       %module_list.106.BatchNorm2d.running_mean : Float(48:1),
#       %module_list.106.BatchNorm2d.running_var : Float(48:1),
#       %module_list.109.Conv2d.weight : Float(96:48, 48:1, 1:1, 1:1),
#       %module_list.109.BatchNorm2d.weight : Float(96:1),
#       %module_list.109.BatchNorm2d.bias : Float(96:1),
#       %module_list.109.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.109.BatchNorm2d.running_var : Float(96:1),
#       %module_list.110.Conv2d.weight : Float(96:25, 1:25, 5:5, 5:1),
#       %module_list.110.BatchNorm2d.weight : Float(96:1),
#       %module_list.110.BatchNorm2d.bias : Float(96:1),
#       %module_list.110.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.110.BatchNorm2d.running_var : Float(96:1),
#       %module_list.111.Conv2d.weight : Float(128:96, 96:1, 1:1, 1:1),
#       %module_list.111.BatchNorm2d.weight : Float(128:1),
#       %module_list.111.BatchNorm2d.bias : Float(128:1),
#       %module_list.111.BatchNorm2d.running_mean : Float(128:1),
#       %module_list.111.BatchNorm2d.running_var : Float(128:1),
#       %module_list.112.Conv2d.weight : Float(128:25, 1:25, 5:5, 5:1),
#       %module_list.112.BatchNorm2d.weight : Float(128:1),
#       %module_list.112.BatchNorm2d.bias : Float(128:1),
#       %module_list.112.BatchNorm2d.running_mean : Float(128:1),
#       %module_list.112.BatchNorm2d.running_var : Float(128:1),
#       %module_list.113.Conv2d.weight : Float(128:128, 128:1, 1:1, 1:1),
#       %module_list.113.BatchNorm2d.weight : Float(128:1),
#       %module_list.113.BatchNorm2d.bias : Float(128:1),
#       %module_list.113.BatchNorm2d.running_mean : Float(128:1),
#       %module_list.113.BatchNorm2d.running_var : Float(128:1),
#       %module_list.114.Conv2d.weight : Float(21:128, 128:1, 1:1, 1:1),
#       %module_list.114.Conv2d.bias : Float(21:1),
#       %module_list.119.Conv2d.weight : Float(96:232, 232:1, 1:1, 1:1),
#       %module_list.119.BatchNorm2d.weight : Float(96:1),
#       %module_list.119.BatchNorm2d.bias : Float(96:1),
#       %module_list.119.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.119.BatchNorm2d.running_var : Float(96:1),
#       %module_list.120.Conv2d.weight : Float(96:25, 1:25, 5:5, 5:1),
#       %module_list.120.BatchNorm2d.weight : Float(96:1),
#       %module_list.120.BatchNorm2d.bias : Float(96:1),
#       %module_list.120.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.120.BatchNorm2d.running_var : Float(96:1),
#       %module_list.121.Conv2d.weight : Float(96:96, 96:1, 1:1, 1:1),
#       %module_list.121.BatchNorm2d.weight : Float(96:1),
#       %module_list.121.BatchNorm2d.bias : Float(96:1),
#       %module_list.121.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.121.BatchNorm2d.running_var : Float(96:1),
#       %module_list.122.Conv2d.weight : Float(96:25, 1:25, 5:5, 5:1),
#       %module_list.122.BatchNorm2d.weight : Float(96:1),
#       %module_list.122.BatchNorm2d.bias : Float(96:1),
#       %module_list.122.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.122.BatchNorm2d.running_var : Float(96:1),
#       %module_list.123.Conv2d.weight : Float(96:96, 96:1, 1:1, 1:1),
#       %module_list.123.BatchNorm2d.weight : Float(96:1),
#       %module_list.123.BatchNorm2d.bias : Float(96:1),
#       %module_list.123.BatchNorm2d.running_mean : Float(96:1),
#       %module_list.123.BatchNorm2d.running_var : Float(96:1),
#       %module_list.124.Conv2d.weight : Float(21:96, 96:1, 1:1, 1:1),
#       %module_list.124.Conv2d.bias : Float(21:1),
#       %1536 : Long(1:1),
#       %1537 : Long(1:1),
#       %1538 : Long(1:1),
#       %1539 : Long(1:1),
#       %1540 : Long(1:1),
#       %1541 : Long(1:1),
#       %1542 : Long(1:1),
#       %1543 : Long(1:1),
#       %1544 : Long(1:1),
#       %1549 : Float(4:1),
#       %1550 : Long(1:1),
#       %1551 : Long(1:1),
#       %1552 : Long(1:1),
#       %1553 : Long(1:1),
#       %1554 : Long(1:1),
#       %1555 : Long(1:1),
#       %1556 : Long(1:1),
#       %1557 : Long(1:1),
#       %1558 : Long(1:1)):
#   %503 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%images, %module_list.0.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %504 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%503, %module_list.0.BatchNorm2d.weight, %module_list.0.BatchNorm2d.bias, %module_list.0.BatchNorm2d.running_mean, %module_list.0.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %505 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%504) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %506 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%505, %module_list.1.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %507 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%506, %module_list.1.BatchNorm2d.weight, %module_list.1.BatchNorm2d.bias, %module_list.1.BatchNorm2d.running_mean, %module_list.1.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %508 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%507) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %509 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=8, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%508, %module_list.2.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %510 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%509, %module_list.2.BatchNorm2d.weight, %module_list.2.BatchNorm2d.bias, %module_list.2.BatchNorm2d.running_mean, %module_list.2.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %511 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%510) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %512 : Float(1:163840, 4:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%511, %module_list.3.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %513 : Float(1:163840, 4:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%512, %module_list.3.BatchNorm2d.weight, %module_list.3.BatchNorm2d.bias, %module_list.3.BatchNorm2d.running_mean, %module_list.3.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %514 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%513, %module_list.4.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %515 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%514, %module_list.4.BatchNorm2d.weight, %module_list.4.BatchNorm2d.bias, %module_list.4.BatchNorm2d.running_mean, %module_list.4.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %516 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%515) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %517 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=8, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%516, %module_list.5.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %518 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%517, %module_list.5.BatchNorm2d.weight, %module_list.5.BatchNorm2d.bias, %module_list.5.BatchNorm2d.running_mean, %module_list.5.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %519 : Float(1:327680, 8:40960, 160:256, 256:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%518) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %520 : Float(1:163840, 4:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%519, %module_list.6.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %521 : Float(1:163840, 4:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%520, %module_list.6.BatchNorm2d.weight, %module_list.6.BatchNorm2d.bias, %module_list.6.BatchNorm2d.running_mean, %module_list.6.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:973:0
#   %522 : Float(1:163840, 4:40960, 160:256, 256:1) = onnx::Add(%521, %513) # /Users/waittim/Google 云端硬盘/Mask-detection/mask-detector/modeling/utils/layers.py:61:0
#   %523 : Float(1:983040, 24:40960, 160:256, 256:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%522, %module_list.9.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %524 : Float(1:983040, 24:40960, 160:256, 256:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%523, %module_list.9.BatchNorm2d.weight, %module_list.9.BatchNorm2d.bias, %module_list.9.BatchNorm2d.running_mean, %module_list.9.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %525 : Float(1:983040, 24:40960, 160:256, 256:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%524) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %526 : Float(1:245760, 24:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=24, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%525, %module_list.10.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %527 : Float(1:245760, 24:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%526, %module_list.10.BatchNorm2d.weight, %module_list.10.BatchNorm2d.bias, %module_list.10.BatchNorm2d.running_mean, %module_list.10.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %528 : Float(1:245760, 24:10240, 80:128, 128:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%527) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %529 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%528, %module_list.11.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %530 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%529, %module_list.11.BatchNorm2d.weight, %module_list.11.BatchNorm2d.bias, %module_list.11.BatchNorm2d.running_mean, %module_list.11.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %531 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%530, %module_list.12.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %532 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%531, %module_list.12.BatchNorm2d.weight, %module_list.12.BatchNorm2d.bias, %module_list.12.BatchNorm2d.running_mean, %module_list.12.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %533 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%532) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %534 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%533, %module_list.13.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %535 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%534, %module_list.13.BatchNorm2d.weight, %module_list.13.BatchNorm2d.bias, %module_list.13.BatchNorm2d.running_mean, %module_list.13.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %536 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%535) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %537 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%536, %module_list.14.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %538 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%537, %module_list.14.BatchNorm2d.weight, %module_list.14.BatchNorm2d.bias, %module_list.14.BatchNorm2d.running_mean, %module_list.14.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:973:0
#   %539 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::Add(%538, %530) # /Users/waittim/Google 云端硬盘/Mask-detection/mask-detector/modeling/utils/layers.py:61:0
#   %540 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%539, %module_list.17.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %541 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%540, %module_list.17.BatchNorm2d.weight, %module_list.17.BatchNorm2d.bias, %module_list.17.BatchNorm2d.running_mean, %module_list.17.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %542 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%541) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %543 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%542, %module_list.18.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %544 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%543, %module_list.18.BatchNorm2d.weight, %module_list.18.BatchNorm2d.bias, %module_list.18.BatchNorm2d.running_mean, %module_list.18.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %545 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%544) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %546 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%545, %module_list.19.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %547 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%546, %module_list.19.BatchNorm2d.weight, %module_list.19.BatchNorm2d.bias, %module_list.19.BatchNorm2d.running_mean, %module_list.19.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:973:0
#   %548 : Float(1:81920, 8:10240, 80:128, 128:1) = onnx::Add(%547, %539) # /Users/waittim/Google 云端硬盘/Mask-detection/mask-detector/modeling/utils/layers.py:61:0
#   %549 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%548, %module_list.22.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %550 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%549, %module_list.22.BatchNorm2d.weight, %module_list.22.BatchNorm2d.bias, %module_list.22.BatchNorm2d.running_mean, %module_list.22.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %551 : Float(1:327680, 32:10240, 80:128, 128:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%550) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %552 : Float(1:81920, 32:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%551, %module_list.23.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %553 : Float(1:81920, 32:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%552, %module_list.23.BatchNorm2d.weight, %module_list.23.BatchNorm2d.bias, %module_list.23.BatchNorm2d.running_mean, %module_list.23.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %554 : Float(1:81920, 32:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%553) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %555 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%554, %module_list.24.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %556 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%555, %module_list.24.BatchNorm2d.weight, %module_list.24.BatchNorm2d.bias, %module_list.24.BatchNorm2d.running_mean, %module_list.24.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %557 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%556, %module_list.25.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %558 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%557, %module_list.25.BatchNorm2d.weight, %module_list.25.BatchNorm2d.bias, %module_list.25.BatchNorm2d.running_mean, %module_list.25.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %559 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%558) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %560 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=48, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%559, %module_list.26.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %561 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%560, %module_list.26.BatchNorm2d.weight, %module_list.26.BatchNorm2d.bias, %module_list.26.BatchNorm2d.running_mean, %module_list.26.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %562 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%561) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %563 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%562, %module_list.27.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %564 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%563, %module_list.27.BatchNorm2d.weight, %module_list.27.BatchNorm2d.bias, %module_list.27.BatchNorm2d.running_mean, %module_list.27.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:973:0
#   %565 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::Add(%564, %556) # /Users/waittim/Google 云端硬盘/Mask-detection/mask-detector/modeling/utils/layers.py:61:0
#   %566 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%565, %module_list.30.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %567 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%566, %module_list.30.BatchNorm2d.weight, %module_list.30.BatchNorm2d.bias, %module_list.30.BatchNorm2d.running_mean, %module_list.30.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %568 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%567) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %569 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=48, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%568, %module_list.31.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %570 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%569, %module_list.31.BatchNorm2d.weight, %module_list.31.BatchNorm2d.bias, %module_list.31.BatchNorm2d.running_mean, %module_list.31.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %571 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%570) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %572 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%571, %module_list.32.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %573 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%572, %module_list.32.BatchNorm2d.weight, %module_list.32.BatchNorm2d.bias, %module_list.32.BatchNorm2d.running_mean, %module_list.32.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:973:0
#   %574 : Float(1:20480, 8:2560, 40:64, 64:1) = onnx::Add(%573, %565) # /Users/waittim/Google 云端硬盘/Mask-detection/mask-detector/modeling/utils/layers.py:61:0
#   %575 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%574, %module_list.35.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %576 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%575, %module_list.35.BatchNorm2d.weight, %module_list.35.BatchNorm2d.bias, %module_list.35.BatchNorm2d.running_mean, %module_list.35.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %577 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%576) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %578 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=48, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%577, %module_list.36.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %579 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%578, %module_list.36.BatchNorm2d.weight, %module_list.36.BatchNorm2d.bias, %module_list.36.BatchNorm2d.running_mean, %module_list.36.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
#   %580 : Float(1:122880, 48:2560, 40:64, 64:1) = onnx::LeakyRelu[alpha=0.10000000000000001](%579) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1293:0
#   %581 : Float(1:40960, 16:2560, 40:64, 64:1) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%580, %module_list.37.Conv2d.weight) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py:416:0
#   %582 : Float(1:40960, 16:2560, 40:64, 64:1) = onnx::BatchNormalization[epsilon=0.0001, momentum=0.96999999999999997](%581, %module_list.37.BatchNorm2d.weight, %module_list.37.BatchNorm2d.bias, %module_list.37.BatchNorm2d.running_mean, %module_list.37.BatchNorm2d.running_var) # /Users/waittim/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:2016:0
# ...
#   %1229 : Tensor = onnx::Add(%1220, %1222)
#   %1230 : Tensor = onnx::Add(%1229, %1224)
#   %1231 : Tensor = onnx::Add(%1230, %1226)
#   %1232 : Tensor = onnx::Add(%1231, %1228)
#   %1233 : Tensor = onnx::Shape(%1232)
#   %1234 : Tensor = onnx::Shape(%1233)
#   %1235 : Tensor = onnx::ConstantOfShape[value={1}](%1234)
#   %1236 : Long() = onnx::Constant[value={-1}]()
#   %1237 : LongTensor = onnx::Mul(%1235, %1236)
#   %1238 : Tensor = onnx::Equal(%1233, %1237)
#   %1239 : Tensor = onnx::Where(%1238, %1235, %1233)
#   %1240 : Tensor = onnx::Expand(%1220, %1239)
#   %1241 : Tensor = onnx::Unsqueeze[axes=[-1]](%1240)
#   %1242 : Tensor = onnx::Shape(%1233)
#   %1243 : Tensor = onnx::ConstantOfShape[value={1}](%1242)
#   %1244 : Long() = onnx::Constant[value={-1}]()
#   %1245 : LongTensor = onnx::Mul(%1243, %1244)
#   %1246 : Tensor = onnx::Equal(%1233, %1245)
#   %1247 : Tensor = onnx::Where(%1246, %1243, %1233)
#   %1248 : Tensor = onnx::Expand(%1222, %1247)
#   %1249 : Tensor = onnx::Unsqueeze[axes=[-1]](%1248)
#   %1250 : Tensor = onnx::Shape(%1233)
#   %1251 : Tensor = onnx::ConstantOfShape[value={1}](%1250)
#   %1252 : Long() = onnx::Constant[value={-1}]()
#   %1253 : LongTensor = onnx::Mul(%1251, %1252)
#   %1254 : Tensor = onnx::Equal(%1233, %1253)
#   %1255 : Tensor = onnx::Where(%1254, %1251, %1233)
#   %1256 : Tensor = onnx::Expand(%1224, %1255)
#   %1257 : Tensor = onnx::Unsqueeze[axes=[-1]](%1256)
#   %1258 : Tensor = onnx::Shape(%1233)
#   %1259 : Tensor = onnx::ConstantOfShape[value={1}](%1258)
#   %1260 : Long() = onnx::Constant[value={-1}]()
#   %1261 : LongTensor = onnx::Mul(%1259, %1260)
#   %1262 : Tensor = onnx::Equal(%1233, %1261)
#   %1263 : Tensor = onnx::Where(%1262, %1259, %1233)
#   %1264 : Tensor = onnx::Expand(%1226, %1263)
#   %1265 : Tensor = onnx::Unsqueeze[axes=[-1]](%1264)
#   %1266 : Tensor = onnx::Shape(%1233)
#   %1267 : Tensor = onnx::ConstantOfShape[value={1}](%1266)
#   %1268 : Long() = onnx::Constant[value={-1}]()
#   %1269 : LongTensor = onnx::Mul(%1267, %1268)
#   %1270 : Tensor = onnx::Equal(%1233, %1269)
#   %1271 : Tensor = onnx::Where(%1270, %1267, %1233)
#   %1272 : Tensor = onnx::Expand(%1228, %1271)
#   %1273 : Tensor = onnx::Unsqueeze[axes=[-1]](%1272)
#   %1274 : Tensor = onnx::Concat[axis=-1](%1241, %1249, %1257, %1265, %1273)
#   %1275 : Tensor = onnx::Shape(%yolo2)
#   %1276 : Tensor = onnx::Constant[value={0}]()
#   %1277 : Tensor = onnx::Constant[value={5}]()
#   %1278 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %1279 : Tensor = onnx::Slice(%1275, %1277, %1278, %1276)
#   %1280 : Tensor = onnx::Concat[axis=0](%1233, %1279)
#   %1281 : Tensor = onnx::Reshape(%1178, %1280)
#   %1282 : Float(1:13440, 3:4480, 20:224, 32:7, 2:1) = onnx::ScatterND(%yolo2, %1274, %1281)
#   %1283 : Tensor = onnx::Constant[value={4}]()
#   %1284 : Tensor = onnx::Constant[value={2}]()
#   %1285 : Tensor = onnx::Constant[value={4}]()
#   %1286 : Tensor = onnx::Constant[value={1}]()
#   %1287 : Float(1:13440, 3:4480, 20:224, 32:7, 2:1) = onnx::Slice(%1282, %1284, %1285, %1283, %1286) # <ipython-input-6-cc76a8bf4ad5>:221:0
#   %1288 : Float(1:3840, 3:1280, 20:64, 32:2, 2:1) = onnx::Exp(%1287) # <ipython-input-6-cc76a8bf4ad5>:221:0
#   %1289 : Float(1:6, 3:2, 1:2, 1:2, 2:1) = onnx::Constant[value=(1,1,1,.,.) =    0.7500  1.1250  (1,2,1,.,.) =    2.3125  3.0625  (1,3,1,.,.) =    3.2500  8.2500 [ CPUFloatType{1,3,1,1,2} ]]()
#   %1290 : Float(1:3840, 3:1280, 20:64, 32:2, 2:1) = onnx::Mul(%1288, %1289) # <ipython-input-6-cc76a8bf4ad5>:221:0
#   %1291 : Tensor = onnx::Constant[value=  3  20  32   2 [ CPULongType{4} ]]()
#   %1292 : Float(3:1280, 20:64, 32:2, 2:1) = onnx::Reshape(%1290, %1291) # <ipython-input-6-cc76a8bf4ad5>:221:0
#   %1293 : Tensor = onnx::Constant[value=  1   3  20  32   2 [ CPULongType{5} ]]()
#   %1295 : Tensor = onnx::ConstantOfShape[value={1}](%1555)
#   %1296 : Long() = onnx::Constant[value={-1}]()
#   %1297 : LongTensor = onnx::Mul(%1295, %1296)
#   %1298 : Long(5:1) = onnx::Constant[value=  1   3  20  32   2 [ CPULongType{5} ]]()
#   %1299 : Tensor = onnx::Equal(%1298, %1297)
#   %1300 : Tensor = onnx::Where(%1299, %1295, %1293)
#   %1301 : Float(1:3840, 3:1280, 20:64, 32:2, 2:1) = onnx::Expand(%1292, %1300) # <ipython-input-6-cc76a8bf4ad5>:221:0
#   %1302 : Tensor = onnx::Shape(%1282)
#   %1303 : Tensor = onnx::Constant[value={0}]()
#   %1304 : Long() = onnx::Gather[axis=0](%1302, %1303)
#   %1305 : Tensor = onnx::Cast[to=7](%1304)
#   %1306 : Tensor = onnx::Constant[value={0}]()
#   %1307 : Tensor = onnx::Constant[value={1}]()
#   %1308 : Tensor = onnx::Range(%1306, %1305, %1307)
#   %1309 : Tensor = onnx::Shape(%1282)
#   %1310 : Tensor = onnx::Constant[value={1}]()
#   %1311 : Long() = onnx::Gather[axis=0](%1309, %1310)
#   %1312 : Tensor = onnx::Cast[to=7](%1311)
#   %1313 : Tensor = onnx::Constant[value={0}]()
#   %1314 : Tensor = onnx::Constant[value={1}]()
#   %1315 : Tensor = onnx::Range(%1313, %1312, %1314)
#   %1316 : Tensor = onnx::Shape(%1282)
#   %1317 : Tensor = onnx::Constant[value={2}]()
#   %1318 : Long() = onnx::Gather[axis=0](%1316, %1317)
#   %1319 : Tensor = onnx::Cast[to=7](%1318)
#   %1320 : Tensor = onnx::Constant[value={0}]()
#   %1321 : Tensor = onnx::Constant[value={1}]()
#   %1322 : Tensor = onnx::Range(%1320, %1319, %1321)
#   %1323 : Tensor = onnx::Shape(%1282)
#   %1324 : Tensor = onnx::Constant[value={3}]()
#   %1325 : Long() = onnx::Gather[axis=0](%1323, %1324)
#   %1326 : Tensor = onnx::Cast[to=7](%1325)
#   %1327 : Tensor = onnx::Constant[value={0}]()
#   %1328 : Tensor = onnx::Constant[value={1}]()
#   %1329 : Tensor = onnx::Range(%1327, %1326, %1328)
#   %1330 : Tensor = onnx::Shape(%1282)
#   %1331 : Tensor = onnx::Constant[value={4}]()
#   %1332 : Long() = onnx::Gather[axis=0](%1330, %1331)
#   %1333 : Tensor = onnx::Cast[to=7](%1332)
#   %1334 : Tensor = onnx::Constant[value={0}]()
#   %1335 : Tensor = onnx::Constant[value={1}]()
#   %1336 : Tensor = onnx::Range(%1334, %1333, %1335)
#   %1337 : Tensor = onnx::Constant[value={0}]()
#   %1338 : Tensor = onnx::Constant[value={2}]()
#   %1339 : Tensor = onnx::Constant[value={4}]()
#   %1340 : Tensor = onnx::Constant[value={1}]()
#   %1341 : Tensor = onnx::Slice(%1336, %1338, %1339, %1337, %1340)
#   %1342 : Tensor = onnx::Constant[value=-1  1  1  1  1 [ CPULongType{5} ]]()
#   %1343 : Tensor = onnx::Reshape(%1308, %1342)
#   %1344 : Tensor = onnx::Constant[value=-1  1  1  1 [ CPULongType{4} ]]()
#   %1345 : Tensor = onnx::Reshape(%1315, %1344)
#   %1346 : Tensor = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %1347 : Tensor = onnx::Reshape(%1322, %1346)
#   %1348 : Tensor = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %1349 : Tensor = onnx::Reshape(%1329, %1348)
#   %1350 : Tensor = onnx::Constant[value={-1}]()
#   %1351 : Tensor = onnx::Reshape(%1341, %1350)
#   %1352 : Tensor = onnx::Add(%1343, %1345)
#   %1353 : Tensor = onnx::Add(%1352, %1347)
#   %1354 : Tensor = onnx::Add(%1353, %1349)
#   %1355 : Tensor = onnx::Add(%1354, %1351)
#   %1356 : Tensor = onnx::Shape(%1355)
#   %1357 : Tensor = onnx::Shape(%1356)
#   %1358 : Tensor = onnx::ConstantOfShape[value={1}](%1357)
#   %1359 : Long() = onnx::Constant[value={-1}]()
#   %1360 : LongTensor = onnx::Mul(%1358, %1359)
#   %1361 : Tensor = onnx::Equal(%1356, %1360)
#   %1362 : Tensor = onnx::Where(%1361, %1358, %1356)
#   %1363 : Tensor = onnx::Expand(%1343, %1362)
#   %1364 : Tensor = onnx::Unsqueeze[axes=[-1]](%1363)
#   %1365 : Tensor = onnx::Shape(%1356)
#   %1366 : Tensor = onnx::ConstantOfShape[value={1}](%1365)
#   %1367 : Long() = onnx::Constant[value={-1}]()
#   %1368 : LongTensor = onnx::Mul(%1366, %1367)
#   %1369 : Tensor = onnx::Equal(%1356, %1368)
#   %1370 : Tensor = onnx::Where(%1369, %1366, %1356)
#   %1371 : Tensor = onnx::Expand(%1345, %1370)
#   %1372 : Tensor = onnx::Unsqueeze[axes=[-1]](%1371)
#   %1373 : Tensor = onnx::Shape(%1356)
#   %1374 : Tensor = onnx::ConstantOfShape[value={1}](%1373)
#   %1375 : Long() = onnx::Constant[value={-1}]()
#   %1376 : LongTensor = onnx::Mul(%1374, %1375)
#   %1377 : Tensor = onnx::Equal(%1356, %1376)
#   %1378 : Tensor = onnx::Where(%1377, %1374, %1356)
#   %1379 : Tensor = onnx::Expand(%1347, %1378)
#   %1380 : Tensor = onnx::Unsqueeze[axes=[-1]](%1379)
#   %1381 : Tensor = onnx::Shape(%1356)
#   %1382 : Tensor = onnx::ConstantOfShape[value={1}](%1381)
#   %1383 : Long() = onnx::Constant[value={-1}]()
#   %1384 : LongTensor = onnx::Mul(%1382, %1383)
#   %1385 : Tensor = onnx::Equal(%1356, %1384)
#   %1386 : Tensor = onnx::Where(%1385, %1382, %1356)
#   %1387 : Tensor = onnx::Expand(%1349, %1386)
#   %1388 : Tensor = onnx::Unsqueeze[axes=[-1]](%1387)
#   %1389 : Tensor = onnx::Shape(%1356)
#   %1390 : Tensor = onnx::ConstantOfShape[value={1}](%1389)
#   %1391 : Long() = onnx::Constant[value={-1}]()
#   %1392 : LongTensor = onnx::Mul(%1390, %1391)
#   %1393 : Tensor = onnx::Equal(%1356, %1392)
#   %1394 : Tensor = onnx::Where(%1393, %1390, %1356)
#   %1395 : Tensor = onnx::Expand(%1351, %1394)
#   %1396 : Tensor = onnx::Unsqueeze[axes=[-1]](%1395)
#   %1397 : Tensor = onnx::Concat[axis=-1](%1364, %1372, %1380, %1388, %1396)
#   %1398 : Tensor = onnx::Shape(%1282)
#   %1399 : Tensor = onnx::Constant[value={0}]()
#   %1400 : Tensor = onnx::Constant[value={5}]()
#   %1401 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %1402 : Tensor = onnx::Slice(%1398, %1400, %1401, %1399)
#   %1403 : Tensor = onnx::Concat[axis=0](%1356, %1402)
#   %1404 : Tensor = onnx::Reshape(%1301, %1403)
#   %1405 : Float(1:13440, 3:4480, 20:224, 32:7, 2:1) = onnx::ScatterND(%1282, %1397, %1404)
#   %1406 : Tensor = onnx::Constant[value={4}]()
#   %1407 : Tensor = onnx::Constant[value={0}]()
#   %1408 : Tensor = onnx::Constant[value={4}]()
#   %1409 : Tensor = onnx::Constant[value={1}]()
#   %1410 : Float(1:13440, 3:4480, 20:224, 32:7, 4:1) = onnx::Slice(%1405, %1407, %1408, %1406, %1409) # <ipython-input-6-cc76a8bf4ad5>:222:0
#   %1411 : Float() = onnx::Constant[value={16}]()
#   %1412 : Float(1:13440, 3:4480, 20:224, 32:7, 4:1) = onnx::Mul(%1410, %1411)
#   %1413 : Tensor = onnx::Constant[value=  3  20  32   4 [ CPULongType{4} ]]()
#   %1414 : Float(3:4480, 20:224, 32:7, 4:1) = onnx::Reshape(%1412, %1413) # <ipython-input-6-cc76a8bf4ad5>:222:0
#   %1415 : Tensor = onnx::Constant[value=  1   3  20  32   4 [ CPULongType{5} ]]()
#   %1417 : Tensor = onnx::ConstantOfShape[value={1}](%1556)
#   %1418 : Long() = onnx::Constant[value={-1}]()
#   %1419 : LongTensor = onnx::Mul(%1417, %1418)
#   %1420 : Long(5:1) = onnx::Constant[value=  1   3  20  32   4 [ CPULongType{5} ]]()
#   %1421 : Tensor = onnx::Equal(%1420, %1419)
#   %1422 : Tensor = onnx::Where(%1421, %1417, %1415)
#   %1423 : Float(1:13440, 3:4480, 20:224, 32:7, 4:1) = onnx::Expand(%1414, %1422) # <ipython-input-6-cc76a8bf4ad5>:222:0
#   %1424 : Tensor = onnx::Shape(%1405)
#   %1425 : Tensor = onnx::Constant[value={0}]()
#   %1426 : Long() = onnx::Gather[axis=0](%1424, %1425)
#   %1427 : Tensor = onnx::Cast[to=7](%1426)
#   %1428 : Tensor = onnx::Constant[value={0}]()
#   %1429 : Tensor = onnx::Constant[value={1}]()
#   %1430 : Tensor = onnx::Range(%1428, %1427, %1429)
#   %1431 : Tensor = onnx::Shape(%1405)
#   %1432 : Tensor = onnx::Constant[value={1}]()
#   %1433 : Long() = onnx::Gather[axis=0](%1431, %1432)
#   %1434 : Tensor = onnx::Cast[to=7](%1433)
#   %1435 : Tensor = onnx::Constant[value={0}]()
#   %1436 : Tensor = onnx::Constant[value={1}]()
#   %1437 : Tensor = onnx::Range(%1435, %1434, %1436)
#   %1438 : Tensor = onnx::Shape(%1405)
#   %1439 : Tensor = onnx::Constant[value={2}]()
#   %1440 : Long() = onnx::Gather[axis=0](%1438, %1439)
#   %1441 : Tensor = onnx::Cast[to=7](%1440)
#   %1442 : Tensor = onnx::Constant[value={0}]()
#   %1443 : Tensor = onnx::Constant[value={1}]()
#   %1444 : Tensor = onnx::Range(%1442, %1441, %1443)
#   %1445 : Tensor = onnx::Shape(%1405)
#   %1446 : Tensor = onnx::Constant[value={3}]()
#   %1447 : Long() = onnx::Gather[axis=0](%1445, %1446)
#   %1448 : Tensor = onnx::Cast[to=7](%1447)
#   %1449 : Tensor = onnx::Constant[value={0}]()
#   %1450 : Tensor = onnx::Constant[value={1}]()
#   %1451 : Tensor = onnx::Range(%1449, %1448, %1450)
#   %1452 : Tensor = onnx::Shape(%1405)
#   %1453 : Tensor = onnx::Constant[value={4}]()
#   %1454 : Long() = onnx::Gather[axis=0](%1452, %1453)
#   %1455 : Tensor = onnx::Cast[to=7](%1454)
#   %1456 : Tensor = onnx::Constant[value={0}]()
#   %1457 : Tensor = onnx::Constant[value={1}]()
#   %1458 : Tensor = onnx::Range(%1456, %1455, %1457)
#   %1459 : Tensor = onnx::Constant[value={0}]()
#   %1460 : Tensor = onnx::Constant[value={0}]()
#   %1461 : Tensor = onnx::Constant[value={4}]()
#   %1462 : Tensor = onnx::Constant[value={1}]()
#   %1463 : Tensor = onnx::Slice(%1458, %1460, %1461, %1459, %1462)
#   %1464 : Tensor = onnx::Constant[value=-1  1  1  1  1 [ CPULongType{5} ]]()
#   %1465 : Tensor = onnx::Reshape(%1430, %1464)
#   %1466 : Tensor = onnx::Constant[value=-1  1  1  1 [ CPULongType{4} ]]()
#   %1467 : Tensor = onnx::Reshape(%1437, %1466)
#   %1468 : Tensor = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %1469 : Tensor = onnx::Reshape(%1444, %1468)
#   %1470 : Tensor = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %1471 : Tensor = onnx::Reshape(%1451, %1470)
#   %1472 : Tensor = onnx::Constant[value={-1}]()
#   %1473 : Tensor = onnx::Reshape(%1463, %1472)
#   %1474 : Tensor = onnx::Add(%1465, %1467)
#   %1475 : Tensor = onnx::Add(%1474, %1469)
#   %1476 : Tensor = onnx::Add(%1475, %1471)
#   %1477 : Tensor = onnx::Add(%1476, %1473)
#   %1478 : Tensor = onnx::Shape(%1477)
#   %1479 : Tensor = onnx::Shape(%1478)
#   %1480 : Tensor = onnx::ConstantOfShape[value={1}](%1479)
#   %1481 : Long() = onnx::Constant[value={-1}]()
#   %1482 : LongTensor = onnx::Mul(%1480, %1481)
#   %1483 : Tensor = onnx::Equal(%1478, %1482)
#   %1484 : Tensor = onnx::Where(%1483, %1480, %1478)
#   %1485 : Tensor = onnx::Expand(%1465, %1484)
#   %1486 : Tensor = onnx::Unsqueeze[axes=[-1]](%1485)
#   %1487 : Tensor = onnx::Shape(%1478)
#   %1488 : Tensor = onnx::ConstantOfShape[value={1}](%1487)
#   %1489 : Long() = onnx::Constant[value={-1}]()
#   %1490 : LongTensor = onnx::Mul(%1488, %1489)
#   %1491 : Tensor = onnx::Equal(%1478, %1490)
#   %1492 : Tensor = onnx::Where(%1491, %1488, %1478)
#   %1493 : Tensor = onnx::Expand(%1467, %1492)
#   %1494 : Tensor = onnx::Unsqueeze[axes=[-1]](%1493)
#   %1495 : Tensor = onnx::Shape(%1478)
#   %1496 : Tensor = onnx::ConstantOfShape[value={1}](%1495)
#   %1497 : Long() = onnx::Constant[value={-1}]()
#   %1498 : LongTensor = onnx::Mul(%1496, %1497)
#   %1499 : Tensor = onnx::Equal(%1478, %1498)
#   %1500 : Tensor = onnx::Where(%1499, %1496, %1478)
#   %1501 : Tensor = onnx::Expand(%1469, %1500)
#   %1502 : Tensor = onnx::Unsqueeze[axes=[-1]](%1501)
#   %1503 : Tensor = onnx::Shape(%1478)
#   %1504 : Tensor = onnx::ConstantOfShape[value={1}](%1503)
#   %1505 : Long() = onnx::Constant[value={-1}]()
#   %1506 : LongTensor = onnx::Mul(%1504, %1505)
#   %1507 : Tensor = onnx::Equal(%1478, %1506)
#   %1508 : Tensor = onnx::Where(%1507, %1504, %1478)
#   %1509 : Tensor = onnx::Expand(%1471, %1508)
#   %1510 : Tensor = onnx::Unsqueeze[axes=[-1]](%1509)
#   %1511 : Tensor = onnx::Shape(%1478)
#   %1512 : Tensor = onnx::ConstantOfShape[value={1}](%1511)
#   %1513 : Long() = onnx::Constant[value={-1}]()
#   %1514 : LongTensor = onnx::Mul(%1512, %1513)
#   %1515 : Tensor = onnx::Equal(%1478, %1514)
#   %1516 : Tensor = onnx::Where(%1515, %1512, %1478)
#   %1517 : Tensor = onnx::Expand(%1473, %1516)
#   %1518 : Tensor = onnx::Unsqueeze[axes=[-1]](%1517)
#   %1519 : Tensor = onnx::Concat[axis=-1](%1486, %1494, %1502, %1510, %1518)
#   %1520 : Tensor = onnx::Shape(%1405)
#   %1521 : Tensor = onnx::Constant[value={0}]()
#   %1522 : Tensor = onnx::Constant[value={5}]()
#   %1523 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %1524 : Tensor = onnx::Slice(%1520, %1522, %1523, %1521)
#   %1525 : Tensor = onnx::Concat[axis=0](%1478, %1524)
#   %1526 : Tensor = onnx::Reshape(%1423, %1525)
#   %1527 : Float(1:13440, 3:4480, 20:224, 32:7, 4:1) = onnx::ScatterND(%1405, %1519, %1526)
#   %1530 : Tensor = onnx::Unsqueeze[axes=[0]](%1147)
#   %1533 : Tensor = onnx::Concat[axis=0](%1530, %1557, %1558)
#   %1534 : Float(1:13440, 1920:7, 7:1) = onnx::Reshape(%1527, %1533) # <ipython-input-6-cc76a8bf4ad5>:224:0
#   %classes : Float(1:16800, 2400:7, 7:1) = onnx::Concat[axis=1](%1119, %1534) # <ipython-input-6-cc76a8bf4ad5>:314:0
#   return (%classes, %yolo1, %yolo2)

# %%
import onnx

onnx_model = onnx.load("weights/yolo-fastest.onnx")

# %%
onnx.checker.check_model(onnx_model)  # Check that the IR is well formed
# Out:
# = <Scalar Tensor []>]()
#   %1029 = Range(%1027, %1026, %1028)
#   %1030 = Shape(%990)
#   %1031 = Constant[value = <Scalar Tensor []>]()
#   %1032 = Gather[axis = 0](%1030, %1031)
#   %1033 = Cast[to = 7](%1032)
#   %1034 = Constant[value = <Scalar Tensor []>]()
#   %1035 = Constant[value = <Scalar Tensor []>]()
#   %1036 = Range(%1034, %1033, %1035)
#   %1037 = Shape(%990)
#   %1038 = Constant[value = <Scalar Tensor []>]()
#   %1039 = Gather[axis = 0](%1037, %1038)
#   %1040 = Cast[to = 7](%1039)
#   %1041 = Constant[value = <Scalar Tensor []>]()
#   %1042 = Constant[value = <Scalar Tensor []>]()
#   %1043 = Range(%1041, %1040, %1042)
#   %1044 = Constant[value = <Tensor>]()
#   %1045 = Constant[value = <Tensor>]()
#   %1046 = Constant[value = <Tensor>]()
#   %1047 = Constant[value = <Tensor>]()
#   %1048 = Slice(%1043, %1045, %1046, %1044, %1047)
#   %1049 = Constant[value = <Tensor>]()
#   %1050 = Reshape(%1015, %1049)
#   %1051 = Constant[value = <Tensor>]()
#   %1052 = Reshape(%1022, %1051)
#   %1053 = Constant[value = <Tensor>]()
#   %1054 = Reshape(%1029, %1053)
#   %1055 = Constant[value = <Tensor>]()
#   %1056 = Reshape(%1036, %1055)
#   %1057 = Constant[value = <Tensor>]()
#   %1058 = Reshape(%1048, %1057)
#   %1059 = Add(%1050, %1052)
#   %1060 = Add(%1059, %1054)
#   %1061 = Add(%1060, %1056)
#   %1062 = Add(%1061, %1058)
#   %1063 = Shape(%1062)
#   %1064 = Shape(%1063)
#   %1065 = ConstantOfShape[value = <Tensor>](%1064)
#   %1066 = Constant[value = <Scalar Tensor []>]()
#   %1067 = Mul(%1065, %1066)
#   %1068 = Equal(%1063, %1067)
#   %1069 = Where(%1068, %1065, %1063)
#   %1070 = Expand(%1050, %1069)
#   %1071 = Unsqueeze[axes = [-1]](%1070)
#   %1072 = Shape(%1063)
#   %1073 = ConstantOfShape[value = <Tensor>](%1072)
#   %1074 = Constant[value = <Scalar Tensor []>]()
#   %1075 = Mul(%1073, %1074)
#   %1076 = Equal(%1063, %1075)
#   %1077 = Where(%1076, %1073, %1063)
#   %1078 = Expand(%1052, %1077)
#   %1079 = Unsqueeze[axes = [-1]](%1078)
#   %1080 = Shape(%1063)
#   %1081 = ConstantOfShape[value = <Tensor>](%1080)
#   %1082 = Constant[value = <Scalar Tensor []>]()
#   %1083 = Mul(%1081, %1082)
#   %1084 = Equal(%1063, %1083)
#   %1085 = Where(%1084, %1081, %1063)
#   %1086 = Expand(%1054, %1085)
#   %1087 = Unsqueeze[axes = [-1]](%1086)
#   %1088 = Shape(%1063)
#   %1089 = ConstantOfShape[value = <Tensor>](%1088)
#   %1090 = Constant[value = <Scalar Tensor []>]()
#   %1091 = Mul(%1089, %1090)
#   %1092 = Equal(%1063, %1091)
#   %1093 = Where(%1092, %1089, %1063)
#   %1094 = Expand(%1056, %1093)
#   %1095 = Unsqueeze[axes = [-1]](%1094)
#   %1096 = Shape(%1063)
#   %1097 = ConstantOfShape[value = <Tensor>](%1096)
#   %1098 = Constant[value = <Scalar Tensor []>]()
#   %1099 = Mul(%1097, %1098)
#   %1100 = Equal(%1063, %1099)
#   %1101 = Where(%1100, %1097, %1063)
#   %1102 = Expand(%1058, %1101)
#   %1103 = Unsqueeze[axes = [-1]](%1102)
#   %1104 = Concat[axis = -1](%1071, %1079, %1087, %1095, %1103)
#   %1105 = Shape(%990)
#   %1106 = Constant[value = <Tensor>]()
#   %1107 = Constant[value = <Tensor>]()
#   %1108 = Constant[value = <Tensor>]()
#   %1109 = Slice(%1105, %1107, %1108, %1106)
#   %1110 = Concat[axis = 0](%1063, %1109)
#   %1111 = Reshape(%1008, %1110)
#   %1112 = ScatterND(%990, %1104, %1111)
#   %1115 = Unsqueeze[axes = [0]](%732)
#   %1118 = Concat[axis = 0](%1115, %1543, %1544)
#   %1119 = Reshape(%1112, %1118)
#   %1128 = Constant[value = <Tensor>]()
#   %1129 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%718, %1128, %1549)
#   %1130 = Concat[axis = 1](%1129, %665)
#   %1131 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1130, %module_list.119.Conv2d.weight)
#   %1132 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1131, %module_list.119.BatchNorm2d.weight, %module_list.119.BatchNorm2d.bias, %module_list.119.BatchNorm2d.running_mean, %module_list.119.BatchNorm2d.running_var)
#   %1133 = LeakyRelu[alpha = 0.100000001490116](%1132)
#   %1134 = Conv[dilations = [1, 1], group = 96, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%1133, %module_list.120.Conv2d.weight)
#   %1135 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1134, %module_list.120.BatchNorm2d.weight, %module_list.120.BatchNorm2d.bias, %module_list.120.BatchNorm2d.running_mean, %module_list.120.BatchNorm2d.running_var)
#   %1136 = LeakyRelu[alpha = 0.100000001490116](%1135)
#   %1137 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1136, %module_list.121.Conv2d.weight)
#   %1138 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1137, %module_list.121.BatchNorm2d.weight, %module_list.121.BatchNorm2d.bias, %module_list.121.BatchNorm2d.running_mean, %module_list.121.BatchNorm2d.running_var)
#   %1139 = Conv[dilations = [1, 1], group = 96, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%1138, %module_list.122.Conv2d.weight)
#   %1140 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1139, %module_list.122.BatchNorm2d.weight, %module_list.122.BatchNorm2d.bias, %module_list.122.BatchNorm2d.running_mean, %module_list.122.BatchNorm2d.running_var)
#   %1141 = LeakyRelu[alpha = 0.100000001490116](%1140)
#   %1142 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1141, %module_list.123.Conv2d.weight)
#   %1143 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1142, %module_list.123.BatchNorm2d.weight, %module_list.123.BatchNorm2d.bias, %module_list.123.BatchNorm2d.running_mean, %module_list.123.BatchNorm2d.running_var)
#   %1144 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1143, %module_list.124.Conv2d.weight, %module_list.124.Conv2d.bias)
#   %1145 = Shape(%1144)
#   %1146 = Constant[value = <Scalar Tensor []>]()
#   %1147 = Gather[axis = 0](%1145, %1146)
#   %1152 = Unsqueeze[axes = [0]](%1147)
#   %1157 = Concat[axis = 0](%1152, %1550, %1551, %1552, %1553)
#   %1158 = Reshape(%1144, %1157)
#   %yolo2 = Transpose[perm = [0, 1, 3, 4, 2]](%1158)
#   %1160 = Constant[value = <Tensor>]()
#   %1161 = Constant[value = <Tensor>]()
#   %1162 = Constant[value = <Tensor>]()
#   %1163 = Constant[value = <Tensor>]()
#   %1164 = Slice(%yolo2, %1161, %1162, %1160, %1163)
#   %1165 = Sigmoid(%1164)
#   %1166 = Constant[value = <Tensor>]()
#   %1167 = Add(%1165, %1166)
#   %1168 = Constant[value = <Tensor>]()
#   %1169 = Reshape(%1167, %1168)
#   %1170 = Constant[value = <Tensor>]()
#   %1172 = ConstantOfShape[value = <Tensor>](%1554)
#   %1173 = Constant[value = <Scalar Tensor []>]()
#   %1174 = Mul(%1172, %1173)
#   %1175 = Constant[value = <Tensor>]()
#   %1176 = Equal(%1175, %1174)
#   %1177 = Where(%1176, %1172, %1170)
#   %1178 = Expand(%1169, %1177)
#   %1179 = Shape(%yolo2)
#   %1180 = Constant[value = <Scalar Tensor []>]()
#   %1181 = Gather[axis = 0](%1179, %1180)
#   %1182 = Cast[to = 7](%1181)
#   %1183 = Constant[value = <Scalar Tensor []>]()
#   %1184 = Constant[value = <Scalar Tensor []>]()
#   %1185 = Range(%1183, %1182, %1184)
#   %1186 = Shape(%yolo2)
#   %1187 = Constant[value = <Scalar Tensor []>]()
#   %1188 = Gather[axis = 0](%1186, %1187)
#   %1189 = Cast[to = 7](%1188)
#   %1190 = Constant[value = <Scalar Tensor []>]()
#   %1191 = Constant[value = <Scalar Tensor []>]()
#   %1192 = Range(%1190, %1189, %1191)
#   %1193 = Shape(%yolo2)
#   %1194 = Constant[value = <Scalar Tensor []>]()
#   %1195 = Gather[axis = 0](%1193, %1194)
#   %1196 = Cast[to = 7](%1195)
#   %1197 = Constant[value = <Scalar Tensor []>]()
#   %1198 = Constant[value = <Scalar Tensor []>]()
#   %1199 = Range(%1197, %1196, %1198)
#   %1200 = Shape(%yolo2)
#   %1201 = Constant[value = <Scalar Tensor []>]()
#   %1202 = Gather[axis = 0](%1200, %1201)
#   %1203 = Cast[to = 7](%1202)
#   %1204 = Constant[value = <Scalar Tensor []>]()
#   %1205 = Constant[value = <Scalar Tensor []>]()
#   %1206 = Range(%1204, %1203, %1205)
#   %1207 = Shape(%yolo2)
#   %1208 = Constant[value = <Scalar Tensor []>]()
#   %1209 = Gather[axis = 0](%1207, %1208)
#   %1210 = Cast[to = 7](%1209)
#   %1211 = Constant[value = <Scalar Tensor []>]()
#   %1212 = Constant[value = <Scalar Tensor []>]()
#   %1213 = Range(%1211, %1210, %1212)
#   %1214 = Constant[value = <Tensor>]()
#   %1215 = Constant[value = <Tensor>]()
#   %1216 = Constant[value = <Tensor>]()
#   %1217 = Constant[value = <Tensor>]()
#   %1218 = Slice(%1213, %1215, %1216, %1214, %1217)
#   %1219 = Constant[value = <Tensor>]()
#   %1220 = Reshape(%1185, %1219)
#   %1221 = Constant[value = <Tensor>]()
#   %1222 = Reshape(%1192, %1221)
#   %1223 = Constant[value = <Tensor>]()
#   %1224 = Reshape(%1199, %1223)
#   %1225 = Constant[value = <Tensor>]()
#   %1226 = Reshape(%1206, %1225)
#   %1227 = Constant[value = <Tensor>]()
#   %1228 = Reshape(%1218, %1227)
#   %1229 = Add(%1220, %1222)
#   %1230 = Add(%1229, %1224)
#   %1231 = Add(%1230, %1226)
#   %1232 = Add(%1231, %1228)
#   %1233 = Shape(%1232)
#   %1234 = Shape(%1233)
#   %1235 = ConstantOfShape[value = <Tensor>](%1234)
#   %1236 = Constant[value = <Scalar Tensor []>]()
#   %1237 = Mul(%1235, %1236)
#   %1238 = Equal(%1233, %1237)
#   %1239 = Where(%1238, %1235, %1233)
#   %1240 = Expand(%1220, %1239)
#   %1241 = Unsqueeze[axes = [-1]](%1240)
#   %1242 = Shape(%1233)
#   %1243 = ConstantOfShape[value = <Tensor>](%1242)
#   %1244 = Constant[value = <Scalar Tensor []>]()
#   %1245 = Mul(%1243, %1244)
#   %1246 = Equal(%1233, %1245)
#   %1247 = Where(%1246, %1243, %1233)
#   %1248 = Expand(%1222, %1247)
#   %1249 = Unsqueeze[axes = [-1]](%1248)
#   %1250 = Shape(%1233)
#   %1251 = ConstantOfShape[value = <Tensor>](%1250)
#   %1252 = Constant[value = <Scalar Tensor []>]()
#   %1253 = Mul(%1251, %1252)
#   %1254 = Equal(%1233, %1253)
#   %1255 = Where(%1254, %1251, %1233)
#   %1256 = Expand(%1224, %1255)
#   %1257 = Unsqueeze[axes = [-1]](%1256)
#   %1258 = Shape(%1233)
#   %1259 = ConstantOfShape[value = <Tensor>](%1258)
#   %1260 = Constant[value = <Scalar Tensor []>]()
#   %1261 = Mul(%1259, %1260)
#   %1262 = Equal(%1233, %1261)
#   %1263 = Where(%1262, %1259, %1233)
#   %1264 = Expand(%1226, %1263)
#   %1265 = Unsqueeze[axes = [-1]](%1264)
#   %1266 = Shape(%1233)
#   %1267 = ConstantOfShape[value = <Tensor>](%1266)
#   %1268 = Constant[value = <Scalar Tensor []>]()
#   %1269 = Mul(%1267, %1268)
#   %1270 = Equal(%1233, %1269)
#   %1271 = Where(%1270, %1267, %1233)
#   %1272 = Expand(%1228, %1271)
#   %1273 = Unsqueeze[axes = [-1]](%1272)
#   %1274 = Concat[axis = -1](%1241, %1249, %1257, %1265, %1273)
#   %1275 = Shape(%yolo2)
#   %1276 = Constant[value = <Tensor>]()
#   %1277 = Constant[value = <Tensor>]()
#   %1278 = Constant[value = <Tensor>]()
#   %1279 = Slice(%1275, %1277, %1278, %1276)
#   %1280 = Concat[axis = 0](%1233, %1279)
#   %1281 = Reshape(%1178, %1280)
#   %1282 = ScatterND(%yolo2, %1274, %1281)
#   %1283 = Constant[value = <Tensor>]()
#   %1284 = Constant[value = <Tensor>]()
#   %1285 = Constant[value = <Tensor>]()
#   %1286 = Constant[value = <Tensor>]()
#   %1287 = Slice(%1282, %1284, %1285, %1283, %1286)
#   %1288 = Exp(%1287)
#   %1289 = Constant[value = <Tensor>]()
#   %1290 = Mul(%1288, %1289)
#   %1291 = Constant[value = <Tensor>]()
#   %1292 = Reshape(%1290, %1291)
#   %1293 = Constant[value = <Tensor>]()
#   %1295 = ConstantOfShape[value = <Tensor>](%1555)
#   %1296 = Constant[value = <Scalar Tensor []>]()
#   %1297 = Mul(%1295, %1296)
#   %1298 = Constant[value = <Tensor>]()
#   %1299 = Equal(%1298, %1297)
#   %1300 = Where(%1299, %1295, %1293)
#   %1301 = Expand(%1292, %1300)
#   %1302 = Shape(%1282)
#   %1303 = Constant[value = <Scalar Tensor []>]()
#   %1304 = Gather[axis = 0](%1302, %1303)
#   %1305 = Cast[to = 7](%1304)
#   %1306 = Constant[value = <Scalar Tensor []>]()
#   %1307 = Constant[value = <Scalar Tensor []>]()
#   %1308 = Range(%1306, %1305, %1307)
#   %1309 = Shape(%1282)
#   %1310 = Constant[value = <Scalar Tensor []>]()
#   %1311 = Gather[axis = 0](%1309, %1310)
#   %1312 = Cast[to = 7](%1311)
#   %1313 = Constant[value = <Scalar Tensor []>]()
#   %1314 = Constant[value = <Scalar Tensor []>]()
#   %1315 = Range(%1313, %1312, %1314)
#   %1316 = Shape(%1282)
#   %1317 = Constant[value = <Scalar Tensor []>]()
#   %1318 = Gather[axis = 0](%1316, %1317)
#   %1319 = Cast[to = 7](%1318)
#   %1320 = Constant[value = <Scalar Tensor []>]()
#   %1321 = Constant[value = <Scalar Tensor []>]()
#   %1322 = Range(%1320, %1319, %1321)
#   %1323 = Shape(%1282)
#   %1324 = Constant[value = <Scalar Tensor []>]()
#   %1325 = Gather[axis = 0](%1323, %1324)
#   %1326 = Cast[to = 7](%1325)
#   %1327 = Constant[value = <Scalar Tensor []>]()
#   %1328 = Constant[value = <Scalar Tensor []>]()
#   %1329 = Range(%1327, %1326, %1328)
#   %1330 = Shape(%1282)
#   %1331 = Constant[value = <Scalar Tensor []>]()
#   %1332 = Gather[axis = 0](%1330, %1331)
#   %1333 = Cast[to = 7](%1332)
#   %1334 = Constant[value = <Scalar Tensor []>]()
#   %1335 = Constant[value = <Scalar Tensor []>]()
#   %1336 = Range(%1334, %1333, %1335)
#   %1337 = Constant[value = <Tensor>]()
#   %1338 = Constant[value = <Tensor>]()
#   %1339 = Constant[value = <Tensor>]()
#   %1340 = Constant[value = <Tensor>]()
#   %1341 = Slice(%1336, %1338, %1339, %1337, %1340)
#   %1342 = Constant[value = <Tensor>]()
#   %1343 = Reshape(%1308, %1342)
#   %1344 = Constant[value = <Tensor>]()
#   %1345 = Reshape(%1315, %1344)
#   %1346 = Constant[value = <Tensor>]()
#   %1347 = Reshape(%1322, %1346)
#   %1348 = Constant[value = <Tensor>]()
#   %1349 = Reshape(%1329, %1348)
#   %1350 = Constant[value = <Tensor>]()
#   %1351 = Reshape(%1341, %1350)
#   %1352 = Add(%1343, %1345)
#   %1353 = Add(%1352, %1347)
#   %1354 = Add(%1353, %1349)
#   %1355 = Add(%1354, %1351)
#   %1356 = Shape(%1355)
#   %1357 = Shape(%1356)
#   %1358 = ConstantOfShape[value = <Tensor>](%1357)
#   %1359 = Constant[value = <Scalar Tensor []>]()
#   %1360 = Mul(%1358, %1359)
#   %1361 = Equal(%1356, %1360)
#   %1362 = Where(%1361, %1358, %1356)
#   %1363 = Expand(%1343, %1362)
#   %1364 = Unsqueeze[axes = [-1]](%1363)
#   %1365 = Shape(%1356)
#   %1366 = ConstantOfShape[value = <Tensor>](%1365)
#   %1367 = Constant[value = <Scalar Tensor []>]()
#   %1368 = Mul(%1366, %1367)
#   %1369 = Equal(%1356, %1368)
#   %1370 = Where(%1369, %1366, %1356)
#   %1371 = Expand(%1345, %1370)
#   %1372 = Unsqueeze[axes = [-1]](%1371)
#   %1373 = Shape(%1356)
#   %1374 = ConstantOfShape[value = <Tensor>](%1373)
#   %1375 = Constant[value = <Scalar Tensor []>]()
#   %1376 = Mul(%1374, %1375)
#   %1377 = Equal(%1356, %1376)
#   %1378 = Where(%1377, %1374, %1356)
#   %1379 = Expand(%1347, %1378)
#   %1380 = Unsqueeze[axes = [-1]](%1379)
#   %1381 = Shape(%1356)
#   %1382 = ConstantOfShape[value = <Tensor>](%1381)
#   %1383 = Constant[value = <Scalar Tensor []>]()
#   %1384 = Mul(%1382, %1383)
#   %1385 = Equal(%1356, %1384)
#   %1386 = Where(%1385, %1382, %1356)
#   %1387 = Expand(%1349, %1386)
#   %1388 = Unsqueeze[axes = [-1]](%1387)
#   %1389 = Shape(%1356)
#   %1390 = ConstantOfShape[value = <Tensor>](%1389)
#   %1391 = Constant[value = <Scalar Tensor []>]()
#   %1392 = Mul(%1390, %1391)
#   %1393 = Equal(%1356, %1392)
#   %1394 = Where(%1393, %1390, %1356)
#   %1395 = Expand(%1351, %1394)
#   %1396 = Unsqueeze[axes = [-1]](%1395)
#   %1397 = Concat[axis = -1](%1364, %1372, %1380, %1388, %1396)
#   %1398 = Shape(%1282)
#   %1399 = Constant[value = <Tensor>]()
#   %1400 = Constant[value = <Tensor>]()
#   %1401 = Constant[value = <Tensor>]()
#   %1402 = Slice(%1398, %1400, %1401, %1399)
#   %1403 = Concat[axis = 0](%1356, %1402)
#   %1404 = Reshape(%1301, %1403)
#   %1405 = ScatterND(%1282, %1397, %1404)
#   %1406 = Constant[value = <Tensor>]()
#   %1407 = Constant[value = <Tensor>]()
#   %1408 = Constant[value = <Tensor>]()
#   %1409 = Constant[value = <Tensor>]()
#   %1410 = Slice(%1405, %1407, %1408, %1406, %1409)
#   %1411 = Constant[value = <Scalar Tensor []>]()
#   %1412 = Mul(%1410, %1411)
#   %1413 = Constant[value = <Tensor>]()
#   %1414 = Reshape(%1412, %1413)
#   %1415 = Constant[value = <Tensor>]()
#   %1417 = ConstantOfShape[value = <Tensor>](%1556)
#   %1418 = Constant[value = <Scalar Tensor []>]()
#   %1419 = Mul(%1417, %1418)
#   %1420 = Constant[value = <Tensor>]()
#   %1421 = Equal(%1420, %1419)
#   %1422 = Where(%1421, %1417, %1415)
#   %1423 = Expand(%1414, %1422)
#   %1424 = Shape(%1405)
#   %1425 = Constant[value = <Scalar Tensor []>]()
#   %1426 = Gather[axis = 0](%1424, %1425)
#   %1427 = Cast[to = 7](%1426)
#   %1428 = Constant[value = <Scalar Tensor []>]()
#   %1429 = Constant[value = <Scalar Tensor []>]()
#   %1430 = Range(%1428, %1427, %1429)
#   %1431 = Shape(%1405)
#   %1432 = Constant[value = <Scalar Tensor []>]()
#   %1433 = Gather[axis = 0](%1431, %1432)
#   %1434 = Cast[to = 7](%1433)
#   %1435 = Constant[value = <Scalar Tensor []>]()
#   %1436 = Constant[value = <Scalar Tensor []>]()
#   %1437 = Range(%1435, %1434, %1436)
#   %1438 = Shape(%1405)
#   %1439 = Constant[value = <Scalar Tensor []>]()
#   %1440 = Gather[axis = 0](%1438, %1439)
#   %1441 = Cast[to = 7](%1440)
#   %1442 = Constant[value = <Scalar Tensor []>]()
#   %1443 = Constant[value = <Scalar Tensor []>]()
#   %1444 = Range(%1442, %1441, %1443)
#   %1445 = Shape(%1405)
#   %1446 = Constant[value = <Scalar Tensor []>]()
#   %1447 = Gather[axis = 0](%1445, %1446)
#   %1448 = Cast[to = 7](%1447)
#   %1449 = Constant[value = <Scalar Tensor []>]()
#   %1450 = Constant[value = <Scalar Tensor []>]()
#   %1451 = Range(%1449, %1448, %1450)
#   %1452 = Shape(%1405)
#   %1453 = Constant[value = <Scalar Tensor []>]()
#   %1454 = Gather[axis = 0](%1452, %1453)
#   %1455 = Cast[to = 7](%1454)
#   %1456 = Constant[value = <Scalar Tensor []>]()
#   %1457 = Constant[value = <Scalar Tensor []>]()
#   %1458 = Range(%1456, %1455, %1457)
#   %1459 = Constant[value = <Tensor>]()
#   %1460 = Constant[value = <Tensor>]()
#   %1461 = Constant[value = <Tensor>]()
#   %1462 = Constant[value = <Tensor>]()
#   %1463 = Slice(%1458, %1460, %1461, %1459, %1462)
#   %1464 = Constant[value = <Tensor>]()
#   %1465 = Reshape(%1430, %1464)
#   %1466 = Constant[value = <Tensor>]()
#   %1467 = Reshape(%1437, %1466)
#   %1468 = Constant[value = <Tensor>]()
#   %1469 = Reshape(%1444, %1468)
#   %1470 = Constant[value = <Tensor>]()
#   %1471 = Reshape(%1451, %1470)
#   %1472 = Constant[value = <Tensor>]()
#   %1473 = Reshape(%1463, %1472)
#   %1474 = Add(%1465, %1467)
#   %1475 = Add(%1474, %1469)
#   %1476 = Add(%1475, %1471)
#   %1477 = Add(%1476, %1473)
#   %1478 = Shape(%1477)
#   %1479 = Shape(%1478)
#   %1480 = ConstantOfShape[value = <Tensor>](%1479)
#   %1481 = Constant[value = <Scalar Tensor []>]()
#   %1482 = Mul(%1480, %1481)
#   %1483 = Equal(%1478, %1482)
#   %1484 = Where(%1483, %1480, %1478)
#   %1485 = Expand(%1465, %1484)
#   %1486 = Unsqueeze[axes = [-1]](%1485)
#   %1487 = Shape(%1478)
#   %1488 = ConstantOfShape[value = <Tensor>](%1487)
#   %1489 = Constant[value = <Scalar Tensor []>]()
#   %1490 = Mul(%1488, %1489)
#   %1491 = Equal(%1478, %1490)
#   %1492 = Where(%1491, %1488, %1478)
#   %1493 = Expand(%1467, %1492)
#   %1494 = Unsqueeze[axes = [-1]](%1493)
#   %1495 = Shape(%1478)
#   %1496 = ConstantOfShape[value = <Tensor>](%1495)
#   %1497 = Constant[value = <Scalar Tensor []>]()
#   %1498 = Mul(%1496, %1497)
#   %1499 = Equal(%1478, %1498)
#   %1500 = Where(%1499, %1496, %1478)
#   %1501 = Expand(%1469, %1500)
#   %1502 = Unsqueeze[axes = [-1]](%1501)
#   %1503 = Shape(%1478)
#   %1504 = ConstantOfShape[value = <Tensor>](%1503)
#   %1505 = Constant[value = <Scalar Tensor []>]()
#   %1506 = Mul(%1504, %1505)
#   %1507 = Equal(%1478, %1506)
#   %1508 = Where(%1507, %1504, %1478)
#   %1509 = Expand(%1471, %1508)
#   %1510 = Unsqueeze[axes = [-1]](%1509)
#   %1511 = Shape(%1478)
#   %1512 = ConstantOfShape[value = <Tensor>](%1511)
#   %1513 = Constant[value = <Scalar Tensor []>]()
#   %1514 = Mul(%1512, %1513)
#   %1515 = Equal(%1478, %1514)
#   %1516 = Where(%1515, %1512, %1478)
#   %1517 = Expand(%1473, %1516)
#   %1518 = Unsqueeze[axes = [-1]](%1517)
#   %1519 = Concat[axis = -1](%1486, %1494, %1502, %1510, %1518)
#   %1520 = Shape(%1405)
#   %1521 = Constant[value = <Tensor>]()
#   %1522 = Constant[value = <Tensor>]()
#   %1523 = Constant[value = <Tensor>]()
#   %1524 = Slice(%1520, %1522, %1523, %1521)
#   %1525 = Concat[axis = 0](%1478, %1524)
#   %1526 = Reshape(%1423, %1525)
#   %1527 = ScatterND(%1405, %1519, %1526)
#   %1530 = Unsqueeze[axes = [0]](%1147)
#   %1533 = Concat[axis = 0](%1530, %1557, %1558)
#   %1534 = Reshape(%1527, %1533)
#   %classes = Concat[axis = 1](%1119, %1534)
#   return %classes, %yolo1, %yolo2
# }

# %%
print(onnx.helper.printable_graph(onnx_model.graph))  # Print a human readable representation of the graph
# Out:
# graph torch-jit-export (
#   %images[FLOAT, 1x3x320x512]
# ) initializers (
#   %1536[INT64, 1]
#   %1537[INT64, 1]
#   %1538[INT64, 1]
#   %1539[INT64, 1]
#   %1540[INT64, 1]
#   %1541[INT64, 1]
#   %1542[INT64, 1]
#   %1543[INT64, 1]
#   %1544[INT64, 1]
#   %1549[FLOAT, 4]
#   %1550[INT64, 1]
#   %1551[INT64, 1]
#   %1552[INT64, 1]
#   %1553[INT64, 1]
#   %1554[INT64, 1]
#   %1555[INT64, 1]
#   %1556[INT64, 1]
#   %1557[INT64, 1]
#   %1558[INT64, 1]
#   %module_list.0.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.0.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.0.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.0.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.0.Conv2d.weight[FLOAT, 8x3x3x3]
#   %module_list.1.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.1.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.1.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.1.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.1.Conv2d.weight[FLOAT, 8x8x1x1]
#   %module_list.10.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.10.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.10.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.10.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.10.Conv2d.weight[FLOAT, 24x1x3x3]
#   %module_list.100.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.100.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.100.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.100.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.100.Conv2d.weight[FLOAT, 224x1x3x3]
#   %module_list.101.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.101.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.101.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.101.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.101.Conv2d.weight[FLOAT, 48x224x1x1]
#   %module_list.104.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.104.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.104.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.104.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.104.Conv2d.weight[FLOAT, 224x48x1x1]
#   %module_list.105.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.105.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.105.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.105.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.105.Conv2d.weight[FLOAT, 224x1x3x3]
#   %module_list.106.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.106.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.106.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.106.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.106.Conv2d.weight[FLOAT, 48x224x1x1]
#   %module_list.109.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.109.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.109.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.109.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.109.Conv2d.weight[FLOAT, 96x48x1x1]
#   %module_list.11.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.11.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.11.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.11.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.11.Conv2d.weight[FLOAT, 8x24x1x1]
#   %module_list.110.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.110.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.110.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.110.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.110.Conv2d.weight[FLOAT, 96x1x5x5]
#   %module_list.111.BatchNorm2d.bias[FLOAT, 128]
#   %module_list.111.BatchNorm2d.running_mean[FLOAT, 128]
#   %module_list.111.BatchNorm2d.running_var[FLOAT, 128]
#   %module_list.111.BatchNorm2d.weight[FLOAT, 128]
#   %module_list.111.Conv2d.weight[FLOAT, 128x96x1x1]
#   %module_list.112.BatchNorm2d.bias[FLOAT, 128]
#   %module_list.112.BatchNorm2d.running_mean[FLOAT, 128]
#   %module_list.112.BatchNorm2d.running_var[FLOAT, 128]
#   %module_list.112.BatchNorm2d.weight[FLOAT, 128]
#   %module_list.112.Conv2d.weight[FLOAT, 128x1x5x5]
#   %module_list.113.BatchNorm2d.bias[FLOAT, 128]
#   %module_list.113.BatchNorm2d.running_mean[FLOAT, 128]
#   %module_list.113.BatchNorm2d.running_var[FLOAT, 128]
#   %module_list.113.BatchNorm2d.weight[FLOAT, 128]
#   %module_list.113.Conv2d.weight[FLOAT, 128x128x1x1]
#   %module_list.114.Conv2d.bias[FLOAT, 21]
#   %module_list.114.Conv2d.weight[FLOAT, 21x128x1x1]
#   %module_list.119.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.119.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.119.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.119.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.119.Conv2d.weight[FLOAT, 96x232x1x1]
#   %module_list.12.BatchNorm2d.bias[FLOAT, 32]
#   %module_list.12.BatchNorm2d.running_mean[FLOAT, 32]
#   %module_list.12.BatchNorm2d.running_var[FLOAT, 32]
#   %module_list.12.BatchNorm2d.weight[FLOAT, 32]
#   %module_list.12.Conv2d.weight[FLOAT, 32x8x1x1]
#   %module_list.120.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.120.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.120.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.120.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.120.Conv2d.weight[FLOAT, 96x1x5x5]
#   %module_list.121.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.121.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.121.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.121.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.121.Conv2d.weight[FLOAT, 96x96x1x1]
#   %module_list.122.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.122.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.122.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.122.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.122.Conv2d.weight[FLOAT, 96x1x5x5]
#   %module_list.123.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.123.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.123.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.123.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.123.Conv2d.weight[FLOAT, 96x96x1x1]
#   %module_list.124.Conv2d.bias[FLOAT, 21]
#   %module_list.124.Conv2d.weight[FLOAT, 21x96x1x1]
#   %module_list.13.BatchNorm2d.bias[FLOAT, 32]
#   %module_list.13.BatchNorm2d.running_mean[FLOAT, 32]
#   %module_list.13.BatchNorm2d.running_var[FLOAT, 32]
#   %module_list.13.BatchNorm2d.weight[FLOAT, 32]
#   %module_list.13.Conv2d.weight[FLOAT, 32x1x3x3]
#   %module_list.14.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.14.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.14.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.14.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.14.Conv2d.weight[FLOAT, 8x32x1x1]
#   %module_list.17.BatchNorm2d.bias[FLOAT, 32]
#   %module_list.17.BatchNorm2d.running_mean[FLOAT, 32]
#   %module_list.17.BatchNorm2d.running_var[FLOAT, 32]
#   %module_list.17.BatchNorm2d.weight[FLOAT, 32]
#   %module_list.17.Conv2d.weight[FLOAT, 32x8x1x1]
#   %module_list.18.BatchNorm2d.bias[FLOAT, 32]
#   %module_list.18.BatchNorm2d.running_mean[FLOAT, 32]
#   %module_list.18.BatchNorm2d.running_var[FLOAT, 32]
#   %module_list.18.BatchNorm2d.weight[FLOAT, 32]
#   %module_list.18.Conv2d.weight[FLOAT, 32x1x3x3]
#   %module_list.19.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.19.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.19.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.19.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.19.Conv2d.weight[FLOAT, 8x32x1x1]
#   %module_list.2.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.2.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.2.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.2.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.2.Conv2d.weight[FLOAT, 8x1x3x3]
#   %module_list.22.BatchNorm2d.bias[FLOAT, 32]
#   %module_list.22.BatchNorm2d.running_mean[FLOAT, 32]
#   %module_list.22.BatchNorm2d.running_var[FLOAT, 32]
#   %module_list.22.BatchNorm2d.weight[FLOAT, 32]
#   %module_list.22.Conv2d.weight[FLOAT, 32x8x1x1]
#   %module_list.23.BatchNorm2d.bias[FLOAT, 32]
#   %module_list.23.BatchNorm2d.running_mean[FLOAT, 32]
#   %module_list.23.BatchNorm2d.running_var[FLOAT, 32]
#   %module_list.23.BatchNorm2d.weight[FLOAT, 32]
#   %module_list.23.Conv2d.weight[FLOAT, 32x1x3x3]
#   %module_list.24.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.24.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.24.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.24.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.24.Conv2d.weight[FLOAT, 8x32x1x1]
#   %module_list.25.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.25.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.25.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.25.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.25.Conv2d.weight[FLOAT, 48x8x1x1]
#   %module_list.26.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.26.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.26.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.26.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.26.Conv2d.weight[FLOAT, 48x1x3x3]
#   %module_list.27.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.27.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.27.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.27.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.27.Conv2d.weight[FLOAT, 8x48x1x1]
#   %module_list.3.BatchNorm2d.bias[FLOAT, 4]
#   %module_list.3.BatchNorm2d.running_mean[FLOAT, 4]
#   %module_list.3.BatchNorm2d.running_var[FLOAT, 4]
#   %module_list.3.BatchNorm2d.weight[FLOAT, 4]
#   %module_list.3.Conv2d.weight[FLOAT, 4x8x1x1]
#   %module_list.30.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.30.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.30.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.30.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.30.Conv2d.weight[FLOAT, 48x8x1x1]
#   %module_list.31.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.31.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.31.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.31.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.31.Conv2d.weight[FLOAT, 48x1x3x3]
#   %module_list.32.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.32.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.32.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.32.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.32.Conv2d.weight[FLOAT, 8x48x1x1]
#   %module_list.35.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.35.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.35.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.35.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.35.Conv2d.weight[FLOAT, 48x8x1x1]
#   %module_list.36.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.36.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.36.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.36.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.36.Conv2d.weight[FLOAT, 48x1x3x3]
#   %module_list.37.BatchNorm2d.bias[FLOAT, 16]
#   %module_list.37.BatchNorm2d.running_mean[FLOAT, 16]
#   %module_list.37.BatchNorm2d.running_var[FLOAT, 16]
#   %module_list.37.BatchNorm2d.weight[FLOAT, 16]
#   %module_list.37.Conv2d.weight[FLOAT, 16x48x1x1]
#   %module_list.38.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.38.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.38.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.38.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.38.Conv2d.weight[FLOAT, 96x16x1x1]
#   %module_list.39.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.39.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.39.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.39.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.39.Conv2d.weight[FLOAT, 96x1x3x3]
#   %module_list.4.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.4.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.4.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.4.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.4.Conv2d.weight[FLOAT, 8x4x1x1]
#   %module_list.40.BatchNorm2d.bias[FLOAT, 16]
#   %module_list.40.BatchNorm2d.running_mean[FLOAT, 16]
#   %module_list.40.BatchNorm2d.running_var[FLOAT, 16]
#   %module_list.40.BatchNorm2d.weight[FLOAT, 16]
#   %module_list.40.Conv2d.weight[FLOAT, 16x96x1x1]
#   %module_list.43.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.43.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.43.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.43.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.43.Conv2d.weight[FLOAT, 96x16x1x1]
#   %module_list.44.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.44.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.44.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.44.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.44.Conv2d.weight[FLOAT, 96x1x3x3]
#   %module_list.45.BatchNorm2d.bias[FLOAT, 16]
#   %module_list.45.BatchNorm2d.running_mean[FLOAT, 16]
#   %module_list.45.BatchNorm2d.running_var[FLOAT, 16]
#   %module_list.45.BatchNorm2d.weight[FLOAT, 16]
#   %module_list.45.Conv2d.weight[FLOAT, 16x96x1x1]
#   %module_list.48.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.48.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.48.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.48.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.48.Conv2d.weight[FLOAT, 96x16x1x1]
#   %module_list.49.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.49.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.49.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.49.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.49.Conv2d.weight[FLOAT, 96x1x3x3]
#   %module_list.5.BatchNorm2d.bias[FLOAT, 8]
#   %module_list.5.BatchNorm2d.running_mean[FLOAT, 8]
#   %module_list.5.BatchNorm2d.running_var[FLOAT, 8]
#   %module_list.5.BatchNorm2d.weight[FLOAT, 8]
#   %module_list.5.Conv2d.weight[FLOAT, 8x1x3x3]
#   %module_list.50.BatchNorm2d.bias[FLOAT, 16]
#   %module_list.50.BatchNorm2d.running_mean[FLOAT, 16]
#   %module_list.50.BatchNorm2d.running_var[FLOAT, 16]
#   %module_list.50.BatchNorm2d.weight[FLOAT, 16]
#   %module_list.50.Conv2d.weight[FLOAT, 16x96x1x1]
#   %module_list.53.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.53.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.53.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.53.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.53.Conv2d.weight[FLOAT, 96x16x1x1]
#   %module_list.54.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.54.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.54.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.54.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.54.Conv2d.weight[FLOAT, 96x1x3x3]
#   %module_list.55.BatchNorm2d.bias[FLOAT, 16]
#   %module_list.55.BatchNorm2d.running_mean[FLOAT, 16]
#   %module_list.55.BatchNorm2d.running_var[FLOAT, 16]
#   %module_list.55.BatchNorm2d.weight[FLOAT, 16]
#   %module_list.55.Conv2d.weight[FLOAT, 16x96x1x1]
#   %module_list.58.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.58.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.58.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.58.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.58.Conv2d.weight[FLOAT, 96x16x1x1]
#   %module_list.59.BatchNorm2d.bias[FLOAT, 96]
#   %module_list.59.BatchNorm2d.running_mean[FLOAT, 96]
#   %module_list.59.BatchNorm2d.running_var[FLOAT, 96]
#   %module_list.59.BatchNorm2d.weight[FLOAT, 96]
#   %module_list.59.Conv2d.weight[FLOAT, 96x1x3x3]
#   %module_list.6.BatchNorm2d.bias[FLOAT, 4]
#   %module_list.6.BatchNorm2d.running_mean[FLOAT, 4]
#   %module_list.6.BatchNorm2d.running_var[FLOAT, 4]
#   %module_list.6.BatchNorm2d.weight[FLOAT, 4]
#   %module_list.6.Conv2d.weight[FLOAT, 4x8x1x1]
#   %module_list.60.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.60.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.60.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.60.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.60.Conv2d.weight[FLOAT, 24x96x1x1]
#   %module_list.61.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.61.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.61.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.61.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.61.Conv2d.weight[FLOAT, 136x24x1x1]
#   %module_list.62.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.62.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.62.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.62.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.62.Conv2d.weight[FLOAT, 136x1x3x3]
#   %module_list.63.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.63.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.63.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.63.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.63.Conv2d.weight[FLOAT, 24x136x1x1]
#   %module_list.66.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.66.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.66.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.66.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.66.Conv2d.weight[FLOAT, 136x24x1x1]
#   %module_list.67.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.67.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.67.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.67.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.67.Conv2d.weight[FLOAT, 136x1x3x3]
#   %module_list.68.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.68.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.68.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.68.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.68.Conv2d.weight[FLOAT, 24x136x1x1]
#   %module_list.71.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.71.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.71.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.71.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.71.Conv2d.weight[FLOAT, 136x24x1x1]
#   %module_list.72.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.72.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.72.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.72.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.72.Conv2d.weight[FLOAT, 136x1x3x3]
#   %module_list.73.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.73.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.73.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.73.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.73.Conv2d.weight[FLOAT, 24x136x1x1]
#   %module_list.76.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.76.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.76.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.76.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.76.Conv2d.weight[FLOAT, 136x24x1x1]
#   %module_list.77.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.77.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.77.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.77.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.77.Conv2d.weight[FLOAT, 136x1x3x3]
#   %module_list.78.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.78.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.78.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.78.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.78.Conv2d.weight[FLOAT, 24x136x1x1]
#   %module_list.81.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.81.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.81.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.81.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.81.Conv2d.weight[FLOAT, 136x24x1x1]
#   %module_list.82.BatchNorm2d.bias[FLOAT, 136]
#   %module_list.82.BatchNorm2d.running_mean[FLOAT, 136]
#   %module_list.82.BatchNorm2d.running_var[FLOAT, 136]
#   %module_list.82.BatchNorm2d.weight[FLOAT, 136]
#   %module_list.82.Conv2d.weight[FLOAT, 136x1x3x3]
#   %module_list.83.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.83.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.83.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.83.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.83.Conv2d.weight[FLOAT, 48x136x1x1]
#   %module_list.84.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.84.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.84.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.84.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.84.Conv2d.weight[FLOAT, 224x48x1x1]
#   %module_list.85.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.85.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.85.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.85.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.85.Conv2d.weight[FLOAT, 224x1x3x3]
#   %module_list.86.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.86.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.86.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.86.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.86.Conv2d.weight[FLOAT, 48x224x1x1]
#   %module_list.89.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.89.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.89.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.89.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.89.Conv2d.weight[FLOAT, 224x48x1x1]
#   %module_list.9.BatchNorm2d.bias[FLOAT, 24]
#   %module_list.9.BatchNorm2d.running_mean[FLOAT, 24]
#   %module_list.9.BatchNorm2d.running_var[FLOAT, 24]
#   %module_list.9.BatchNorm2d.weight[FLOAT, 24]
#   %module_list.9.Conv2d.weight[FLOAT, 24x4x1x1]
#   %module_list.90.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.90.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.90.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.90.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.90.Conv2d.weight[FLOAT, 224x1x3x3]
#   %module_list.91.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.91.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.91.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.91.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.91.Conv2d.weight[FLOAT, 48x224x1x1]
#   %module_list.94.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.94.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.94.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.94.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.94.Conv2d.weight[FLOAT, 224x48x1x1]
#   %module_list.95.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.95.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.95.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.95.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.95.Conv2d.weight[FLOAT, 224x1x3x3]
#   %module_list.96.BatchNorm2d.bias[FLOAT, 48]
#   %module_list.96.BatchNorm2d.running_mean[FLOAT, 48]
#   %module_list.96.BatchNorm2d.running_var[FLOAT, 48]
#   %module_list.96.BatchNorm2d.weight[FLOAT, 48]
#   %module_list.96.Conv2d.weight[FLOAT, 48x224x1x1]
#   %module_list.99.BatchNorm2d.bias[FLOAT, 224]
#   %module_list.99.BatchNorm2d.running_mean[FLOAT, 224]
#   %module_list.99.BatchNorm2d.running_var[FLOAT, 224]
#   %module_list.99.BatchNorm2d.weight[FLOAT, 224]
#   %module_list.99.Conv2d.weight[FLOAT, 224x48x1x1]
# ) {
#   %503 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%images, %module_list.0.Conv2d.weight)
#   %504 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%503, %module_list.0.BatchNorm2d.weight, %module_list.0.BatchNorm2d.bias, %module_list.0.BatchNorm2d.running_mean, %module_list.0.BatchNorm2d.running_var)
#   %505 = LeakyRelu[alpha = 0.100000001490116](%504)
#   %506 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%505, %module_list.1.Conv2d.weight)
#   %507 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%506, %module_list.1.BatchNorm2d.weight, %module_list.1.BatchNorm2d.bias, %module_list.1.BatchNorm2d.running_mean, %module_list.1.BatchNorm2d.running_var)
#   %508 = LeakyRelu[alpha = 0.100000001490116](%507)
#   %509 = Conv[dilations = [1, 1], group = 8, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%508, %module_list.2.Conv2d.weight)
#   %510 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%509, %module_list.2.BatchNorm2d.weight, %module_list.2.BatchNorm2d.bias, %module_list.2.BatchNorm2d.running_mean, %module_list.2.BatchNorm2d.running_var)
#   %511 = LeakyRelu[alpha = 0.100000001490116](%510)
#   %512 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%511, %module_list.3.Conv2d.weight)
#   %513 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%512, %module_list.3.BatchNorm2d.weight, %module_list.3.BatchNorm2d.bias, %module_list.3.BatchNorm2d.running_mean, %module_list.3.BatchNorm2d.running_var)
#   %514 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%513, %module_list.4.Conv2d.weight)
#   %515 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%514, %module_list.4.BatchNorm2d.weight, %module_list.4.BatchNorm2d.bias, %module_list.4.BatchNorm2d.running_mean, %module_list.4.BatchNorm2d.running_var)
#   %516 = LeakyRelu[alpha = 0.100000001490116](%515)
#   %517 = Conv[dilations = [1, 1], group = 8, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%516, %module_list.5.Conv2d.weight)
#   %518 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%517, %module_list.5.BatchNorm2d.weight, %module_list.5.BatchNorm2d.bias, %module_list.5.BatchNorm2d.running_mean, %module_list.5.BatchNorm2d.running_var)
#   %519 = LeakyRelu[alpha = 0.100000001490116](%518)
#   %520 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%519, %module_list.6.Conv2d.weight)
#   %521 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%520, %module_list.6.BatchNorm2d.weight, %module_list.6.BatchNorm2d.bias, %module_list.6.BatchNorm2d.running_mean, %module_list.6.BatchNorm2d.running_var)
#   %522 = Add(%521, %513)
#   %523 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%522, %module_list.9.Conv2d.weight)
#   %524 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%523, %module_list.9.BatchNorm2d.weight, %module_list.9.BatchNorm2d.bias, %module_list.9.BatchNorm2d.running_mean, %module_list.9.BatchNorm2d.running_var)
#   %525 = LeakyRelu[alpha = 0.100000001490116](%524)
#   %526 = Conv[dilations = [1, 1], group = 24, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%525, %module_list.10.Conv2d.weight)
#   %527 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%526, %module_list.10.BatchNorm2d.weight, %module_list.10.BatchNorm2d.bias, %module_list.10.BatchNorm2d.running_mean, %module_list.10.BatchNorm2d.running_var)
#   %528 = LeakyRelu[alpha = 0.100000001490116](%527)
#   %529 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%528, %module_list.11.Conv2d.weight)
#   %530 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%529, %module_list.11.BatchNorm2d.weight, %module_list.11.BatchNorm2d.bias, %module_list.11.BatchNorm2d.running_mean, %module_list.11.BatchNorm2d.running_var)
#   %531 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%530, %module_list.12.Conv2d.weight)
#   %532 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%531, %module_list.12.BatchNorm2d.weight, %module_list.12.BatchNorm2d.bias, %module_list.12.BatchNorm2d.running_mean, %module_list.12.BatchNorm2d.running_var)
#   %533 = LeakyRelu[alpha = 0.100000001490116](%532)
#   %534 = Conv[dilations = [1, 1], group = 32, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%533, %module_list.13.Conv2d.weight)
#   %535 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%534, %module_list.13.BatchNorm2d.weight, %module_list.13.BatchNorm2d.bias, %module_list.13.BatchNorm2d.running_mean, %module_list.13.BatchNorm2d.running_var)
#   %536 = LeakyRelu[alpha = 0.100000001490116](%535)
#   %537 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%536, %module_list.14.Conv2d.weight)
#   %538 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%537, %module_list.14.BatchNorm2d.weight, %module_list.14.BatchNorm2d.bias, %module_list.14.BatchNorm2d.running_mean, %module_list.14.BatchNorm2d.running_var)
#   %539 = Add(%538, %530)
#   %540 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%539, %module_list.17.Conv2d.weight)
#   %541 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%540, %module_list.17.BatchNorm2d.weight, %module_list.17.BatchNorm2d.bias, %module_list.17.BatchNorm2d.running_mean, %module_list.17.BatchNorm2d.running_var)
#   %542 = LeakyRelu[alpha = 0.100000001490116](%541)
#   %543 = Conv[dilations = [1, 1], group = 32, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%542, %module_list.18.Conv2d.weight)
#   %544 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%543, %module_list.18.BatchNorm2d.weight, %module_list.18.BatchNorm2d.bias, %module_list.18.BatchNorm2d.running_mean, %module_list.18.BatchNorm2d.running_var)
#   %545 = LeakyRelu[alpha = 0.100000001490116](%544)
#   %546 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%545, %module_list.19.Conv2d.weight)
#   %547 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%546, %module_list.19.BatchNorm2d.weight, %module_list.19.BatchNorm2d.bias, %module_list.19.BatchNorm2d.running_mean, %module_list.19.BatchNorm2d.running_var)
#   %548 = Add(%547, %539)
#   %549 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%548, %module_list.22.Conv2d.weight)
#   %550 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%549, %module_list.22.BatchNorm2d.weight, %module_list.22.BatchNorm2d.bias, %module_list.22.BatchNorm2d.running_mean, %module_list.22.BatchNorm2d.running_var)
#   %551 = LeakyRelu[alpha = 0.100000001490116](%550)
#   %552 = Conv[dilations = [1, 1], group = 32, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%551, %module_list.23.Conv2d.weight)
#   %553 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%552, %module_list.23.BatchNorm2d.weight, %module_list.23.BatchNorm2d.bias, %module_list.23.BatchNorm2d.running_mean, %module_list.23.BatchNorm2d.running_var)
#   %554 = LeakyRelu[alpha = 0.100000001490116](%553)
#   %555 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%554, %module_list.24.Conv2d.weight)
#   %556 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%555, %module_list.24.BatchNorm2d.weight, %module_list.24.BatchNorm2d.bias, %module_list.24.BatchNorm2d.running_mean, %module_list.24.BatchNorm2d.running_var)
#   %557 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%556, %module_list.25.Conv2d.weight)
#   %558 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%557, %module_list.25.BatchNorm2d.weight, %module_list.25.BatchNorm2d.bias, %module_list.25.BatchNorm2d.running_mean, %module_list.25.BatchNorm2d.running_var)
#   %559 = LeakyRelu[alpha = 0.100000001490116](%558)
#   %560 = Conv[dilations = [1, 1], group = 48, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%559, %module_list.26.Conv2d.weight)
#   %561 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%560, %module_list.26.BatchNorm2d.weight, %module_list.26.BatchNorm2d.bias, %module_list.26.BatchNorm2d.running_mean, %module_list.26.BatchNorm2d.running_var)
#   %562 = LeakyRelu[alpha = 0.100000001490116](%561)
#   %563 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%562, %module_list.27.Conv2d.weight)
#   %564 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%563, %module_list.27.BatchNorm2d.weight, %module_list.27.BatchNorm2d.bias, %module_list.27.BatchNorm2d.running_mean, %module_list.27.BatchNorm2d.running_var)
#   %565 = Add(%564, %556)
#   %566 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%565, %module_list.30.Conv2d.weight)
#   %567 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%566, %module_list.30.BatchNorm2d.weight, %module_list.30.BatchNorm2d.bias, %module_list.30.BatchNorm2d.running_mean, %module_list.30.BatchNorm2d.running_var)
#   %568 = LeakyRelu[alpha = 0.100000001490116](%567)
#   %569 = Conv[dilations = [1, 1], group = 48, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%568, %module_list.31.Conv2d.weight)
#   %570 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%569, %module_list.31.BatchNorm2d.weight, %module_list.31.BatchNorm2d.bias, %module_list.31.BatchNorm2d.running_mean, %module_list.31.BatchNorm2d.running_var)
#   %571 = LeakyRelu[alpha = 0.100000001490116](%570)
#   %572 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%571, %module_list.32.Conv2d.weight)
#   %573 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%572, %module_list.32.BatchNorm2d.weight, %module_list.32.BatchNorm2d.bias, %module_list.32.BatchNorm2d.running_mean, %module_list.32.BatchNorm2d.running_var)
#   %574 = Add(%573, %565)
#   %575 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%574, %module_list.35.Conv2d.weight)
#   %576 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%575, %module_list.35.BatchNorm2d.weight, %module_list.35.BatchNorm2d.bias, %module_list.35.BatchNorm2d.running_mean, %module_list.35.BatchNorm2d.running_var)
#   %577 = LeakyRelu[alpha = 0.100000001490116](%576)
#   %578 = Conv[dilations = [1, 1], group = 48, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%577, %module_list.36.Conv2d.weight)
#   %579 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%578, %module_list.36.BatchNorm2d.weight, %module_list.36.BatchNorm2d.bias, %module_list.36.BatchNorm2d.running_mean, %module_list.36.BatchNorm2d.running_var)
#   %580 = LeakyRelu[alpha = 0.100000001490116](%579)
#   %581 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%580, %module_list.37.Conv2d.weight)
#   %582 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%581, %module_list.37.BatchNorm2d.weight, %module_list.37.BatchNorm2d.bias, %module_list.37.BatchNorm2d.running_mean, %module_list.37.BatchNorm2d.running_var)
#   %583 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%582, %module_list.38.Conv2d.weight)
#   %584 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%583, %module_list.38.BatchNorm2d.weight, %module_list.38.BatchNorm2d.bias, %module_list.38.BatchNorm2d.running_mean, %module_list.38.BatchNorm2d.running_var)
#   %585 = LeakyRelu[alpha = 0.100000001490116](%584)
#   %586 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%585, %module_list.39.Conv2d.weight)
#   %587 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%586, %module_list.39.BatchNorm2d.weight, %module_list.39.BatchNorm2d.bias, %module_list.39.BatchNorm2d.running_mean, %module_list.39.BatchNorm2d.running_var)
#   %588 = LeakyRelu[alpha = 0.100000001490116](%587)
#   %589 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%588, %module_list.40.Conv2d.weight)
#   %590 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%589, %module_list.40.BatchNorm2d.weight, %module_list.40.BatchNorm2d.bias, %module_list.40.BatchNorm2d.running_mean, %module_list.40.BatchNorm2d.running_var)
#   %591 = Add(%590, %582)
#   %592 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%591, %module_list.43.Conv2d.weight)
#   %593 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%592, %module_list.43.BatchNorm2d.weight, %module_list.43.BatchNorm2d.bias, %module_list.43.BatchNorm2d.running_mean, %module_list.43.BatchNorm2d.running_var)
#   %594 = LeakyRelu[alpha = 0.100000001490116](%593)
#   %595 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%594, %module_list.44.Conv2d.weight)
#   %596 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%595, %module_list.44.BatchNorm2d.weight, %module_list.44.BatchNorm2d.bias, %module_list.44.BatchNorm2d.running_mean, %module_list.44.BatchNorm2d.running_var)
#   %597 = LeakyRelu[alpha = 0.100000001490116](%596)
#   %598 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%597, %module_list.45.Conv2d.weight)
#   %599 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%598, %module_list.45.BatchNorm2d.weight, %module_list.45.BatchNorm2d.bias, %module_list.45.BatchNorm2d.running_mean, %module_list.45.BatchNorm2d.running_var)
#   %600 = Add(%599, %591)
#   %601 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%600, %module_list.48.Conv2d.weight)
#   %602 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%601, %module_list.48.BatchNorm2d.weight, %module_list.48.BatchNorm2d.bias, %module_list.48.BatchNorm2d.running_mean, %module_list.48.BatchNorm2d.running_var)
#   %603 = LeakyRelu[alpha = 0.100000001490116](%602)
#   %604 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%603, %module_list.49.Conv2d.weight)
#   %605 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%604, %module_list.49.BatchNorm2d.weight, %module_list.49.BatchNorm2d.bias, %module_list.49.BatchNorm2d.running_mean, %module_list.49.BatchNorm2d.running_var)
#   %606 = LeakyRelu[alpha = 0.100000001490116](%605)
#   %607 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%606, %module_list.50.Conv2d.weight)
#   %608 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%607, %module_list.50.BatchNorm2d.weight, %module_list.50.BatchNorm2d.bias, %module_list.50.BatchNorm2d.running_mean, %module_list.50.BatchNorm2d.running_var)
#   %609 = Add(%608, %600)
#   %610 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%609, %module_list.53.Conv2d.weight)
#   %611 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%610, %module_list.53.BatchNorm2d.weight, %module_list.53.BatchNorm2d.bias, %module_list.53.BatchNorm2d.running_mean, %module_list.53.BatchNorm2d.running_var)
#   %612 = LeakyRelu[alpha = 0.100000001490116](%611)
#   %613 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%612, %module_list.54.Conv2d.weight)
#   %614 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%613, %module_list.54.BatchNorm2d.weight, %module_list.54.BatchNorm2d.bias, %module_list.54.BatchNorm2d.running_mean, %module_list.54.BatchNorm2d.running_var)
#   %615 = LeakyRelu[alpha = 0.100000001490116](%614)
#   %616 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%615, %module_list.55.Conv2d.weight)
#   %617 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%616, %module_list.55.BatchNorm2d.weight, %module_list.55.BatchNorm2d.bias, %module_list.55.BatchNorm2d.running_mean, %module_list.55.BatchNorm2d.running_var)
#   %618 = Add(%617, %609)
#   %619 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%618, %module_list.58.Conv2d.weight)
#   %620 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%619, %module_list.58.BatchNorm2d.weight, %module_list.58.BatchNorm2d.bias, %module_list.58.BatchNorm2d.running_mean, %module_list.58.BatchNorm2d.running_var)
#   %621 = LeakyRelu[alpha = 0.100000001490116](%620)
#   %622 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%621, %module_list.59.Conv2d.weight)
#   %623 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%622, %module_list.59.BatchNorm2d.weight, %module_list.59.BatchNorm2d.bias, %module_list.59.BatchNorm2d.running_mean, %module_list.59.BatchNorm2d.running_var)
#   %624 = LeakyRelu[alpha = 0.100000001490116](%623)
#   %625 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%624, %module_list.60.Conv2d.weight)
#   %626 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%625, %module_list.60.BatchNorm2d.weight, %module_list.60.BatchNorm2d.bias, %module_list.60.BatchNorm2d.running_mean, %module_list.60.BatchNorm2d.running_var)
#   %627 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%626, %module_list.61.Conv2d.weight)
#   %628 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%627, %module_list.61.BatchNorm2d.weight, %module_list.61.BatchNorm2d.bias, %module_list.61.BatchNorm2d.running_mean, %module_list.61.BatchNorm2d.running_var)
#   %629 = LeakyRelu[alpha = 0.100000001490116](%628)
#   %630 = Conv[dilations = [1, 1], group = 136, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%629, %module_list.62.Conv2d.weight)
#   %631 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%630, %module_list.62.BatchNorm2d.weight, %module_list.62.BatchNorm2d.bias, %module_list.62.BatchNorm2d.running_mean, %module_list.62.BatchNorm2d.running_var)
#   %632 = LeakyRelu[alpha = 0.100000001490116](%631)
#   %633 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%632, %module_list.63.Conv2d.weight)
#   %634 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%633, %module_list.63.BatchNorm2d.weight, %module_list.63.BatchNorm2d.bias, %module_list.63.BatchNorm2d.running_mean, %module_list.63.BatchNorm2d.running_var)
#   %635 = Add(%634, %626)
#   %636 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%635, %module_list.66.Conv2d.weight)
#   %637 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%636, %module_list.66.BatchNorm2d.weight, %module_list.66.BatchNorm2d.bias, %module_list.66.BatchNorm2d.running_mean, %module_list.66.BatchNorm2d.running_var)
#   %638 = LeakyRelu[alpha = 0.100000001490116](%637)
#   %639 = Conv[dilations = [1, 1], group = 136, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%638, %module_list.67.Conv2d.weight)
#   %640 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%639, %module_list.67.BatchNorm2d.weight, %module_list.67.BatchNorm2d.bias, %module_list.67.BatchNorm2d.running_mean, %module_list.67.BatchNorm2d.running_var)
#   %641 = LeakyRelu[alpha = 0.100000001490116](%640)
#   %642 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%641, %module_list.68.Conv2d.weight)
#   %643 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%642, %module_list.68.BatchNorm2d.weight, %module_list.68.BatchNorm2d.bias, %module_list.68.BatchNorm2d.running_mean, %module_list.68.BatchNorm2d.running_var)
#   %644 = Add(%643, %635)
#   %645 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%644, %module_list.71.Conv2d.weight)
#   %646 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%645, %module_list.71.BatchNorm2d.weight, %module_list.71.BatchNorm2d.bias, %module_list.71.BatchNorm2d.running_mean, %module_list.71.BatchNorm2d.running_var)
#   %647 = LeakyRelu[alpha = 0.100000001490116](%646)
#   %648 = Conv[dilations = [1, 1], group = 136, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%647, %module_list.72.Conv2d.weight)
#   %649 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%648, %module_list.72.BatchNorm2d.weight, %module_list.72.BatchNorm2d.bias, %module_list.72.BatchNorm2d.running_mean, %module_list.72.BatchNorm2d.running_var)
#   %650 = LeakyRelu[alpha = 0.100000001490116](%649)
#   %651 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%650, %module_list.73.Conv2d.weight)
#   %652 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%651, %module_list.73.BatchNorm2d.weight, %module_list.73.BatchNorm2d.bias, %module_list.73.BatchNorm2d.running_mean, %module_list.73.BatchNorm2d.running_var)
#   %653 = Add(%652, %644)
#   %654 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%653, %module_list.76.Conv2d.weight)
#   %655 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%654, %module_list.76.BatchNorm2d.weight, %module_list.76.BatchNorm2d.bias, %module_list.76.BatchNorm2d.running_mean, %module_list.76.BatchNorm2d.running_var)
#   %656 = LeakyRelu[alpha = 0.100000001490116](%655)
#   %657 = Conv[dilations = [1, 1], group = 136, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%656, %module_list.77.Conv2d.weight)
#   %658 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%657, %module_list.77.BatchNorm2d.weight, %module_list.77.BatchNorm2d.bias, %module_list.77.BatchNorm2d.running_mean, %module_list.77.BatchNorm2d.running_var)
#   %659 = LeakyRelu[alpha = 0.100000001490116](%658)
#   %660 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%659, %module_list.78.Conv2d.weight)
#   %661 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%660, %module_list.78.BatchNorm2d.weight, %module_list.78.BatchNorm2d.bias, %module_list.78.BatchNorm2d.running_mean, %module_list.78.BatchNorm2d.running_var)
#   %662 = Add(%661, %653)
#   %663 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%662, %module_list.81.Conv2d.weight)
#   %664 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%663, %module_list.81.BatchNorm2d.weight, %module_list.81.BatchNorm2d.bias, %module_list.81.BatchNorm2d.running_mean, %module_list.81.BatchNorm2d.running_var)
#   %665 = LeakyRelu[alpha = 0.100000001490116](%664)
#   %666 = Conv[dilations = [1, 1], group = 136, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%665, %module_list.82.Conv2d.weight)
#   %667 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%666, %module_list.82.BatchNorm2d.weight, %module_list.82.BatchNorm2d.bias, %module_list.82.BatchNorm2d.running_mean, %module_list.82.BatchNorm2d.running_var)
#   %668 = LeakyRelu[alpha = 0.100000001490116](%667)
#   %669 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%668, %module_list.83.Conv2d.weight)
#   %670 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%669, %module_list.83.BatchNorm2d.weight, %module_list.83.BatchNorm2d.bias, %module_list.83.BatchNorm2d.running_mean, %module_list.83.BatchNorm2d.running_var)
#   %671 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%670, %module_list.84.Conv2d.weight)
#   %672 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%671, %module_list.84.BatchNorm2d.weight, %module_list.84.BatchNorm2d.bias, %module_list.84.BatchNorm2d.running_mean, %module_list.84.BatchNorm2d.running_var)
#   %673 = LeakyRelu[alpha = 0.100000001490116](%672)
#   %674 = Conv[dilations = [1, 1], group = 224, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%673, %module_list.85.Conv2d.weight)
#   %675 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%674, %module_list.85.BatchNorm2d.weight, %module_list.85.BatchNorm2d.bias, %module_list.85.BatchNorm2d.running_mean, %module_list.85.BatchNorm2d.running_var)
#   %676 = LeakyRelu[alpha = 0.100000001490116](%675)
#   %677 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%676, %module_list.86.Conv2d.weight)
#   %678 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%677, %module_list.86.BatchNorm2d.weight, %module_list.86.BatchNorm2d.bias, %module_list.86.BatchNorm2d.running_mean, %module_list.86.BatchNorm2d.running_var)
#   %679 = Add(%678, %670)
# ...
#   %1135 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1134, %module_list.120.BatchNorm2d.weight, %module_list.120.BatchNorm2d.bias, %module_list.120.BatchNorm2d.running_mean, %module_list.120.BatchNorm2d.running_var)
#   %1136 = LeakyRelu[alpha = 0.100000001490116](%1135)
#   %1137 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1136, %module_list.121.Conv2d.weight)
#   %1138 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1137, %module_list.121.BatchNorm2d.weight, %module_list.121.BatchNorm2d.bias, %module_list.121.BatchNorm2d.running_mean, %module_list.121.BatchNorm2d.running_var)
#   %1139 = Conv[dilations = [1, 1], group = 96, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%1138, %module_list.122.Conv2d.weight)
#   %1140 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1139, %module_list.122.BatchNorm2d.weight, %module_list.122.BatchNorm2d.bias, %module_list.122.BatchNorm2d.running_mean, %module_list.122.BatchNorm2d.running_var)
#   %1141 = LeakyRelu[alpha = 0.100000001490116](%1140)
#   %1142 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1141, %module_list.123.Conv2d.weight)
#   %1143 = BatchNormalization[epsilon = 9.99999974737875e-05, momentum = 0.970000028610229](%1142, %module_list.123.BatchNorm2d.weight, %module_list.123.BatchNorm2d.bias, %module_list.123.BatchNorm2d.running_mean, %module_list.123.BatchNorm2d.running_var)
#   %1144 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%1143, %module_list.124.Conv2d.weight, %module_list.124.Conv2d.bias)
#   %1145 = Shape(%1144)
#   %1146 = Constant[value = <Scalar Tensor []>]()
#   %1147 = Gather[axis = 0](%1145, %1146)
#   %1152 = Unsqueeze[axes = [0]](%1147)
#   %1157 = Concat[axis = 0](%1152, %1550, %1551, %1552, %1553)
#   %1158 = Reshape(%1144, %1157)
#   %yolo2 = Transpose[perm = [0, 1, 3, 4, 2]](%1158)
#   %1160 = Constant[value = <Tensor>]()
#   %1161 = Constant[value = <Tensor>]()
#   %1162 = Constant[value = <Tensor>]()
#   %1163 = Constant[value = <Tensor>]()
#   %1164 = Slice(%yolo2, %1161, %1162, %1160, %1163)
#   %1165 = Sigmoid(%1164)
#   %1166 = Constant[value = <Tensor>]()
#   %1167 = Add(%1165, %1166)
#   %1168 = Constant[value = <Tensor>]()
#   %1169 = Reshape(%1167, %1168)
#   %1170 = Constant[value = <Tensor>]()
#   %1172 = ConstantOfShape[value = <Tensor>](%1554)
#   %1173 = Constant[value = <Scalar Tensor []>]()
#   %1174 = Mul(%1172, %1173)
#   %1175 = Constant[value = <Tensor>]()
#   %1176 = Equal(%1175, %1174)
#   %1177 = Where(%1176, %1172, %1170)
#   %1178 = Expand(%1169, %1177)
#   %1179 = Shape(%yolo2)
#   %1180 = Constant[value = <Scalar Tensor []>]()
#   %1181 = Gather[axis = 0](%1179, %1180)
#   %1182 = Cast[to = 7](%1181)
#   %1183 = Constant[value = <Scalar Tensor []>]()
#   %1184 = Constant[value = <Scalar Tensor []>]()
#   %1185 = Range(%1183, %1182, %1184)
#   %1186 = Shape(%yolo2)
#   %1187 = Constant[value = <Scalar Tensor []>]()
#   %1188 = Gather[axis = 0](%1186, %1187)
#   %1189 = Cast[to = 7](%1188)
#   %1190 = Constant[value = <Scalar Tensor []>]()
#   %1191 = Constant[value = <Scalar Tensor []>]()
#   %1192 = Range(%1190, %1189, %1191)
#   %1193 = Shape(%yolo2)
#   %1194 = Constant[value = <Scalar Tensor []>]()
#   %1195 = Gather[axis = 0](%1193, %1194)
#   %1196 = Cast[to = 7](%1195)
#   %1197 = Constant[value = <Scalar Tensor []>]()
#   %1198 = Constant[value = <Scalar Tensor []>]()
#   %1199 = Range(%1197, %1196, %1198)
#   %1200 = Shape(%yolo2)
#   %1201 = Constant[value = <Scalar Tensor []>]()
#   %1202 = Gather[axis = 0](%1200, %1201)
#   %1203 = Cast[to = 7](%1202)
#   %1204 = Constant[value = <Scalar Tensor []>]()
#   %1205 = Constant[value = <Scalar Tensor []>]()
#   %1206 = Range(%1204, %1203, %1205)
#   %1207 = Shape(%yolo2)
#   %1208 = Constant[value = <Scalar Tensor []>]()
#   %1209 = Gather[axis = 0](%1207, %1208)
#   %1210 = Cast[to = 7](%1209)
#   %1211 = Constant[value = <Scalar Tensor []>]()
#   %1212 = Constant[value = <Scalar Tensor []>]()
#   %1213 = Range(%1211, %1210, %1212)
#   %1214 = Constant[value = <Tensor>]()
#   %1215 = Constant[value = <Tensor>]()
#   %1216 = Constant[value = <Tensor>]()
#   %1217 = Constant[value = <Tensor>]()
#   %1218 = Slice(%1213, %1215, %1216, %1214, %1217)
#   %1219 = Constant[value = <Tensor>]()
#   %1220 = Reshape(%1185, %1219)
#   %1221 = Constant[value = <Tensor>]()
#   %1222 = Reshape(%1192, %1221)
#   %1223 = Constant[value = <Tensor>]()
#   %1224 = Reshape(%1199, %1223)
#   %1225 = Constant[value = <Tensor>]()
#   %1226 = Reshape(%1206, %1225)
#   %1227 = Constant[value = <Tensor>]()
#   %1228 = Reshape(%1218, %1227)
#   %1229 = Add(%1220, %1222)
#   %1230 = Add(%1229, %1224)
#   %1231 = Add(%1230, %1226)
#   %1232 = Add(%1231, %1228)
#   %1233 = Shape(%1232)
#   %1234 = Shape(%1233)
#   %1235 = ConstantOfShape[value = <Tensor>](%1234)
#   %1236 = Constant[value = <Scalar Tensor []>]()
#   %1237 = Mul(%1235, %1236)
#   %1238 = Equal(%1233, %1237)
#   %1239 = Where(%1238, %1235, %1233)
#   %1240 = Expand(%1220, %1239)
#   %1241 = Unsqueeze[axes = [-1]](%1240)
#   %1242 = Shape(%1233)
#   %1243 = ConstantOfShape[value = <Tensor>](%1242)
#   %1244 = Constant[value = <Scalar Tensor []>]()
#   %1245 = Mul(%1243, %1244)
#   %1246 = Equal(%1233, %1245)
#   %1247 = Where(%1246, %1243, %1233)
#   %1248 = Expand(%1222, %1247)
#   %1249 = Unsqueeze[axes = [-1]](%1248)
#   %1250 = Shape(%1233)
#   %1251 = ConstantOfShape[value = <Tensor>](%1250)
#   %1252 = Constant[value = <Scalar Tensor []>]()
#   %1253 = Mul(%1251, %1252)
#   %1254 = Equal(%1233, %1253)
#   %1255 = Where(%1254, %1251, %1233)
#   %1256 = Expand(%1224, %1255)
#   %1257 = Unsqueeze[axes = [-1]](%1256)
#   %1258 = Shape(%1233)
#   %1259 = ConstantOfShape[value = <Tensor>](%1258)
#   %1260 = Constant[value = <Scalar Tensor []>]()
#   %1261 = Mul(%1259, %1260)
#   %1262 = Equal(%1233, %1261)
#   %1263 = Where(%1262, %1259, %1233)
#   %1264 = Expand(%1226, %1263)
#   %1265 = Unsqueeze[axes = [-1]](%1264)
#   %1266 = Shape(%1233)
#   %1267 = ConstantOfShape[value = <Tensor>](%1266)
#   %1268 = Constant[value = <Scalar Tensor []>]()
#   %1269 = Mul(%1267, %1268)
#   %1270 = Equal(%1233, %1269)
#   %1271 = Where(%1270, %1267, %1233)
#   %1272 = Expand(%1228, %1271)
#   %1273 = Unsqueeze[axes = [-1]](%1272)
#   %1274 = Concat[axis = -1](%1241, %1249, %1257, %1265, %1273)
#   %1275 = Shape(%yolo2)
#   %1276 = Constant[value = <Tensor>]()
#   %1277 = Constant[value = <Tensor>]()
#   %1278 = Constant[value = <Tensor>]()
#   %1279 = Slice(%1275, %1277, %1278, %1276)
#   %1280 = Concat[axis = 0](%1233, %1279)
#   %1281 = Reshape(%1178, %1280)
#   %1282 = ScatterND(%yolo2, %1274, %1281)
#   %1283 = Constant[value = <Tensor>]()
#   %1284 = Constant[value = <Tensor>]()
#   %1285 = Constant[value = <Tensor>]()
#   %1286 = Constant[value = <Tensor>]()
#   %1287 = Slice(%1282, %1284, %1285, %1283, %1286)
#   %1288 = Exp(%1287)
#   %1289 = Constant[value = <Tensor>]()
#   %1290 = Mul(%1288, %1289)
#   %1291 = Constant[value = <Tensor>]()
#   %1292 = Reshape(%1290, %1291)
#   %1293 = Constant[value = <Tensor>]()
#   %1295 = ConstantOfShape[value = <Tensor>](%1555)
#   %1296 = Constant[value = <Scalar Tensor []>]()
#   %1297 = Mul(%1295, %1296)
#   %1298 = Constant[value = <Tensor>]()
#   %1299 = Equal(%1298, %1297)
#   %1300 = Where(%1299, %1295, %1293)
#   %1301 = Expand(%1292, %1300)
#   %1302 = Shape(%1282)
#   %1303 = Constant[value = <Scalar Tensor []>]()
#   %1304 = Gather[axis = 0](%1302, %1303)
#   %1305 = Cast[to = 7](%1304)
#   %1306 = Constant[value = <Scalar Tensor []>]()
#   %1307 = Constant[value = <Scalar Tensor []>]()
#   %1308 = Range(%1306, %1305, %1307)
#   %1309 = Shape(%1282)
#   %1310 = Constant[value = <Scalar Tensor []>]()
#   %1311 = Gather[axis = 0](%1309, %1310)
#   %1312 = Cast[to = 7](%1311)
#   %1313 = Constant[value = <Scalar Tensor []>]()
#   %1314 = Constant[value = <Scalar Tensor []>]()
#   %1315 = Range(%1313, %1312, %1314)
#   %1316 = Shape(%1282)
#   %1317 = Constant[value = <Scalar Tensor []>]()
#   %1318 = Gather[axis = 0](%1316, %1317)
#   %1319 = Cast[to = 7](%1318)
#   %1320 = Constant[value = <Scalar Tensor []>]()
#   %1321 = Constant[value = <Scalar Tensor []>]()
#   %1322 = Range(%1320, %1319, %1321)
#   %1323 = Shape(%1282)
#   %1324 = Constant[value = <Scalar Tensor []>]()
#   %1325 = Gather[axis = 0](%1323, %1324)
#   %1326 = Cast[to = 7](%1325)
#   %1327 = Constant[value = <Scalar Tensor []>]()
#   %1328 = Constant[value = <Scalar Tensor []>]()
#   %1329 = Range(%1327, %1326, %1328)
#   %1330 = Shape(%1282)
#   %1331 = Constant[value = <Scalar Tensor []>]()
#   %1332 = Gather[axis = 0](%1330, %1331)
#   %1333 = Cast[to = 7](%1332)
#   %1334 = Constant[value = <Scalar Tensor []>]()
#   %1335 = Constant[value = <Scalar Tensor []>]()
#   %1336 = Range(%1334, %1333, %1335)
#   %1337 = Constant[value = <Tensor>]()
#   %1338 = Constant[value = <Tensor>]()
#   %1339 = Constant[value = <Tensor>]()
#   %1340 = Constant[value = <Tensor>]()
#   %1341 = Slice(%1336, %1338, %1339, %1337, %1340)
#   %1342 = Constant[value = <Tensor>]()
#   %1343 = Reshape(%1308, %1342)
#   %1344 = Constant[value = <Tensor>]()
#   %1345 = Reshape(%1315, %1344)
#   %1346 = Constant[value = <Tensor>]()
#   %1347 = Reshape(%1322, %1346)
#   %1348 = Constant[value = <Tensor>]()
#   %1349 = Reshape(%1329, %1348)
#   %1350 = Constant[value = <Tensor>]()
#   %1351 = Reshape(%1341, %1350)
#   %1352 = Add(%1343, %1345)
#   %1353 = Add(%1352, %1347)
#   %1354 = Add(%1353, %1349)
#   %1355 = Add(%1354, %1351)
#   %1356 = Shape(%1355)
#   %1357 = Shape(%1356)
#   %1358 = ConstantOfShape[value = <Tensor>](%1357)
#   %1359 = Constant[value = <Scalar Tensor []>]()
#   %1360 = Mul(%1358, %1359)
#   %1361 = Equal(%1356, %1360)
#   %1362 = Where(%1361, %1358, %1356)
#   %1363 = Expand(%1343, %1362)
#   %1364 = Unsqueeze[axes = [-1]](%1363)
#   %1365 = Shape(%1356)
#   %1366 = ConstantOfShape[value = <Tensor>](%1365)
#   %1367 = Constant[value = <Scalar Tensor []>]()
#   %1368 = Mul(%1366, %1367)
#   %1369 = Equal(%1356, %1368)
#   %1370 = Where(%1369, %1366, %1356)
#   %1371 = Expand(%1345, %1370)
#   %1372 = Unsqueeze[axes = [-1]](%1371)
#   %1373 = Shape(%1356)
#   %1374 = ConstantOfShape[value = <Tensor>](%1373)
#   %1375 = Constant[value = <Scalar Tensor []>]()
#   %1376 = Mul(%1374, %1375)
#   %1377 = Equal(%1356, %1376)
#   %1378 = Where(%1377, %1374, %1356)
#   %1379 = Expand(%1347, %1378)
#   %1380 = Unsqueeze[axes = [-1]](%1379)
#   %1381 = Shape(%1356)
#   %1382 = ConstantOfShape[value = <Tensor>](%1381)
#   %1383 = Constant[value = <Scalar Tensor []>]()
#   %1384 = Mul(%1382, %1383)
#   %1385 = Equal(%1356, %1384)
#   %1386 = Where(%1385, %1382, %1356)
#   %1387 = Expand(%1349, %1386)
#   %1388 = Unsqueeze[axes = [-1]](%1387)
#   %1389 = Shape(%1356)
#   %1390 = ConstantOfShape[value = <Tensor>](%1389)
#   %1391 = Constant[value = <Scalar Tensor []>]()
#   %1392 = Mul(%1390, %1391)
#   %1393 = Equal(%1356, %1392)
#   %1394 = Where(%1393, %1390, %1356)
#   %1395 = Expand(%1351, %1394)
#   %1396 = Unsqueeze[axes = [-1]](%1395)
#   %1397 = Concat[axis = -1](%1364, %1372, %1380, %1388, %1396)
#   %1398 = Shape(%1282)
#   %1399 = Constant[value = <Tensor>]()
#   %1400 = Constant[value = <Tensor>]()
#   %1401 = Constant[value = <Tensor>]()
#   %1402 = Slice(%1398, %1400, %1401, %1399)
#   %1403 = Concat[axis = 0](%1356, %1402)
#   %1404 = Reshape(%1301, %1403)
#   %1405 = ScatterND(%1282, %1397, %1404)
#   %1406 = Constant[value = <Tensor>]()
#   %1407 = Constant[value = <Tensor>]()
#   %1408 = Constant[value = <Tensor>]()
#   %1409 = Constant[value = <Tensor>]()
#   %1410 = Slice(%1405, %1407, %1408, %1406, %1409)
#   %1411 = Constant[value = <Scalar Tensor []>]()
#   %1412 = Mul(%1410, %1411)
#   %1413 = Constant[value = <Tensor>]()
#   %1414 = Reshape(%1412, %1413)
#   %1415 = Constant[value = <Tensor>]()
#   %1417 = ConstantOfShape[value = <Tensor>](%1556)
#   %1418 = Constant[value = <Scalar Tensor []>]()
#   %1419 = Mul(%1417, %1418)
#   %1420 = Constant[value = <Tensor>]()
#   %1421 = Equal(%1420, %1419)
#   %1422 = Where(%1421, %1417, %1415)
#   %1423 = Expand(%1414, %1422)
#   %1424 = Shape(%1405)
#   %1425 = Constant[value = <Scalar Tensor []>]()
#   %1426 = Gather[axis = 0](%1424, %1425)
#   %1427 = Cast[to = 7](%1426)
#   %1428 = Constant[value = <Scalar Tensor []>]()
#   %1429 = Constant[value = <Scalar Tensor []>]()
#   %1430 = Range(%1428, %1427, %1429)
#   %1431 = Shape(%1405)
#   %1432 = Constant[value = <Scalar Tensor []>]()
#   %1433 = Gather[axis = 0](%1431, %1432)
#   %1434 = Cast[to = 7](%1433)
#   %1435 = Constant[value = <Scalar Tensor []>]()
#   %1436 = Constant[value = <Scalar Tensor []>]()
#   %1437 = Range(%1435, %1434, %1436)
#   %1438 = Shape(%1405)
#   %1439 = Constant[value = <Scalar Tensor []>]()
#   %1440 = Gather[axis = 0](%1438, %1439)
#   %1441 = Cast[to = 7](%1440)
#   %1442 = Constant[value = <Scalar Tensor []>]()
#   %1443 = Constant[value = <Scalar Tensor []>]()
#   %1444 = Range(%1442, %1441, %1443)
#   %1445 = Shape(%1405)
#   %1446 = Constant[value = <Scalar Tensor []>]()
#   %1447 = Gather[axis = 0](%1445, %1446)
#   %1448 = Cast[to = 7](%1447)
#   %1449 = Constant[value = <Scalar Tensor []>]()
#   %1450 = Constant[value = <Scalar Tensor []>]()
#   %1451 = Range(%1449, %1448, %1450)
#   %1452 = Shape(%1405)
#   %1453 = Constant[value = <Scalar Tensor []>]()
#   %1454 = Gather[axis = 0](%1452, %1453)
#   %1455 = Cast[to = 7](%1454)
#   %1456 = Constant[value = <Scalar Tensor []>]()
#   %1457 = Constant[value = <Scalar Tensor []>]()
#   %1458 = Range(%1456, %1455, %1457)
#   %1459 = Constant[value = <Tensor>]()
#   %1460 = Constant[value = <Tensor>]()
#   %1461 = Constant[value = <Tensor>]()
#   %1462 = Constant[value = <Tensor>]()
#   %1463 = Slice(%1458, %1460, %1461, %1459, %1462)
#   %1464 = Constant[value = <Tensor>]()
#   %1465 = Reshape(%1430, %1464)
#   %1466 = Constant[value = <Tensor>]()
#   %1467 = Reshape(%1437, %1466)
#   %1468 = Constant[value = <Tensor>]()
#   %1469 = Reshape(%1444, %1468)
#   %1470 = Constant[value = <Tensor>]()
#   %1471 = Reshape(%1451, %1470)
#   %1472 = Constant[value = <Tensor>]()
#   %1473 = Reshape(%1463, %1472)
#   %1474 = Add(%1465, %1467)
#   %1475 = Add(%1474, %1469)
#   %1476 = Add(%1475, %1471)
#   %1477 = Add(%1476, %1473)
#   %1478 = Shape(%1477)
#   %1479 = Shape(%1478)
#   %1480 = ConstantOfShape[value = <Tensor>](%1479)
#   %1481 = Constant[value = <Scalar Tensor []>]()
#   %1482 = Mul(%1480, %1481)
#   %1483 = Equal(%1478, %1482)
#   %1484 = Where(%1483, %1480, %1478)
#   %1485 = Expand(%1465, %1484)
#   %1486 = Unsqueeze[axes = [-1]](%1485)
#   %1487 = Shape(%1478)
#   %1488 = ConstantOfShape[value = <Tensor>](%1487)
#   %1489 = Constant[value = <Scalar Tensor []>]()
#   %1490 = Mul(%1488, %1489)
#   %1491 = Equal(%1478, %1490)
#   %1492 = Where(%1491, %1488, %1478)
#   %1493 = Expand(%1467, %1492)
#   %1494 = Unsqueeze[axes = [-1]](%1493)
#   %1495 = Shape(%1478)
#   %1496 = ConstantOfShape[value = <Tensor>](%1495)
#   %1497 = Constant[value = <Scalar Tensor []>]()
#   %1498 = Mul(%1496, %1497)
#   %1499 = Equal(%1478, %1498)
#   %1500 = Where(%1499, %1496, %1478)
#   %1501 = Expand(%1469, %1500)
#   %1502 = Unsqueeze[axes = [-1]](%1501)
#   %1503 = Shape(%1478)
#   %1504 = ConstantOfShape[value = <Tensor>](%1503)
#   %1505 = Constant[value = <Scalar Tensor []>]()
#   %1506 = Mul(%1504, %1505)
#   %1507 = Equal(%1478, %1506)
#   %1508 = Where(%1507, %1504, %1478)
#   %1509 = Expand(%1471, %1508)
#   %1510 = Unsqueeze[axes = [-1]](%1509)
#   %1511 = Shape(%1478)
#   %1512 = ConstantOfShape[value = <Tensor>](%1511)
#   %1513 = Constant[value = <Scalar Tensor []>]()
#   %1514 = Mul(%1512, %1513)
#   %1515 = Equal(%1478, %1514)
#   %1516 = Where(%1515, %1512, %1478)
#   %1517 = Expand(%1473, %1516)
#   %1518 = Unsqueeze[axes = [-1]](%1517)
#   %1519 = Concat[axis = -1](%1486, %1494, %1502, %1510, %1518)
#   %1520 = Shape(%1405)
#   %1521 = Constant[value = <Tensor>]()
#   %1522 = Constant[value = <Tensor>]()
#   %1523 = Constant[value = <Tensor>]()
#   %1524 = Slice(%1520, %1522, %1523, %1521)
#   %1525 = Concat[axis = 0](%1478, %1524)
#   %1526 = Reshape(%1423, %1525)
#   %1527 = ScatterND(%1405, %1519, %1526)
#   %1530 = Unsqueeze[axes = [0]](%1147)
#   %1533 = Concat[axis = 0](%1530, %1557, %1558)
#   %1534 = Reshape(%1527, %1533)
#   %classes = Concat[axis = 1](%1119, %1534)
#   return %classes, %yolo1, %yolo2
# }

# %%
onnx_model.graph.node
# Out:
# .BatchNorm2d.bias"
# input: "module_list.1.BatchNorm2d.running_mean"
# input: "module_list.1.BatchNorm2d.running_var"
# output: "507"
# name: "BatchNormalization_4"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "507"
# output: "508"
# name: "LeakyRelu_5"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "508"
# input: "module_list.2.Conv2d.weight"
# output: "509"
# name: "Conv_6"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 8
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "509"
# input: "module_list.2.BatchNorm2d.weight"
# input: "module_list.2.BatchNorm2d.bias"
# input: "module_list.2.BatchNorm2d.running_mean"
# input: "module_list.2.BatchNorm2d.running_var"
# output: "510"
# name: "BatchNormalization_7"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "510"
# output: "511"
# name: "LeakyRelu_8"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "511"
# input: "module_list.3.Conv2d.weight"
# output: "512"
# name: "Conv_9"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "512"
# input: "module_list.3.BatchNorm2d.weight"
# input: "module_list.3.BatchNorm2d.bias"
# input: "module_list.3.BatchNorm2d.running_mean"
# input: "module_list.3.BatchNorm2d.running_var"
# output: "513"
# name: "BatchNormalization_10"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "513"
# input: "module_list.4.Conv2d.weight"
# output: "514"
# name: "Conv_11"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "514"
# input: "module_list.4.BatchNorm2d.weight"
# input: "module_list.4.BatchNorm2d.bias"
# input: "module_list.4.BatchNorm2d.running_mean"
# input: "module_list.4.BatchNorm2d.running_var"
# output: "515"
# name: "BatchNormalization_12"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "515"
# output: "516"
# name: "LeakyRelu_13"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "516"
# input: "module_list.5.Conv2d.weight"
# output: "517"
# name: "Conv_14"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 8
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "517"
# input: "module_list.5.BatchNorm2d.weight"
# input: "module_list.5.BatchNorm2d.bias"
# input: "module_list.5.BatchNorm2d.running_mean"
# input: "module_list.5.BatchNorm2d.running_var"
# output: "518"
# name: "BatchNormalization_15"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "518"
# output: "519"
# name: "LeakyRelu_16"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "519"
# input: "module_list.6.Conv2d.weight"
# output: "520"
# name: "Conv_17"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "520"
# input: "module_list.6.BatchNorm2d.weight"
# input: "module_list.6.BatchNorm2d.bias"
# input: "module_list.6.BatchNorm2d.running_mean"
# input: "module_list.6.BatchNorm2d.running_var"
# output: "521"
# name: "BatchNormalization_18"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "521"
# input: "513"
# output: "522"
# name: "Add_19"
# op_type: "Add"
# , input: "522"
# input: "module_list.9.Conv2d.weight"
# output: "523"
# name: "Conv_20"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "523"
# input: "module_list.9.BatchNorm2d.weight"
# input: "module_list.9.BatchNorm2d.bias"
# input: "module_list.9.BatchNorm2d.running_mean"
# input: "module_list.9.BatchNorm2d.running_var"
# output: "524"
# name: "BatchNormalization_21"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "524"
# output: "525"
# name: "LeakyRelu_22"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "525"
# input: "module_list.10.Conv2d.weight"
# output: "526"
# name: "Conv_23"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 24
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "526"
# input: "module_list.10.BatchNorm2d.weight"
# input: "module_list.10.BatchNorm2d.bias"
# input: "module_list.10.BatchNorm2d.running_mean"
# input: "module_list.10.BatchNorm2d.running_var"
# output: "527"
# name: "BatchNormalization_24"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "527"
# output: "528"
# name: "LeakyRelu_25"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "528"
# input: "module_list.11.Conv2d.weight"
# output: "529"
# name: "Conv_26"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "529"
# input: "module_list.11.BatchNorm2d.weight"
# input: "module_list.11.BatchNorm2d.bias"
# input: "module_list.11.BatchNorm2d.running_mean"
# input: "module_list.11.BatchNorm2d.running_var"
# output: "530"
# name: "BatchNormalization_27"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "530"
# input: "module_list.12.Conv2d.weight"
# output: "531"
# name: "Conv_28"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "531"
# input: "module_list.12.BatchNorm2d.weight"
# input: "module_list.12.BatchNorm2d.bias"
# input: "module_list.12.BatchNorm2d.running_mean"
# input: "module_list.12.BatchNorm2d.running_var"
# output: "532"
# name: "BatchNormalization_29"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "532"
# output: "533"
# name: "LeakyRelu_30"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "533"
# input: "module_list.13.Conv2d.weight"
# output: "534"
# name: "Conv_31"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 32
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "534"
# input: "module_list.13.BatchNorm2d.weight"
# input: "module_list.13.BatchNorm2d.bias"
# input: "module_list.13.BatchNorm2d.running_mean"
# input: "module_list.13.BatchNorm2d.running_var"
# output: "535"
# name: "BatchNormalization_32"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "535"
# output: "536"
# name: "LeakyRelu_33"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "536"
# input: "module_list.14.Conv2d.weight"
# output: "537"
# name: "Conv_34"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "537"
# input: "module_list.14.BatchNorm2d.weight"
# input: "module_list.14.BatchNorm2d.bias"
# input: "module_list.14.BatchNorm2d.running_mean"
# input: "module_list.14.BatchNorm2d.running_var"
# output: "538"
# name: "BatchNormalization_35"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "538"
# input: "530"
# output: "539"
# name: "Add_36"
# op_type: "Add"
# , input: "539"
# input: "module_list.17.Conv2d.weight"
# output: "540"
# name: "Conv_37"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "540"
# input: "module_list.17.BatchNorm2d.weight"
# input: "module_list.17.BatchNorm2d.bias"
# input: "module_list.17.BatchNorm2d.running_mean"
# input: "module_list.17.BatchNorm2d.running_var"
# output: "541"
# name: "BatchNormalization_38"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "541"
# output: "542"
# name: "LeakyRelu_39"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "542"
# input: "module_list.18.Conv2d.weight"
# output: "543"
# name: "Conv_40"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 32
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "543"
# input: "module_list.18.BatchNorm2d.weight"
# input: "module_list.18.BatchNorm2d.bias"
# input: "module_list.18.BatchNorm2d.running_mean"
# input: "module_list.18.BatchNorm2d.running_var"
# output: "544"
# name: "BatchNormalization_41"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "544"
# output: "545"
# name: "LeakyRelu_42"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "545"
# input: "module_list.19.Conv2d.weight"
# output: "546"
# name: "Conv_43"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "546"
# input: "module_list.19.BatchNorm2d.weight"
# input: "module_list.19.BatchNorm2d.bias"
# input: "module_list.19.BatchNorm2d.running_mean"
# input: "module_list.19.BatchNorm2d.running_var"
# output: "547"
# name: "BatchNormalization_44"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "547"
# input: "539"
# output: "548"
# name: "Add_45"
# op_type: "Add"
# , input: "548"
# input: "module_list.22.Conv2d.weight"
# output: "549"
# name: "Conv_46"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "549"
# input: "module_list.22.BatchNorm2d.weight"
# input: "module_list.22.BatchNorm2d.bias"
# input: "module_list.22.BatchNorm2d.running_mean"
# input: "module_list.22.BatchNorm2d.running_var"
# output: "550"
# name: "BatchNormalization_47"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "550"
# output: "551"
# name: "LeakyRelu_48"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "551"
# input: "module_list.23.Conv2d.weight"
# output: "552"
# name: "Conv_49"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 32
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "552"
# input: "module_list.23.BatchNorm2d.weight"
# input: "module_list.23.BatchNorm2d.bias"
# input: "module_list.23.BatchNorm2d.running_mean"
# input: "module_list.23.BatchNorm2d.running_var"
# output: "553"
# name: "BatchNormalization_50"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "553"
# output: "554"
# name: "LeakyRelu_51"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "554"
# input: "module_list.24.Conv2d.weight"
# output: "555"
# name: "Conv_52"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "555"
# input: "module_list.24.BatchNorm2d.weight"
# input: "module_list.24.BatchNorm2d.bias"
# input: "module_list.24.BatchNorm2d.running_mean"
# input: "module_list.24.BatchNorm2d.running_var"
# output: "556"
# name: "BatchNormalization_53"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "556"
# input: "module_list.25.Conv2d.weight"
# output: "557"
# name: "Conv_54"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "557"
# input: "module_list.25.BatchNorm2d.weight"
# input: "module_list.25.BatchNorm2d.bias"
# input: "module_list.25.BatchNorm2d.running_mean"
# input: "module_list.25.BatchNorm2d.running_var"
# output: "558"
# name: "BatchNormalization_55"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "558"
# output: "559"
# name: "LeakyRelu_56"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "559"
# input: "module_list.26.Conv2d.weight"
# output: "560"
# name: "Conv_57"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 48
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "560"
# input: "module_list.26.BatchNorm2d.weight"
# input: "module_list.26.BatchNorm2d.bias"
# input: "module_list.26.BatchNorm2d.running_mean"
# input: "module_list.26.BatchNorm2d.running_var"
# output: "561"
# name: "BatchNormalization_58"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "561"
# output: "562"
# name: "LeakyRelu_59"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "562"
# input: "module_list.27.Conv2d.weight"
# output: "563"
# name: "Conv_60"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "563"
# input: "module_list.27.BatchNorm2d.weight"
# input: "module_list.27.BatchNorm2d.bias"
# input: "module_list.27.BatchNorm2d.running_mean"
# input: "module_list.27.BatchNorm2d.running_var"
# output: "564"
# name: "BatchNormalization_61"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "564"
# input: "556"
# output: "565"
# name: "Add_62"
# op_type: "Add"
# , input: "565"
# input: "module_list.30.Conv2d.weight"
# output: "566"
# name: "Conv_63"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "566"
# input: "module_list.30.BatchNorm2d.weight"
# input: "module_list.30.BatchNorm2d.bias"
# input: "module_list.30.BatchNorm2d.running_mean"
# input: "module_list.30.BatchNorm2d.running_var"
# output: "567"
# name: "BatchNormalization_64"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "567"
# output: "568"
# name: "LeakyRelu_65"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "568"
# input: "module_list.31.Conv2d.weight"
# output: "569"
# name: "Conv_66"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 48
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "569"
# input: "module_list.31.BatchNorm2d.weight"
# input: "module_list.31.BatchNorm2d.bias"
# input: "module_list.31.BatchNorm2d.running_mean"
# input: "module_list.31.BatchNorm2d.running_var"
# output: "570"
# name: "BatchNormalization_67"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "570"
# output: "571"
# name: "LeakyRelu_68"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "571"
# input: "module_list.32.Conv2d.weight"
# output: "572"
# name: "Conv_69"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "572"
# input: "module_list.32.BatchNorm2d.weight"
# input: "module_list.32.BatchNorm2d.bias"
# input: "module_list.32.BatchNorm2d.running_mean"
# input: "module_list.32.BatchNorm2d.running_var"
# output: "573"
# name: "BatchNormalization_70"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "573"
# input: "565"
# output: "574"
# name: "Add_71"
# op_type: "Add"
# , input: "574"
# input: "module_list.35.Conv2d.weight"
# output: "575"
# name: "Conv_72"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "575"
# input: "module_list.35.BatchNorm2d.weight"
# input: "module_list.35.BatchNorm2d.bias"
# input: "module_list.35.BatchNorm2d.running_mean"
# input: "module_list.35.BatchNorm2d.running_var"
# output: "576"
# name: "BatchNormalization_73"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "576"
# output: "577"
# name: "LeakyRelu_74"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "577"
# input: "module_list.36.Conv2d.weight"
# output: "578"
# name: "Conv_75"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 48
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "578"
# input: "module_list.36.BatchNorm2d.weight"
# input: "module_list.36.BatchNorm2d.bias"
# input: "module_list.36.BatchNorm2d.running_mean"
# input: "module_list.36.BatchNorm2d.running_var"
# output: "579"
# name: "BatchNormalization_76"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "579"
# output: "580"
# name: "LeakyRelu_77"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "580"
# input: "module_list.37.Conv2d.weight"
# output: "581"
# name: "Conv_78"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "581"
# input: "module_list.37.BatchNorm2d.weight"
# input: "module_list.37.BatchNorm2d.bias"
# input: "module_list.37.BatchNorm2d.running_mean"
# input: "module_list.37.BatchNorm2d.running_var"
# output: "582"
# name: "BatchNormalization_79"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "582"
# input: "module_list.38.Conv2d.weight"
# output: "583"
# name: "Conv_80"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "583"
# input: "module_list.38.BatchNorm2d.weight"
# input: "module_list.38.BatchNorm2d.bias"
# input: "module_list.38.BatchNorm2d.running_mean"
# input: "module_list.38.BatchNorm2d.running_var"
# output: "584"
# name: "BatchNormalization_81"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "584"
# output: "585"
# name: "LeakyRelu_82"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "585"
# input: "module_list.39.Conv2d.weight"
# output: "586"
# name: "Conv_83"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 96
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "586"
# input: "module_list.39.BatchNorm2d.weight"
# input: "module_list.39.BatchNorm2d.bias"
# input: "module_list.39.BatchNorm2d.running_mean"
# input: "module_list.39.BatchNorm2d.running_var"
# output: "587"
# name: "BatchNormalization_84"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "587"
# output: "588"
# name: "LeakyRelu_85"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "588"
# input: "module_list.40.Conv2d.weight"
# output: "589"
# name: "Conv_86"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "589"
# input: "module_list.40.BatchNorm2d.weight"
# input: "module_list.40.BatchNorm2d.bias"
# input: "module_list.40.BatchNorm2d.running_mean"
# input: "module_list.40.BatchNorm2d.running_var"
# output: "590"
# name: "BatchNormalization_87"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "590"
# input: "582"
# output: "591"
# name: "Add_88"
# op_type: "Add"
# , input: "591"
# input: "module_list.43.Conv2d.weight"
# output: "592"
# name: "Conv_89"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "592"
# input: "module_list.43.BatchNorm2d.weight"
# input: "module_list.43.BatchNorm2d.bias"
# input: "module_list.43.BatchNorm2d.running_mean"
# input: "module_list.43.BatchNorm2d.running_var"
# output: "593"
# name: "BatchNormalization_90"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "593"
# output: "594"
# name: "LeakyRelu_91"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "594"
# input: "module_list.44.Conv2d.weight"
# output: "595"
# name: "Conv_92"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 96
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "595"
# input: "module_list.44.BatchNorm2d.weight"
# input: "module_list.44.BatchNorm2d.bias"
# input: "module_list.44.BatchNorm2d.running_mean"
# input: "module_list.44.BatchNorm2d.running_var"
# output: "596"
# name: "BatchNormalization_93"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "596"
# output: "597"
# name: "LeakyRelu_94"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "597"
# input: "module_list.45.Conv2d.weight"
# output: "598"
# name: "Conv_95"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "598"
# input: "module_list.45.BatchNorm2d.weight"
# input: "module_list.45.BatchNorm2d.bias"
# input: "module_list.45.BatchNorm2d.running_mean"
# input: "module_list.45.BatchNorm2d.running_var"
# output: "599"
# name: "BatchNormalization_96"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "599"
# input: "591"
# output: "600"
# name: "Add_97"
# op_type: "Add"
# , input: "600"
# input: "module_list.48.Conv2d.weight"
# output: "601"
# name: "Conv_98"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "601"
# input: "module_list.48.BatchNorm2d.weight"
# input: "module_list.48.BatchNorm2d.bias"
# input: "module_list.48.BatchNorm2d.running_mean"
# input: "module_list.48.BatchNorm2d.running_var"
# output: "602"
# name: "BatchNormalization_99"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "602"
# output: "603"
# name: "LeakyRelu_100"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "603"
# input: "module_list.49.Conv2d.weight"
# output: "604"
# name: "Conv_101"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 96
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "604"
# input: "module_list.49.BatchNorm2d.weight"
# input: "module_list.49.BatchNorm2d.bias"
# input: "module_list.49.BatchNorm2d.running_mean"
# input: "module_list.49.BatchNorm2d.running_var"
# output: "605"
# name: "BatchNormalization_102"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "605"
# output: "606"
# name: "LeakyRelu_103"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "606"
# input: "module_list.50.Conv2d.weight"
# output: "607"
# name: "Conv_104"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "607"
# input: "module_list.50.BatchNorm2d.weight"
# input: "module_list.50.BatchNorm2d.bias"
# input: "module_list.50.BatchNorm2d.running_mean"
# input: "module_list.50.BatchNorm2d.running_var"
# output: "608"
# name: "BatchNormalization_105"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "608"
# input: "600"
# output: "609"
# name: "Add_106"
# op_type: "Add"
# , input: "609"
# input: "module_list.53.Conv2d.weight"
# output: "610"
# name: "Conv_107"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "610"
# input: "module_list.53.BatchNorm2d.weight"
# input: "module_list.53.BatchNorm2d.bias"
# input: "module_list.53.BatchNorm2d.running_mean"
# input: "module_list.53.BatchNorm2d.running_var"
# output: "611"
# name: "BatchNormalization_108"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "611"
# output: "612"
# name: "LeakyRelu_109"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "612"
# input: "module_list.54.Conv2d.weight"
# output: "613"
# name: "Conv_110"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 96
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "613"
# input: "module_list.54.BatchNorm2d.weight"
# input: "module_list.54.BatchNorm2d.bias"
# input: "module_list.54.BatchNorm2d.running_mean"
# input: "module_list.54.BatchNorm2d.running_var"
# output: "614"
# name: "BatchNormalization_111"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "614"
# output: "615"
# name: "LeakyRelu_112"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "615"
# input: "module_list.55.Conv2d.weight"
# output: "616"
# name: "Conv_113"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "616"
# input: "module_list.55.BatchNorm2d.weight"
# input: "module_list.55.BatchNorm2d.bias"
# input: "module_list.55.BatchNorm2d.running_mean"
# input: "module_list.55.BatchNorm2d.running_var"
# output: "617"
# name: "BatchNormalization_114"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "617"
# input: "609"
# output: "618"
# name: "Add_115"
# op_type: "Add"
# , input: "618"
# input: "module_list.58.Conv2d.weight"
# output: "619"
# name: "Conv_116"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "619"
# input: "module_list.58.BatchNorm2d.weight"
# input: "module_list.58.BatchNorm2d.bias"
# input: "module_list.58.BatchNorm2d.running_mean"
# input: "module_list.58.BatchNorm2d.running_var"
# output: "620"
# name: "BatchNormalization_117"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "620"
# output: "621"
# name: "LeakyRelu_118"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "621"
# input: "module_list.59.Conv2d.weight"
# output: "622"
# name: "Conv_119"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 96
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "622"
# input: "module_list.59.BatchNorm2d.weight"
# input: "module_list.59.BatchNorm2d.bias"
# input: "module_list.59.BatchNorm2d.running_mean"
# input: "module_list.59.BatchNorm2d.running_var"
# output: "623"
# name: "BatchNormalization_120"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "623"
# output: "624"
# name: "LeakyRelu_121"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "624"
# input: "module_list.60.Conv2d.weight"
# output: "625"
# name: "Conv_122"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "625"
# input: "module_list.60.BatchNorm2d.weight"
# input: "module_list.60.BatchNorm2d.bias"
# input: "module_list.60.BatchNorm2d.running_mean"
# input: "module_list.60.BatchNorm2d.running_var"
# output: "626"
# name: "BatchNormalization_123"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "626"
# input: "module_list.61.Conv2d.weight"
# output: "627"
# name: "Conv_124"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "627"
# input: "module_list.61.BatchNorm2d.weight"
# input: "module_list.61.BatchNorm2d.bias"
# input: "module_list.61.BatchNorm2d.running_mean"
# input: "module_list.61.BatchNorm2d.running_var"
# output: "628"
# name: "BatchNormalization_125"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "628"
# output: "629"
# name: "LeakyRelu_126"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "629"
# input: "module_list.62.Conv2d.weight"
# output: "630"
# name: "Conv_127"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 136
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "630"
# input: "module_list.62.BatchNorm2d.weight"
# input: "module_list.62.BatchNorm2d.bias"
# input: "module_list.62.BatchNorm2d.running_mean"
# input: "module_list.62.BatchNorm2d.running_var"
# output: "631"
# name: "BatchNormalization_128"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "631"
# output: "632"
# name: "LeakyRelu_129"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "632"
# input: "module_list.63.Conv2d.weight"
# output: "633"
# name: "Conv_130"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "633"
# input: "module_list.63.BatchNorm2d.weight"
# input: "module_list.63.BatchNorm2d.bias"
# input: "module_list.63.BatchNorm2d.running_mean"
# input: "module_list.63.BatchNorm2d.running_var"
# output: "634"
# name: "BatchNormalization_131"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "634"
# input: "626"
# output: "635"
# name: "Add_132"
# op_type: "Add"
# , input: "635"
# input: "module_list.66.Conv2d.weight"
# output: "636"
# name: "Conv_133"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "636"
# input: "module_list.66.BatchNorm2d.weight"
# input: "module_list.66.BatchNorm2d.bias"
# input: "module_list.66.BatchNorm2d.running_mean"
# input: "module_list.66.BatchNorm2d.running_var"
# output: "637"
# name: "BatchNormalization_134"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "637"
# output: "638"
# name: "LeakyRelu_135"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "638"
# input: "module_list.67.Conv2d.weight"
# output: "639"
# name: "Conv_136"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 136
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "639"
# input: "module_list.67.BatchNorm2d.weight"
# input: "module_list.67.BatchNorm2d.bias"
# input: "module_list.67.BatchNorm2d.running_mean"
# input: "module_list.67.BatchNorm2d.running_var"
# output: "640"
# name: "BatchNormalization_137"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "640"
# output: "641"
# name: "LeakyRelu_138"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "641"
# input: "module_list.68.Conv2d.weight"
# output: "642"
# name: "Conv_139"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "642"
# input: "module_list.68.BatchNorm2d.weight"
# input: "module_list.68.BatchNorm2d.bias"
# input: "module_list.68.BatchNorm2d.running_mean"
# input: "module_list.68.BatchNorm2d.running_var"
# output: "643"
# name: "BatchNormalization_140"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "643"
# input: "635"
# output: "644"
# name: "Add_141"
# op_type: "Add"
# , input: "644"
# input: "module_list.71.Conv2d.weight"
# output: "645"
# name: "Conv_142"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "645"
# input: "module_list.71.BatchNorm2d.weight"
# input: "module_list.71.BatchNorm2d.bias"
# input: "module_list.71.BatchNorm2d.running_mean"
# input: "module_list.71.BatchNorm2d.running_var"
# output: "646"
# name: "BatchNormalization_143"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "646"
# output: "647"
# name: "LeakyRelu_144"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "647"
# input: "module_list.72.Conv2d.weight"
# output: "648"
# name: "Conv_145"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 136
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "648"
# input: "module_list.72.BatchNorm2d.weight"
# input: "module_list.72.BatchNorm2d.bias"
# input: "module_list.72.BatchNorm2d.running_mean"
# input: "module_list.72.BatchNorm2d.running_var"
# output: "649"
# name: "BatchNormalization_146"
# op_type: "BatchNormalization"
# attribute {
#   name: "epsilon"
#   f: 9.999999747378752e-05
#   type: FLOAT
# }
# attribute {
#   name: "momentum"
#   f: 0.9700000286102295
#   type: FLOAT
# }
# , input: "649"
# output: "650"
# name: "LeakyRelu_147"
# op_type: "LeakyRelu"
# attribute {
#   name: "alpha"
#   f: 0.10000000149011612
#   type: FLOAT
# }
# , input: "650"
# input: "module_list.73.Conv2d.weight"
# output: "651"
# name: "Conv_148"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "651"
# input: "module_list.73.BatchNorm2d.weight"
# input: "module_list.73.BatchNorm2d.bias"
# input: "module_list.73.BatchNorm2d.running_mean"
# input: "module_list.73.BatchNorm2d.running_var"
# ...
# output: "1410"
# name: "Slice_874"
# op_type: "Slice"
# , output: "1411"
# name: "Constant_875"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 1
#     raw_data: "\000\000\200A"
#   }
#   type: TENSOR
# }
# , input: "1410"
# input: "1411"
# output: "1412"
# name: "Mul_876"
# op_type: "Mul"
# , output: "1413"
# name: "Constant_877"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 4
#     data_type: 7
#     raw_data: "\003\000\000\000\000\000\000\000\024\000\000\000\000\000\000\000 \000\000\000\000\000\000\000\004\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1412"
# input: "1413"
# output: "1414"
# name: "Reshape_878"
# op_type: "Reshape"
# , output: "1415"
# name: "Constant_879"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 5
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000\003\000\000\000\000\000\000\000\024\000\000\000\000\000\000\000 \000\000\000\000\000\000\000\004\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1556"
# output: "1417"
# name: "ConstantOfShape_880"
# op_type: "ConstantOfShape"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1418"
# name: "Constant_881"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1417"
# input: "1418"
# output: "1419"
# name: "Mul_882"
# op_type: "Mul"
# , output: "1420"
# name: "Constant_883"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 5
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000\003\000\000\000\000\000\000\000\024\000\000\000\000\000\000\000 \000\000\000\000\000\000\000\004\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1420"
# input: "1419"
# output: "1421"
# name: "Equal_884"
# op_type: "Equal"
# , input: "1421"
# input: "1417"
# input: "1415"
# output: "1422"
# name: "Where_885"
# op_type: "Where"
# , input: "1414"
# input: "1422"
# output: "1423"
# name: "Expand_886"
# op_type: "Expand"
# , input: "1405"
# output: "1424"
# name: "Shape_887"
# op_type: "Shape"
# , output: "1425"
# name: "Constant_888"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1424"
# input: "1425"
# output: "1426"
# name: "Gather_889"
# op_type: "Gather"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1426"
# output: "1427"
# name: "Cast_890"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 7
#   type: INT
# }
# , output: "1428"
# name: "Constant_891"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1429"
# name: "Constant_892"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1428"
# input: "1427"
# input: "1429"
# output: "1430"
# name: "Range_893"
# op_type: "Range"
# , input: "1405"
# output: "1431"
# name: "Shape_894"
# op_type: "Shape"
# , output: "1432"
# name: "Constant_895"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1431"
# input: "1432"
# output: "1433"
# name: "Gather_896"
# op_type: "Gather"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1433"
# output: "1434"
# name: "Cast_897"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 7
#   type: INT
# }
# , output: "1435"
# name: "Constant_898"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1436"
# name: "Constant_899"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1435"
# input: "1434"
# input: "1436"
# output: "1437"
# name: "Range_900"
# op_type: "Range"
# , input: "1405"
# output: "1438"
# name: "Shape_901"
# op_type: "Shape"
# , output: "1439"
# name: "Constant_902"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\002\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1438"
# input: "1439"
# output: "1440"
# name: "Gather_903"
# op_type: "Gather"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1440"
# output: "1441"
# name: "Cast_904"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 7
#   type: INT
# }
# , output: "1442"
# name: "Constant_905"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1443"
# name: "Constant_906"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1442"
# input: "1441"
# input: "1443"
# output: "1444"
# name: "Range_907"
# op_type: "Range"
# , input: "1405"
# output: "1445"
# name: "Shape_908"
# op_type: "Shape"
# , output: "1446"
# name: "Constant_909"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\003\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1445"
# input: "1446"
# output: "1447"
# name: "Gather_910"
# op_type: "Gather"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1447"
# output: "1448"
# name: "Cast_911"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 7
#   type: INT
# }
# , output: "1449"
# name: "Constant_912"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1450"
# name: "Constant_913"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1449"
# input: "1448"
# input: "1450"
# output: "1451"
# name: "Range_914"
# op_type: "Range"
# , input: "1405"
# output: "1452"
# name: "Shape_915"
# op_type: "Shape"
# , output: "1453"
# name: "Constant_916"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\004\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1452"
# input: "1453"
# output: "1454"
# name: "Gather_917"
# op_type: "Gather"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1454"
# output: "1455"
# name: "Cast_918"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 7
#   type: INT
# }
# , output: "1456"
# name: "Constant_919"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1457"
# name: "Constant_920"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1456"
# input: "1455"
# input: "1457"
# output: "1458"
# name: "Range_921"
# op_type: "Range"
# , output: "1459"
# name: "Constant_922"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1460"
# name: "Constant_923"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1461"
# name: "Constant_924"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\004\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1462"
# name: "Constant_925"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1458"
# input: "1460"
# input: "1461"
# input: "1459"
# input: "1462"
# output: "1463"
# name: "Slice_926"
# op_type: "Slice"
# , output: "1464"
# name: "Constant_927"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 5
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377\001\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1430"
# input: "1464"
# output: "1465"
# name: "Reshape_928"
# op_type: "Reshape"
# , output: "1466"
# name: "Constant_929"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 4
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377\001\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1437"
# input: "1466"
# output: "1467"
# name: "Reshape_930"
# op_type: "Reshape"
# , output: "1468"
# name: "Constant_931"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 3
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377\001\000\000\000\000\000\000\000\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1444"
# input: "1468"
# output: "1469"
# name: "Reshape_932"
# op_type: "Reshape"
# , output: "1470"
# name: "Constant_933"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 2
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , input: "1451"
# input: "1470"
# output: "1471"
# name: "Reshape_934"
# op_type: "Reshape"
# , output: "1472"
# name: "Constant_935"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1463"
# input: "1472"
# output: "1473"
# name: "Reshape_936"
# op_type: "Reshape"
# , input: "1465"
# input: "1467"
# output: "1474"
# name: "Add_937"
# op_type: "Add"
# , input: "1474"
# input: "1469"
# output: "1475"
# name: "Add_938"
# op_type: "Add"
# , input: "1475"
# input: "1471"
# output: "1476"
# name: "Add_939"
# op_type: "Add"
# , input: "1476"
# input: "1473"
# output: "1477"
# name: "Add_940"
# op_type: "Add"
# , input: "1477"
# output: "1478"
# name: "Shape_941"
# op_type: "Shape"
# , input: "1478"
# output: "1479"
# name: "Shape_942"
# op_type: "Shape"
# , input: "1479"
# output: "1480"
# name: "ConstantOfShape_943"
# op_type: "ConstantOfShape"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1481"
# name: "Constant_944"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1480"
# input: "1481"
# output: "1482"
# name: "Mul_945"
# op_type: "Mul"
# , input: "1478"
# input: "1482"
# output: "1483"
# name: "Equal_946"
# op_type: "Equal"
# , input: "1483"
# input: "1480"
# input: "1478"
# output: "1484"
# name: "Where_947"
# op_type: "Where"
# , input: "1465"
# input: "1484"
# output: "1485"
# name: "Expand_948"
# op_type: "Expand"
# , input: "1485"
# output: "1486"
# name: "Unsqueeze_949"
# op_type: "Unsqueeze"
# attribute {
#   name: "axes"
#   ints: -1
#   type: INTS
# }
# , input: "1478"
# output: "1487"
# name: "Shape_950"
# op_type: "Shape"
# , input: "1487"
# output: "1488"
# name: "ConstantOfShape_951"
# op_type: "ConstantOfShape"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1489"
# name: "Constant_952"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1488"
# input: "1489"
# output: "1490"
# name: "Mul_953"
# op_type: "Mul"
# , input: "1478"
# input: "1490"
# output: "1491"
# name: "Equal_954"
# op_type: "Equal"
# , input: "1491"
# input: "1488"
# input: "1478"
# output: "1492"
# name: "Where_955"
# op_type: "Where"
# , input: "1467"
# input: "1492"
# output: "1493"
# name: "Expand_956"
# op_type: "Expand"
# , input: "1493"
# output: "1494"
# name: "Unsqueeze_957"
# op_type: "Unsqueeze"
# attribute {
#   name: "axes"
#   ints: -1
#   type: INTS
# }
# , input: "1478"
# output: "1495"
# name: "Shape_958"
# op_type: "Shape"
# , input: "1495"
# output: "1496"
# name: "ConstantOfShape_959"
# op_type: "ConstantOfShape"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1497"
# name: "Constant_960"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1496"
# input: "1497"
# output: "1498"
# name: "Mul_961"
# op_type: "Mul"
# , input: "1478"
# input: "1498"
# output: "1499"
# name: "Equal_962"
# op_type: "Equal"
# , input: "1499"
# input: "1496"
# input: "1478"
# output: "1500"
# name: "Where_963"
# op_type: "Where"
# , input: "1469"
# input: "1500"
# output: "1501"
# name: "Expand_964"
# op_type: "Expand"
# , input: "1501"
# output: "1502"
# name: "Unsqueeze_965"
# op_type: "Unsqueeze"
# attribute {
#   name: "axes"
#   ints: -1
#   type: INTS
# }
# , input: "1478"
# output: "1503"
# name: "Shape_966"
# op_type: "Shape"
# , input: "1503"
# output: "1504"
# name: "ConstantOfShape_967"
# op_type: "ConstantOfShape"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1505"
# name: "Constant_968"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1504"
# input: "1505"
# output: "1506"
# name: "Mul_969"
# op_type: "Mul"
# , input: "1478"
# input: "1506"
# output: "1507"
# name: "Equal_970"
# op_type: "Equal"
# , input: "1507"
# input: "1504"
# input: "1478"
# output: "1508"
# name: "Where_971"
# op_type: "Where"
# , input: "1471"
# input: "1508"
# output: "1509"
# name: "Expand_972"
# op_type: "Expand"
# , input: "1509"
# output: "1510"
# name: "Unsqueeze_973"
# op_type: "Unsqueeze"
# attribute {
#   name: "axes"
#   ints: -1
#   type: INTS
# }
# , input: "1478"
# output: "1511"
# name: "Shape_974"
# op_type: "Shape"
# , input: "1511"
# output: "1512"
# name: "ConstantOfShape_975"
# op_type: "ConstantOfShape"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\001\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1513"
# name: "Constant_976"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\377"
#   }
#   type: TENSOR
# }
# , input: "1512"
# input: "1513"
# output: "1514"
# name: "Mul_977"
# op_type: "Mul"
# , input: "1478"
# input: "1514"
# output: "1515"
# name: "Equal_978"
# op_type: "Equal"
# , input: "1515"
# input: "1512"
# input: "1478"
# output: "1516"
# name: "Where_979"
# op_type: "Where"
# , input: "1473"
# input: "1516"
# output: "1517"
# name: "Expand_980"
# op_type: "Expand"
# , input: "1517"
# output: "1518"
# name: "Unsqueeze_981"
# op_type: "Unsqueeze"
# attribute {
#   name: "axes"
#   ints: -1
#   type: INTS
# }
# , input: "1486"
# input: "1494"
# input: "1502"
# input: "1510"
# input: "1518"
# output: "1519"
# name: "Concat_982"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   i: -1
#   type: INT
# }
# , input: "1405"
# output: "1520"
# name: "Shape_983"
# op_type: "Shape"
# , output: "1521"
# name: "Constant_984"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\000\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1522"
# name: "Constant_985"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\005\000\000\000\000\000\000\000"
#   }
#   type: TENSOR
# }
# , output: "1523"
# name: "Constant_986"
# op_type: "Constant"
# attribute {
#   name: "value"
#   t {
#     dims: 1
#     data_type: 7
#     raw_data: "\377\377\377\377\377\377\377\177"
#   }
#   type: TENSOR
# }
# , input: "1520"
# input: "1522"
# input: "1523"
# input: "1521"
# output: "1524"
# name: "Slice_987"
# op_type: "Slice"
# , input: "1478"
# input: "1524"
# output: "1525"
# name: "Concat_988"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1423"
# input: "1525"
# output: "1526"
# name: "Reshape_989"
# op_type: "Reshape"
# , input: "1405"
# input: "1519"
# input: "1526"
# output: "1527"
# name: "ScatterND_990"
# op_type: "ScatterND"
# , input: "1147"
# output: "1530"
# name: "Unsqueeze_991"
# op_type: "Unsqueeze"
# attribute {
#   name: "axes"
#   ints: 0
#   type: INTS
# }
# , input: "1530"
# input: "1557"
# input: "1558"
# output: "1533"
# name: "Concat_992"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   i: 0
#   type: INT
# }
# , input: "1527"
# input: "1533"
# output: "1534"
# name: "Reshape_993"
# op_type: "Reshape"
# , input: "1119"
# input: "1534"
# output: "classes"
# name: "Concat_994"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   i: 1
#   type: INT
# }
# ]

# %%
import onnxruntime

ort_session = onnxruntime.InferenceSession("weights/yolo-fastest.onnx")

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# compute ONNX Runtime output prediction
x_array = to_numpy(x)
ort_inputs = {ort_session.get_inputs()[0].name: x_array}
ort_outs = ort_session.run(None, ort_inputs)

# %%
torch_out[0].shape
# Out:
# torch.Size([1, 2400, 7])

# %%
# compare ONNX Runtime and PyTorch results
torch_out_array = [to_numpy(torch_out[0]), to_numpy(torch_out[1][0]),to_numpy(torch_out[1][1])]
np.testing.assert_allclose(torch_out_array[0], ort_outs[0], rtol=1e-03, atol=1e-05)

print("Exported model has been tested with ONNXRuntime, and the result looks good!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-30-29f2a1871e2b> in <module>
#       1 # compare ONNX Runtime and PyTorch results
#       2 torch_out_array = [to_numpy(torch_out[0]), to_numpy(torch_out[1][0]),to_numpy(torch_out[1][1])]
# ----> 3 np.testing.assert_allclose(torch_out_array[0], ort_outs[0], rtol=1e-03, atol=1e-05)
#       4
#       5 print("Exported model has been tested with ONNXRuntime, and the result looks good!")
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/testing/_private/utils.py in assert_allclose(actual, desired, rtol, atol, equal_nan, err_msg, verbose)
#    1526     header = 'Not equal to tolerance rtol=%g, atol=%g' % (rtol, atol)
#    1527     assert_array_compare(compare, actual, desired, err_msg=str(err_msg),
# -> 1528                          verbose=verbose, header=header, equal_nan=equal_nan)
#    1529
#    1530
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/testing/_private/utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     838                                 verbose=verbose, header=header,
#     839                                 names=('x', 'y'), precision=precision)
# --> 840             raise AssertionError(msg)
#     841     except ValueError:
#     842         import traceback
#
# AssertionError:
# Not equal to tolerance rtol=0.001, atol=1e-05
#
# Mismatched elements: 7197 / 16800 (42.8%)
# Max absolute difference:      19.835
# Max relative difference:   4.092e+05
#  x: array([[[     25.479,       21.32,      57.021, ...,  2.7384e-06,    0.013062,     0.99144],
#         [     48.863,      23.147,      103.85, ...,  3.9784e-05,   0.0075577,     0.99291],
#         [     84.161,          24,      153.27, ...,  4.0627e-05,   0.0075448,     0.99217],...
#  y: array([[[     25.479,       21.32,      57.021, ...,     -12.808,     -4.3249,      4.7517],
#         [     48.863,      23.147,      103.85, ...,     -10.132,     -4.8776,      4.9417],
#         [     84.161,          24,      153.27, ...,     -10.111,     -4.8793,      4.8415],...

# %%
np.testing.assert_allclose(torch_out_array[1], ort_outs[1], rtol=1e-03, atol=1e-05)
np.testing.assert_allclose(torch_out_array[2], ort_outs[2], rtol=1e-03, atol=1e-05)

print("Exported model has been tested with ONNXRuntime, and the result looks good!")
# Out:
# Exported model has been tested with ONNXRuntime, and the result looks good!

# %%
from onnxruntime.quantization import quantize_dynamic, QuantType

model_fp32 = 'weights/yolo-fastest.onnx'
model_quant = 'weights/yolo-fastest-int8.onnx'
quantized_model = quantize_dynamic(model_fp32, model_quant, weight_type=QuantType.QUInt8)

# %%
from onnxruntime.quantization import quantize_qat, QuantType

model_fp32 = 'weights/yolo-fastest.onnx'
model_quant = 'weights/yolo-fastest-int8.onnx'
quantized_model = quantize_qat(model_fp32, model_quant)

# %%
def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

batch_size = 1
# Input to the model
x = torch.randn(batch_size, 3, 320, 512, requires_grad=True)
torch_out = model(x)
torch_out_array = [to_numpy(torch_out[0]), to_numpy(torch_out[1][0]),to_numpy(torch_out[1][1])]

# %%
from tensorflow.keras.models import load_model

x_array = to_numpy(x)
x_array = np.transpose(x_array, [0, 2, 3, 1])
keras_model = load_model('weights/yolo-fastest.h5', compile=False)
keras_out = keras_model(x_array)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-24-2a52953e4c7c> in <module>
#       4 x_array = np.transpose(x_array, [0, 2, 3, 1])
#       5 keras_model = load_model('weights/yolo-fastest.h5', compile=False)
# ----> 6 keras_out = keras_model(x_array)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     384     """
#     385     return self._run_internal_graph(
# --> 386         inputs, training=training, mask=mask)
#     387
#     388   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     506
#     507         args, kwargs = node.map_arguments(tensor_dict)
# --> 508         outputs = node.layer(*args, **kwargs)
#     509
#     510         # Update tensor_dict.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/convolutional.py in call(self, inputs)
#     245       inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
#     246
# --> 247     outputs = self._convolution_op(inputs, self.kernel)
#     248
#     249     if self.use_bias:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1015       data_format=data_format,
#    1016       dilations=dilations,
# -> 1017       name=name)
#    1018
#    1019
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1145           data_format=data_format,
#    1146           dilations=dilations,
# -> 1147           name=name)
#    1148     else:
#    1149       if channel_index == 1:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2589         data_format=data_format,
#    2590         dilations=dilations,
# -> 2591         name=name)
#    2592   return squeeze_batch_dims(
#    2593       input,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     936       return _result
#     937     except _core._NotOkStatusException as e:
# --> 938       _ops.raise_from_not_ok_status(e, name)
#     939     except _core._FallbackException:
#     940       pass
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# ~/anaconda3/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# UnimplementedError: The Conv2D op currently does not support grouped convolutions on the CPU. A grouped convolution was attempted to be run because the input depth of 8 does not match the filter input depth of 1 [Op:Conv2D]

# %%
np.shape(x_array)
# Out:
# (320, 512, 1, 3)
